# %%
import numpy as np
import pandas as pd
import csv

# %% [markdown]
# # By Zeek

# %%
path='/home/janati/Desktop/Meryem/IDS-Datasets/Datasets/cupid/Zeek/timeout1/Baselines/conn_logs/042219_1000_0_conn.log'

df1 = pd.read_csv(path, sep="\t", comment='#',
                         names=['ts', 'uid', 'id.orig_h', 'id.orig_p',
                                'id.resp_h', 'id.resp_p', 'proto', 'service',
                                'duration',  'orig_bytes', 'resp_bytes',
                                'conn_state', 'local_orig', 'local_resp',
                                'missed_bytes',  'history', 'orig_pkts',
                                'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes',
                                'tunnel_parents'])

df1 = pd.DataFrame(df1.values, columns=df1.columns)
df1['duration'].replace('-', np.nan, inplace=True)
df1['duration'] = df1['duration'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       1 path='/home/janati/Desktop/Meryem/IDS-Datasets/Datasets/cupid/Zeek/timeout1/Baselines/conn_logs/042219_1000_0_conn.log'
# ----> 3 df1 = pd.read_csv(path, sep="\t", comment='#',
#       4                          names=['ts', 'uid', 'id.orig_h', 'id.orig_p',
#       5                                 'id.resp_h', 'id.resp_p', 'proto', 'service',
#       6                                 'duration',  'orig_bytes', 'resp_bytes',
#       7                                 'conn_state', 'local_orig', 'local_resp',
#       8                                 'missed_bytes',  'history', 'orig_pkts',
#       9                                 'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes',
#      10                                 'tunnel_parents'])
#      12 df1 = pd.DataFrame(df1.values, columns=df1.columns)
#      13 df1['duration'].replace('-', np.nan, inplace=True)
#
# File ~/anaconda3/envs/ids_env2/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/ids_env2/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/ids_env2/lib/python3.8/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/anaconda3/envs/ids_env2/lib/python3.8/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/ids_env2/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/anaconda3/envs/ids_env2/lib/python3.8/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/janati/Desktop/Meryem/IDS-Datasets/Datasets/cupid/Zeek/timeout1/Baselines/conn_logs/042219_1000_0_conn.log'

# %%
df1.head()
# Out:
#                   ts                 uid      id.orig_h id.orig_p  \
# 0  1555945272.145427  CSXoLx3fG4r1zC35zc  192.168.1.105     61890
# 1  1555945273.474809  CKWLaF2QRW68Jdeem2   192.168.1.50     61200
# 2  1555945276.079306  Cv6lXB2glbmps45L38    192.168.1.7     49666
# 3  1555945279.876259  CDlFqq4bpcwyMsh506   192.168.1.11     64764
# 4   1555945280.13829  Cx1qpA43pRLJ0aoVHk   192.168.1.11     64767
#
#      id.resp_h id.resp_p proto service  duration orig_bytes  ... conn_state  \
# 0  64.4.54.254       443   tcp       -  0.027222          0  ...         SF
# 1  64.4.54.253       443   tcp       -  0.000006          0  ...        OTH
# 2  192.168.1.9     30692   tcp       -  0.000011          0  ...         SF
# 3  192.168.1.7       389   tcp       -  0.042657       3291  ...       RSTR
# 4  192.168.1.7      3268   tcp       -  0.012241       3047  ...       RSTR
#
#   local_orig local_resp missed_bytes      history orig_pkts orig_ip_bytes  \
# 0          T          F            0          FfA         4           160
# 1          T          F            0            R         2            80
# 2          T          T            0         AfFa         4           160
# 3          T          T            1  ShADTdtaGrF        20          8096
# 4          T          T            0   ShADTdtaFr        26          7158
#
#   resp_pkts resp_ip_bytes tunnel_parents
# 0         2            80              -
# 1         0             0              -
# 2         4           160              -
# 3        20          8136              -
# 4        26          8770              -
#
# [5 rows x 21 columns]

# %%
df1["duration"].max(), df1["duration"].min(), df1.shape
# Out:
# (10975.544676, 1e-06, (21966, 21))

# %%
path='/home/janati/Desktop/Meryem/IDS-Datasets/Datasets/cupid/Zeek/timeout60/Baselines/conn_logs/042219_1000_0_conn.log'


df60 = pd.read_csv(path, sep="\t", comment='#',
                         names=['ts', 'uid', 'id.orig_h', 'id.orig_p',
                                'id.resp_h', 'id.resp_p', 'proto', 'service',
                                'duration',  'orig_bytes', 'resp_bytes',
                                'conn_state', 'local_orig', 'local_resp',
                                'missed_bytes',  'history', 'orig_pkts',
                                'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes',
                                'tunnel_parents'])
df60 = pd.DataFrame(df60.values, columns=df60.columns)
df60['duration'].replace('-', np.nan, inplace=True)
df60['duration'] = df60['duration'].astype(float)

# %%
df60.head()
# Out:
#                   ts                 uid      id.orig_h id.orig_p  \
# 0  1555945272.145427  C4GXSw3vdeGY2kni27  192.168.1.105     61890
# 1  1555945273.474809  CQVD2c396mNPGiyG7d   192.168.1.50     61200
# 2  1555945276.079306   CfWV0M9yx7OeUR6Fh    192.168.1.7     49666
# 3  1555945279.876259   C91jJzb4pzEAK0bX7   192.168.1.11     64764
# 4   1555945280.13829  CqAhIf1vHtfCJeqNdb   192.168.1.11     64767
#
#      id.resp_h id.resp_p proto service  duration orig_bytes  ... conn_state  \
# 0  64.4.54.254       443   tcp       -  0.027222          0  ...         SF
# 1  64.4.54.253       443   tcp       -  0.000006          0  ...        OTH
# 2  192.168.1.9     30692   tcp       -  0.000011          0  ...         SF
# 3  192.168.1.7       389   tcp       -  0.042657       3291  ...       RSTR
# 4  192.168.1.7      3268   tcp       -  0.012241       3047  ...       RSTR
#
#   local_orig local_resp missed_bytes      history orig_pkts orig_ip_bytes  \
# 0          T          F            0          FfA         4           160
# 1          T          F            0            R         2            80
# 2          T          T            0         AfFa         4           160
# 3          T          T            1  ShADTdtaGrF        20          8096
# 4          T          T            0   ShADTdtaFr        26          7158
#
#   resp_pkts resp_ip_bytes tunnel_parents
# 0         2            80              -
# 1         0             0              -
# 2         4           160              -
# 3        20          8136              -
# 4        26          8770              -
#
# [5 rows x 21 columns]

# %%
df60["duration"].max(), df60["duration"].min() , df60.shape
# Out:
# (10975.544676, 3e-06, (16917, 21))

# %% [markdown]
# # By Argus

# %%
path='/home/janati/Desktop/Meryem/IDS-Datasets/Datasets/unsw/Argus/timeout1/features/1_features.csv'


df1 = pd.read_csv(path)

# %%
df1.head()
# Out:
#      SrcId  Rank        StartTime         LastTime  Trans        Flgs  Seq  \
# 0  0.0.0.0   NaN  05:34:41.011668  05:34:41.010902    NaN                0
# 1  0.0.0.0   1.0  00:23:27.658518  00:23:28.308420    1.0   * *          1
# 2  0.0.0.0   2.0  00:23:27.760103  00:23:29.383232    1.0   * *          2
# 3  0.0.0.0   3.0  00:23:27.801348  00:23:29.482990    1.0   * *          3
# 4  0.0.0.0   4.0  00:23:27.843340  00:23:27.964818    1.0   *            4
#
#         Dur   RunTime      IdleTime  ...  sVpri  dVpri  SRange  ERange  \
# 0  0.000766       NaN           NaN  ...    NaN    NaN     NaN     NaN
# 1  0.649902  0.649902  1.723092e+09  ...    NaN    NaN     NaN     NaN
# 2  1.623129  1.623129  1.723092e+09  ...    NaN    NaN     NaN     NaN
# 3  1.681642  1.681642  1.723092e+09  ...    NaN    NaN     NaN     NaN
# 4  0.121478  0.121478  1.723092e+09  ...    NaN    NaN     NaN     NaN
#
#      SrcTCPBase    DstTCPBase    TcpRtt    SynAck    AckDat TcpOpt
# 0           NaN           NaN  0.000000  0.000000  0.000000    NaN
# 1  1.417884e+09  3.077388e+09  0.000000  0.000000  0.000000    NaN
# 2  2.116151e+09  2.963115e+09  0.111897  0.061458  0.050439     Mw
# 3  1.107119e+09  1.047443e+09  0.000000  0.000000  0.000000    NaN
# 4  2.202534e+09  6.217727e+08  0.000000  0.000000  0.000000    NaN
#
# [5 rows x 109 columns]

# %%
df1["Dur"].min(), df1["Dur"].max(), df1.shape
# Out:
# (0.0, 5.003872, (46262, 109))

# %%
path='/home/janati/Desktop/Meryem/IDS-Datasets/Datasets/unsw/Argus/timeout5/features/1_features.csv'


df60 = pd.read_csv(path)

# %%
df60["Dur"].min(), df60["Dur"].max(), df60.shape
# Out:
# (0.0, 5.004087, (46262, 109))
