# %%
import sys
sys.path.append("../..")

# %%
from models.Fed import FedAvg
from models.Nets import MLP

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, f1_score
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor  
import warnings
import pickle
import os
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %%
cols = [ 'expiration_id', 'protocol', 'src_port', 'dst_port',
       'ip_version',   'bidirectional_duration_ms', 'bidirectional_packets',
       'bidirectional_bytes', 'src2dst_duration_ms', 'src2dst_packets',
       'src2dst_bytes', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes',
       'bidirectional_min_ps', 'bidirectional_mean_ps',
       'bidirectional_stddev_ps', 'bidirectional_max_ps',
       'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps',
       'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps',
       'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms',
       'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms',
       'bidirectional_max_piat_ms', 'src2dst_min_piat_ms',
       'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms',
       'src2dst_max_piat_ms', 'dst2src_min_piat_ms',
       'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms',
       'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_ack_packets',
       'bidirectional_psh_packets', 'bidirectional_rst_packets',
       'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_ack_packets',
       'src2dst_psh_packets', 'src2dst_rst_packets',
       'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_ack_packets',
       'dst2src_psh_packets', 'dst2src_rst_packets',
       'dst2src_fin_packets','application_name',
       'application_category_name', 'application_is_guessed',
       'application_confidence', 'content_type', 'udps.num_pkts_up_to_128_bytes',
       'udps.num_pkts_128_to_256_bytes', 'udps.num_pkts_256_to_512_bytes',
       'udps.num_pkts_512_to_1024_bytes',
       'udps.num_pkts_1024_to_1514_bytes', 'udps.min_ttl', 'udps.max_ttl',
       'udps.min_ip_pkt_len', 'udps.max_ip_pkt_len', 'udps.src2dst_flags',
       'udps.dst2src_flags', 'udps.tcp_flags', 'udps.tcp_win_max_in',
       'udps.tcp_win_max_out', 'udps.icmp_type', 'udps.icmp_v4_type',
       'udps.dns_query_id', 'udps.dns_query_type', 'udps.dns_ttl_answer',
       'udps.ftp_command_ret_code', 'udps.retransmitted_in_packets',
       'udps.retransmitted_out_packets', 'udps.retransmitted_in_bytes',
       'udps.retransmitted_out_bytes', 'udps.src_to_dst_second_bytes',
       'udps.dst_to_src_second_bytes', 'udps.src_to_dst_avg_throughput',
       'udps.dst_to_src_avg_throughput', 'udps.src_to_dst_second_bytes2',
       'udps.dst_to_src_second_bytes2', 'udps.src_to_dst_avg_throughput2',
       'udps.dst_to_src_avg_throughput2', 'udps.tcp_init_ms',
       'udps.tcp_synack_ack_ms', 'udps.tcp_half_closed_time_ms',
       'udps.num_pkts_after_termination',
       'udps.src2dst_first_packet_payload_len',
       'udps.dst2src_first_packet_payload_len',
       'udps.bidirectional_transport_bytes',
       'udps.bidirectional_payload_bytes', 'udps.src2dst_transport_bytes',
       'udps.src2dst_payload_bytes', 'udps.dst2src_transport_bytes',
       'udps.dst2src_payload_bytes',
       'udps.src2dst_most_freq_payload_ratio',
       'udps.src2dst_most_freq_payload_len',
       'udps.dst2src_most_freq_payload_ratio',
       'udps.dst2src_most_freq_payload_len',
       'udps.bidirectional_mean_packet_relative_times',
       'udps.bidirectional_stddev_packet_relative_times',
       'udps.bidirectional_variance_packet_relative_times',
       'udps.bidirectional_coeff_of_var_packet_relative_times',
       'udps.bidirectional_skew_from_median_packet_relative_times',
       'udps.src2dst_mean_packet_relative_times',
       'udps.src2dst_stddev_packet_relative_times',
       'udps.src2dst_variance_packet_relative_times',
       'udps.src2dst_coeff_of_var_packet_relative_times',
       'udps.src2dst_skew_from_median_packet_relative_times',
       'udps.dst2src_mean_packet_relative_times',
       'udps.dst2src_stddev_packet_relative_times',
       'udps.dst2src_variance_packet_relative_times',
       'udps.dst2src_coeff_of_var_packet_relative_times',
       'udps.dst2src_skew_from_median_packet_relative_times',
       'udps.min_req_res_time_diff', 'udps.max_req_res_time_diff',
       'udps.mean_req_res_time_diff', 'udps.stddev_req_res_time_diff',
       'udps.variance_req_res_time_diff',
       'udps.coeff_of_var_req_res_time_diff',
       'udps.skew_from_median_req_res_time_diff',
       'udps.src2dst_small_packet_payload_packets',
       'udps.src2dst_small_packet_payload_ratio',
       'udps.dst2src_small_packet_payload_packets',
       'udps.dst2src_small_packet_payload_ratio',
       'udps.sent_recv_packet_ratio',
       'udps.bidirectional_ps_first_quartile',
       'udps.bidirectional_ps_second_quartile',
       'udps.bidirectional_ps_third_quartile',
       'udps.bidirectional_ps_median_absoulte_deviation',
       'udps.bidirectional_ps_skewness', 'udps.bidirectional_ps_kurtosis',
       'udps.bidirectional_piat_first_quartile',
       'udps.bidirectional_piat_second_quartile',
       'udps.bidirectional_piat_third_quartile',
       'udps.bidirectional_piat_median_absoulte_deviation',
       'udps.bidirectional_piat_skewness',
       'udps.bidirectional_piat_kurtosis',
       'udps.median_req_res_time_diff', 'Attack']

# %%
def port_feature(port):
    if port < 1024:
        return 1
    elif port < 49152 and port >= 1024:
        return 2
    else:
        return 3

# %%
def encode(df, cols):
    """
    @param df pandas DataFrame
    @param cols a list of columns to encode 
    @return a DataFrame with one-hot encoding
    """
    les = {}
    for each in cols:
        le_col = LabelEncoder()
        df[each] = le_col.fit_transform(df[each])
        les[each] = le_col
       
    return df, les

# %%
def normalize_content_type(x):
    if str(x).isspace():
        return "unkown/unkown"
    elif "/" not in str(x):
        return str(x)+"/unkown"
    else:
        return x

# %%
def save_predictions(predictions, targets, timeout, save_path= "results/ET"):
    name_file_pred = 'predictions_idle_' + str(timeout[0]) + "_active_" + str(timeout[1]) + ".p"
    name_file_y = 'targets_idle_' + str(timeout[0]) + "_active_" + str(timeout[1]) + ".p"

    pickle.dump(predictions, open(os.path.join(save_path, name_file_pred), 'wb') )
    pickle.dump(targets, open(os.path.join(save_path, name_file_y), 'wb') )
    
def load_predictions(timeout, save_path= "results/ET"):
    name_file_pred = 'predictions_idle_' + str(timeout[0]) + "_active_" + str(timeout[1]) + ".p"
    name_file_y = 'targets_idle_' + str(timeout[0]) + "_active_" + str(timeout[1]) + ".p"
    
    predictions =  pickle.load(open(os.path.join(save_path, name_file_pred), 'rb') )
    targets =  pickle.load(open(os.path.join(save_path, name_file_y), 'rb') )
    return predictions, targets

# %%
timeouts = [(0.5,2), (1, 2), (2,2), (0.5,3), (1,3), (2, 3), (3,3), (0.5,4), (1, 4), (2,4), (3,4), (4,4), (0.5,5), (1,5), (2,5), (3,5), (4,5), (5,5), (0.5, 30), (1, 30), (2,30), (3,30), (4,30), (5,30), (10, 30), (0.5, 60), (1, 60), (2,60), (3,60), (4,60), (5,60), (10, 60)]

# %%
def split_data(data):
    train_idx, test_idx = next(StratifiedKFold(n_splits=3).split(data, data['Attack']))
    train, test = data.iloc[train_idx].reset_index(drop=True), data.iloc[test_idx].reset_index(drop=True)
    return train, test

# %%
from configs.net_config import MLPConfig
import torch

config = MLPConfig()

# %%
gpu = 1
config.device = torch.device('cuda:{}'.format(gpu) if torch.cuda.is_available() and gpu != -1 else 'cpu')
seed=config.seed
iid=config.iid
config.dataset= "cic17"
all_clients = config.all_clients
config.epochs=10
config.local_ep=5
print("Dataset: {}, Model: {}, IID: {}, Data Type : {}, Device : {} ".format(config.dataset, config.model, iid, config.data_type, config.device))
# Out:
# Dataset: cic17, Model: MLP, IID: True, Data Type : tabular, Device : cuda:1

# %%
# build model
classes = ['Benign', 'Botnet', 'DDoS', 'DoS GoldenEye', 'DoS Hulk', 'DoS Slowhttptest', 'DoS Slowloris', 'FTP-Patator', 'Infiltration', 'Infiltration - Portscan',
 'Portscan', 'SSH-Patator', 'Web Attack - Brute Force', 'Web Attack - SQL Injection', 'Web Attack - XSS']

if config.model == 'MLP' and config.dataset == 'cic17' and config.data_type == "tabular":
    net_glob = MLP(num_features=57, hidden1_size=32, hidden2_size=16, num_classes=len(classes)).to(config.device) 
else:
    exit('Error: unrecognized model')
print(net_glob)
# Out:
# MLP(
#   (fc1): Linear(in_features=57, out_features=32, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=32, out_features=16, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=16, out_features=15, bias=True)
# )

# %%
from models.Update import LocalUpdate
import copy

preprocessing=False
if preprocessing:
    for timeout in timeouts:
        print("Processing timeout : ", timeout)
        idle, active = timeout
        out_dir = f'/home/meryem.janati/lustre/nlp_team-um6p-st-sccs-id7fz1zvotk/IDS/janati/IDS/project2/extractions/extractions/new_idle_{idle}min_active_{active}min/CIC-IDS-2017'
        df = pd.read_csv(out_dir+"/CIC-IDS-2017.csv")

        df = df[(~df.Attack.str.contains('Attempted')) & (~df.Attack.str.contains('Heartbleed')) ]
        df = df.sort_values(by=['bidirectional_last_seen_ms']).reset_index(drop=True)
        df_new = df[cols]
        df_new['application_name'] = df_new['application_name'].apply(lambda x: x.split(".")[0])
        df_new['content_type'] = df_new['content_type'].fillna("unkown/unkown")
        df_new['content_type'] = df_new['content_type'].apply(lambda x: normalize_content_type(x))
        df_new['content_sub_type'] = df_new['content_type'].apply(lambda x: x.split("/")[1])
        df_new['content_type'] = df_new['content_type'].apply(lambda x: x.split("/")[0])
        # df_new['src_port'] = df_new['src_port'].apply(lambda x: port_feature(x))
        # df_new['dst_port'] = df_new['dst_port'].apply(lambda x: port_feature(x))
        df_new = df_new.fillna(0)
        categ_cols = ["application_name", "application_category_name", "content_sub_type", "content_type" ]
        df_new, lbl_encoders = encode(df_new,categ_cols)    
        train, test = split_data(df_new)
        y_train = train['Attack']
        X_train = train.drop('Attack', axis=1)
        y_test = test['Attack']
        X_test = test.drop('Attack', axis=1)
        le = LabelEncoder()
        y_train = le.fit_transform(y_train)
        y_test = le.transform(y_test)
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        print("Saving data for timeout: ", timeout)
        np.save(os.path.join('../../data/CIC-IDS2017/baselineFeatures/X_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), X_train)
        np.save(os.path.join('../../data/CIC-IDS2017/baselineFeatures/y_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), y_train)
        np.save(os.path.join('../../data/CIC-IDS2017/baselineFeatures/X_test_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), X_test)
        np.save(os.path.join('../../data/CIC-IDS2017/baselineFeatures/y_test_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), y_test)

# %%
from models.Update import LocalUpdate
import copy

def FL_training():
    #net_glob = MLP(dim_in=46, dim_hidden=32, dim_out=le.classes_).to(config.device) 
    net_glob.train()
    # copy weights
    w_glob = net_glob.state_dict()
    print("Training ... ")
    net_loss_train = []


    if config.all_clients: 
        print("Aggregation over all clients")
        w_net_locals = [w_glob for i in range(config.num_users)]

    for iter in range(config.epochs):
        net_loss_locals = []
        X_train, y_train = None, None
        if not config.all_clients:
            w_net_locals = []
        m = max(int(config.frac * config.num_users), 1)
        idxs_timeouts = np.random.choice(range(config.num_users), m, replace=False)
        for idx in idxs_timeouts:
            timeout = timeouts[idx]
            X_train = np.load(os.path.join('../../data/CIC-IDS2017/baselineFeatures/X_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
            y_train = np.load(os.path.join('../../data/CIC-IDS2017/baselineFeatures/y_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
            
            local = LocalUpdate(config=config, x_train=X_train, y_train=y_train)
            w_net, net_loss = local.train_net(net=copy.deepcopy(net_glob).to(config.device), timeout=timeout)

            w_net = w_net.state_dict()
            if config.all_clients:
                w_net_locals[idx] = copy.deepcopy(w_net)
            else:
                w_net_locals.append(copy.deepcopy(w_net))

            net_loss_locals.append(copy.deepcopy(net_loss))
        # update global weights
        w_glob = FedAvg(w_net_locals)

        # copy weight to net_glob
        net_glob.load_state_dict(w_glob)

        # print loss
        net_loss_avg = sum(net_loss_locals) / len(net_loss_locals)
        print('Round {:3d}, Average MLP loss {:.3f}'.format(iter, net_loss_avg))
        net_loss_train.append(net_loss_avg)

    #save_model(config.local_ep, net_glob, filepath) 
FL_training()
# Out:
# Training ...
# Timeout : (0.5, 60) 	Local Epoch : 0 	Loss: 0.039267
# Timeout : (0.5, 60) 	Local Epoch : 1 	Loss: 0.012373
# Timeout : (0.5, 60) 	Local Epoch : 2 	Loss: 0.011404
# Timeout : (0.5, 60) 	Local Epoch : 3 	Loss: 0.010833
# Timeout : (0.5, 60) 	Local Epoch : 4 	Loss: 0.010576
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.042489
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.012860
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.011754
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.011268
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.011014
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.041365
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.012987
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.011938
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.011350
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.011034
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.043820
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.013440
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.012134
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.012035
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.011331
# Timeout : (2, 60) 	Local Epoch : 0 	Loss: 0.043128
# Timeout : (2, 60) 	Local Epoch : 1 	Loss: 0.013063
# Timeout : (2, 60) 	Local Epoch : 2 	Loss: 0.012030
# Timeout : (2, 60) 	Local Epoch : 3 	Loss: 0.011431
# Timeout : (2, 60) 	Local Epoch : 4 	Loss: 0.011183
# Timeout : (5, 30) 	Local Epoch : 0 	Loss: 0.048813
# Timeout : (5, 30) 	Local Epoch : 1 	Loss: 0.016012
# Timeout : (5, 30) 	Local Epoch : 2 	Loss: 0.014134
# Timeout : (5, 30) 	Local Epoch : 3 	Loss: 0.012613
# Timeout : (5, 30) 	Local Epoch : 4 	Loss: 0.012493
# Timeout : (5, 60) 	Local Epoch : 0 	Loss: 0.046971
# Timeout : (5, 60) 	Local Epoch : 1 	Loss: 0.015503
# Timeout : (5, 60) 	Local Epoch : 2 	Loss: 0.014147
# Timeout : (5, 60) 	Local Epoch : 3 	Loss: 0.012476
# Timeout : (5, 60) 	Local Epoch : 4 	Loss: 0.011932
# Timeout : (4, 60) 	Local Epoch : 0 	Loss: 0.050180
# Timeout : (4, 60) 	Local Epoch : 1 	Loss: 0.017654
# Timeout : (4, 60) 	Local Epoch : 2 	Loss: 0.015258
# Timeout : (4, 60) 	Local Epoch : 3 	Loss: 0.013534
# Timeout : (4, 60) 	Local Epoch : 4 	Loss: 0.012452
# Timeout : (1, 60) 	Local Epoch : 0 	Loss: 0.042462
# Timeout : (1, 60) 	Local Epoch : 1 	Loss: 0.013067
# Timeout : (1, 60) 	Local Epoch : 2 	Loss: 0.011990
# Timeout : (1, 60) 	Local Epoch : 3 	Loss: 0.011532
# Timeout : (1, 60) 	Local Epoch : 4 	Loss: 0.011184
# Timeout : (0.5, 3) 	Local Epoch : 0 	Loss: 0.039443
# Timeout : (0.5, 3) 	Local Epoch : 1 	Loss: 0.012337
# Timeout : (0.5, 3) 	Local Epoch : 2 	Loss: 0.011304
# Timeout : (0.5, 3) 	Local Epoch : 3 	Loss: 0.010892
# Timeout : (0.5, 3) 	Local Epoch : 4 	Loss: 0.010614
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.041921
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.013066
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.011968
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.011330
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.011128
# Timeout : (3, 30) 	Local Epoch : 0 	Loss: 0.043134
# Timeout : (3, 30) 	Local Epoch : 1 	Loss: 0.012803
# Timeout : (3, 30) 	Local Epoch : 2 	Loss: 0.011825
# Timeout : (3, 30) 	Local Epoch : 3 	Loss: 0.011409
# Timeout : (3, 30) 	Local Epoch : 4 	Loss: 0.011267
# Timeout : (2, 2) 	Local Epoch : 0 	Loss: 0.042194
# Timeout : (2, 2) 	Local Epoch : 1 	Loss: 0.012696
# Timeout : (2, 2) 	Local Epoch : 2 	Loss: 0.011682
# Timeout : (2, 2) 	Local Epoch : 3 	Loss: 0.011179
# Timeout : (2, 2) 	Local Epoch : 4 	Loss: 0.010911
# Timeout : (1, 3) 	Local Epoch : 0 	Loss: 0.041433
# Timeout : (1, 3) 	Local Epoch : 1 	Loss: 0.012659
# Timeout : (1, 3) 	Local Epoch : 2 	Loss: 0.011721
# Timeout : (1, 3) 	Local Epoch : 3 	Loss: 0.011123
# Timeout : (1, 3) 	Local Epoch : 4 	Loss: 0.010845
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.042367
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.013011
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.011946
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.011448
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.011099
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.042055
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.013376
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.012117
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.011483
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.011116
# Round   0, Average MLP loss 0.018
# Timeout : (4, 30) 	Local Epoch : 0 	Loss: 0.023437
# Timeout : (4, 30) 	Local Epoch : 1 	Loss: 0.018743
# Timeout : (4, 30) 	Local Epoch : 2 	Loss: 0.017481
# Timeout : (4, 30) 	Local Epoch : 3 	Loss: 0.015018
# Timeout : (4, 30) 	Local Epoch : 4 	Loss: 0.013723
# Timeout : (5, 60) 	Local Epoch : 0 	Loss: 0.024761
# Timeout : (5, 60) 	Local Epoch : 1 	Loss: 0.020703
# Timeout : (5, 60) 	Local Epoch : 2 	Loss: 0.016925
# Timeout : (5, 60) 	Local Epoch : 3 	Loss: 0.014562
# Timeout : (5, 60) 	Local Epoch : 4 	Loss: 0.012567
# Timeout : (0.5, 60) 	Local Epoch : 0 	Loss: 0.013148
# Timeout : (0.5, 60) 	Local Epoch : 1 	Loss: 0.010967
# Timeout : (0.5, 60) 	Local Epoch : 2 	Loss: 0.010572
# Timeout : (0.5, 60) 	Local Epoch : 3 	Loss: 0.010325
# Timeout : (0.5, 60) 	Local Epoch : 4 	Loss: 0.010204
# Timeout : (4, 5) 	Local Epoch : 0 	Loss: 0.015202
# Timeout : (4, 5) 	Local Epoch : 1 	Loss: 0.013164
# Timeout : (4, 5) 	Local Epoch : 2 	Loss: 0.012336
# Timeout : (4, 5) 	Local Epoch : 3 	Loss: 0.011972
# Timeout : (4, 5) 	Local Epoch : 4 	Loss: 0.011712
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.013278
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.011449
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.011067
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.010839
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.010897
# Timeout : (4, 60) 	Local Epoch : 0 	Loss: 0.025499
# Timeout : (4, 60) 	Local Epoch : 1 	Loss: 0.020733
# Timeout : (4, 60) 	Local Epoch : 2 	Loss: 0.017537
# Timeout : (4, 60) 	Local Epoch : 3 	Loss: 0.015891
# Timeout : (4, 60) 	Local Epoch : 4 	Loss: 0.013815
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.013423
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.011435
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.011001
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.010873
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.010699
# Timeout : (10, 30) 	Local Epoch : 0 	Loss: 0.030285
# Timeout : (10, 30) 	Local Epoch : 1 	Loss: 0.023769
# Timeout : (10, 30) 	Local Epoch : 2 	Loss: 0.022355
# Timeout : (10, 30) 	Local Epoch : 3 	Loss: 0.018786
# Timeout : (10, 30) 	Local Epoch : 4 	Loss: 0.016054
# Timeout : (1, 2) 	Local Epoch : 0 	Loss: 0.013241
# Timeout : (1, 2) 	Local Epoch : 1 	Loss: 0.011223
# Timeout : (1, 2) 	Local Epoch : 2 	Loss: 0.010829
# Timeout : (1, 2) 	Local Epoch : 3 	Loss: 0.010668
# Timeout : (1, 2) 	Local Epoch : 4 	Loss: 0.010470
# Timeout : (10, 60) 	Local Epoch : 0 	Loss: 0.030750
# Timeout : (10, 60) 	Local Epoch : 1 	Loss: 0.024104
# Timeout : (10, 60) 	Local Epoch : 2 	Loss: 0.021194
# Timeout : (10, 60) 	Local Epoch : 3 	Loss: 0.018469
# Timeout : (10, 60) 	Local Epoch : 4 	Loss: 0.015386
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.013523
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.011373
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.011114
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.010852
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.010723
# Timeout : (1, 30) 	Local Epoch : 0 	Loss: 0.013631
# Timeout : (1, 30) 	Local Epoch : 1 	Loss: 0.011436
# Timeout : (1, 30) 	Local Epoch : 2 	Loss: 0.011145
# Timeout : (1, 30) 	Local Epoch : 3 	Loss: 0.010926
# Timeout : (1, 30) 	Local Epoch : 4 	Loss: 0.010819
# Timeout : (3, 3) 	Local Epoch : 0 	Loss: 0.013235
# Timeout : (3, 3) 	Local Epoch : 1 	Loss: 0.011377
# Timeout : (3, 3) 	Local Epoch : 2 	Loss: 0.011048
# Timeout : (3, 3) 	Local Epoch : 3 	Loss: 0.010793
# Timeout : (3, 3) 	Local Epoch : 4 	Loss: 0.010661
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.013254
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.011020
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.010538
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.010404
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.010263
# Timeout : (2, 60) 	Local Epoch : 0 	Loss: 0.013363
# Timeout : (2, 60) 	Local Epoch : 1 	Loss: 0.011514
# Timeout : (2, 60) 	Local Epoch : 2 	Loss: 0.011155
# Timeout : (2, 60) 	Local Epoch : 3 	Loss: 0.011048
# Timeout : (2, 60) 	Local Epoch : 4 	Loss: 0.010875
# Timeout : (1, 3) 	Local Epoch : 0 	Loss: 0.013372
# Timeout : (1, 3) 	Local Epoch : 1 	Loss: 0.011341
# Timeout : (1, 3) 	Local Epoch : 2 	Loss: 0.010972
# Timeout : (1, 3) 	Local Epoch : 3 	Loss: 0.010741
# Timeout : (1, 3) 	Local Epoch : 4 	Loss: 0.010678
# Round   1, Average MLP loss 0.014
# Timeout : (0.5, 3) 	Local Epoch : 0 	Loss: 0.011153
# Timeout : (0.5, 3) 	Local Epoch : 1 	Loss: 0.010330
# Timeout : (0.5, 3) 	Local Epoch : 2 	Loss: 0.010179
# Timeout : (0.5, 3) 	Local Epoch : 3 	Loss: 0.010044
# Timeout : (0.5, 3) 	Local Epoch : 4 	Loss: 0.009895
# Timeout : (4, 30) 	Local Epoch : 0 	Loss: 0.022483
# Timeout : (4, 30) 	Local Epoch : 1 	Loss: 0.018797
# Timeout : (4, 30) 	Local Epoch : 2 	Loss: 0.015727
# Timeout : (4, 30) 	Local Epoch : 3 	Loss: 0.016269
# Timeout : (4, 30) 	Local Epoch : 4 	Loss: 0.013489
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.011111
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.010642
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.010560
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.010448
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.010398
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.011281
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.010786
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.010602
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.010499
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.010419
# Timeout : (1, 2) 	Local Epoch : 0 	Loss: 0.011117
# Timeout : (1, 2) 	Local Epoch : 1 	Loss: 0.010618
# Timeout : (1, 2) 	Local Epoch : 2 	Loss: 0.010440
# Timeout : (1, 2) 	Local Epoch : 3 	Loss: 0.010325
# Timeout : (1, 2) 	Local Epoch : 4 	Loss: 0.010188
# Timeout : (1, 60) 	Local Epoch : 0 	Loss: 0.011291
# Timeout : (1, 60) 	Local Epoch : 1 	Loss: 0.010899
# Timeout : (1, 60) 	Local Epoch : 2 	Loss: 0.010665
# Timeout : (1, 60) 	Local Epoch : 3 	Loss: 0.010581
# Timeout : (1, 60) 	Local Epoch : 4 	Loss: 0.010448
# Timeout : (10, 30) 	Local Epoch : 0 	Loss: 0.026656
# Timeout : (10, 30) 	Local Epoch : 1 	Loss: 0.021785
# Timeout : (10, 30) 	Local Epoch : 2 	Loss: 0.020382
# Timeout : (10, 30) 	Local Epoch : 3 	Loss: 0.018240
# Timeout : (10, 30) 	Local Epoch : 4 	Loss: 0.016326
# Timeout : (3, 30) 	Local Epoch : 0 	Loss: 0.011553
# Timeout : (3, 30) 	Local Epoch : 1 	Loss: 0.011045
# Timeout : (3, 30) 	Local Epoch : 2 	Loss: 0.010915
# Timeout : (3, 30) 	Local Epoch : 3 	Loss: 0.010770
# Timeout : (3, 30) 	Local Epoch : 4 	Loss: 0.010566
# Timeout : (5, 30) 	Local Epoch : 0 	Loss: 0.022706
# Timeout : (5, 30) 	Local Epoch : 1 	Loss: 0.019091
# Timeout : (5, 30) 	Local Epoch : 2 	Loss: 0.016694
# Timeout : (5, 30) 	Local Epoch : 3 	Loss: 0.014880
# Timeout : (5, 30) 	Local Epoch : 4 	Loss: 0.013611
# Timeout : (4, 5) 	Local Epoch : 0 	Loss: 0.013586
# Timeout : (4, 5) 	Local Epoch : 1 	Loss: 0.012637
# Timeout : (4, 5) 	Local Epoch : 2 	Loss: 0.012280
# Timeout : (4, 5) 	Local Epoch : 3 	Loss: 0.012133
# Timeout : (4, 5) 	Local Epoch : 4 	Loss: 0.011783
# Timeout : (1, 30) 	Local Epoch : 0 	Loss: 0.011288
# Timeout : (1, 30) 	Local Epoch : 1 	Loss: 0.010808
# Timeout : (1, 30) 	Local Epoch : 2 	Loss: 0.010740
# Timeout : (1, 30) 	Local Epoch : 3 	Loss: 0.010517
# Timeout : (1, 30) 	Local Epoch : 4 	Loss: 0.010425
# Timeout : (3, 3) 	Local Epoch : 0 	Loss: 0.011213
# Timeout : (3, 3) 	Local Epoch : 1 	Loss: 0.010784
# Timeout : (3, 3) 	Local Epoch : 2 	Loss: 0.010650
# Timeout : (3, 3) 	Local Epoch : 3 	Loss: 0.010570
# Timeout : (3, 3) 	Local Epoch : 4 	Loss: 0.010454
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.011332
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.010850
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.010697
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.010688
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.010659
# Timeout : (5, 60) 	Local Epoch : 0 	Loss: 0.023324
# Timeout : (5, 60) 	Local Epoch : 1 	Loss: 0.019310
# Timeout : (5, 60) 	Local Epoch : 2 	Loss: 0.017515
# Timeout : (5, 60) 	Local Epoch : 3 	Loss: 0.014527
# Timeout : (5, 60) 	Local Epoch : 4 	Loss: 0.013310
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.011563
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.011093
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.010881
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.010909
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.010563
# Timeout : (0.5, 2) 	Local Epoch : 0 	Loss: 0.011045
# Timeout : (0.5, 2) 	Local Epoch : 1 	Loss: 0.010364
# Timeout : (0.5, 2) 	Local Epoch : 2 	Loss: 0.010105
# Timeout : (0.5, 2) 	Local Epoch : 3 	Loss: 0.009982
# Timeout : (0.5, 2) 	Local Epoch : 4 	Loss: 0.009932
# Round   2, Average MLP loss 0.013
# Timeout : (4, 4) 	Local Epoch : 0 	Loss: 0.012481
# Timeout : (4, 4) 	Local Epoch : 1 	Loss: 0.012158
# Timeout : (4, 4) 	Local Epoch : 2 	Loss: 0.011602
# Timeout : (4, 4) 	Local Epoch : 3 	Loss: 0.011741
# Timeout : (4, 4) 	Local Epoch : 4 	Loss: 0.011431
# Timeout : (3, 30) 	Local Epoch : 0 	Loss: 0.011332
# Timeout : (3, 30) 	Local Epoch : 1 	Loss: 0.010796
# Timeout : (3, 30) 	Local Epoch : 2 	Loss: 0.010630
# Timeout : (3, 30) 	Local Epoch : 3 	Loss: 0.010477
# Timeout : (3, 30) 	Local Epoch : 4 	Loss: 0.010624
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.010863
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.010646
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.010562
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.010553
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.010482
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.010885
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.010564
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.010424
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.010211
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.010225
# Timeout : (4, 5) 	Local Epoch : 0 	Loss: 0.012925
# Timeout : (4, 5) 	Local Epoch : 1 	Loss: 0.012377
# Timeout : (4, 5) 	Local Epoch : 2 	Loss: 0.011923
# Timeout : (4, 5) 	Local Epoch : 3 	Loss: 0.011658
# Timeout : (4, 5) 	Local Epoch : 4 	Loss: 0.011449
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.010910
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.010545
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.010414
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.010330
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.010259
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.011212
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.010754
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.010571
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.010480
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.010433
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.010737
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.010137
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.010066
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.009896
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.009809
# Timeout : (0.5, 3) 	Local Epoch : 0 	Loss: 0.010657
# Timeout : (0.5, 3) 	Local Epoch : 1 	Loss: 0.010111
# Timeout : (0.5, 3) 	Local Epoch : 2 	Loss: 0.010074
# Timeout : (0.5, 3) 	Local Epoch : 3 	Loss: 0.009894
# Timeout : (0.5, 3) 	Local Epoch : 4 	Loss: 0.009847
# Timeout : (5, 5) 	Local Epoch : 0 	Loss: 0.012670
# Timeout : (5, 5) 	Local Epoch : 1 	Loss: 0.012330
# Timeout : (5, 5) 	Local Epoch : 2 	Loss: 0.011892
# Timeout : (5, 5) 	Local Epoch : 3 	Loss: 0.011812
# Timeout : (5, 5) 	Local Epoch : 4 	Loss: 0.011453
# Timeout : (1, 30) 	Local Epoch : 0 	Loss: 0.010922
# Timeout : (1, 30) 	Local Epoch : 1 	Loss: 0.010533
# Timeout : (1, 30) 	Local Epoch : 2 	Loss: 0.010443
# Timeout : (1, 30) 	Local Epoch : 3 	Loss: 0.010261
# Timeout : (1, 30) 	Local Epoch : 4 	Loss: 0.010271
# Timeout : (5, 30) 	Local Epoch : 0 	Loss: 0.022147
# Timeout : (5, 30) 	Local Epoch : 1 	Loss: 0.018697
# Timeout : (5, 30) 	Local Epoch : 2 	Loss: 0.015649
# Timeout : (5, 30) 	Local Epoch : 3 	Loss: 0.014279
# Timeout : (5, 30) 	Local Epoch : 4 	Loss: 0.014097
# Timeout : (3, 3) 	Local Epoch : 0 	Loss: 0.010736
# Timeout : (3, 3) 	Local Epoch : 1 	Loss: 0.010553
# Timeout : (3, 3) 	Local Epoch : 2 	Loss: 0.010408
# Timeout : (3, 3) 	Local Epoch : 3 	Loss: 0.010483
# Timeout : (3, 3) 	Local Epoch : 4 	Loss: 0.010338
# Timeout : (4, 60) 	Local Epoch : 0 	Loss: 0.020435
# Timeout : (4, 60) 	Local Epoch : 1 	Loss: 0.017664
# Timeout : (4, 60) 	Local Epoch : 2 	Loss: 0.015335
# Timeout : (4, 60) 	Local Epoch : 3 	Loss: 0.014016
# Timeout : (4, 60) 	Local Epoch : 4 	Loss: 0.012478
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.010862
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.010736
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.010452
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.010469
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.010462
# Timeout : (10, 60) 	Local Epoch : 0 	Loss: 0.023812
# Timeout : (10, 60) 	Local Epoch : 1 	Loss: 0.020051
# Timeout : (10, 60) 	Local Epoch : 2 	Loss: 0.017618
# Timeout : (10, 60) 	Local Epoch : 3 	Loss: 0.014542
# Timeout : (10, 60) 	Local Epoch : 4 	Loss: 0.014338
# Round   3, Average MLP loss 0.012
# Timeout : (1, 3) 	Local Epoch : 0 	Loss: 0.010576
# Timeout : (1, 3) 	Local Epoch : 1 	Loss: 0.010191
# Timeout : (1, 3) 	Local Epoch : 2 	Loss: 0.010117
# Timeout : (1, 3) 	Local Epoch : 3 	Loss: 0.010035
# Timeout : (1, 3) 	Local Epoch : 4 	Loss: 0.009918
# Timeout : (3, 4) 	Local Epoch : 0 	Loss: 0.010654
# Timeout : (3, 4) 	Local Epoch : 1 	Loss: 0.010595
# Timeout : (3, 4) 	Local Epoch : 2 	Loss: 0.010483
# Timeout : (3, 4) 	Local Epoch : 3 	Loss: 0.010502
# Timeout : (3, 4) 	Local Epoch : 4 	Loss: 0.010551
# Timeout : (4, 30) 	Local Epoch : 0 	Loss: 0.018256
# Timeout : (4, 30) 	Local Epoch : 1 	Loss: 0.015795
# Timeout : (4, 30) 	Local Epoch : 2 	Loss: 0.014246
# Timeout : (4, 30) 	Local Epoch : 3 	Loss: 0.012009
# Timeout : (4, 30) 	Local Epoch : 4 	Loss: 0.012702
# Timeout : (1, 2) 	Local Epoch : 0 	Loss: 0.010557
# Timeout : (1, 2) 	Local Epoch : 1 	Loss: 0.010228
# Timeout : (1, 2) 	Local Epoch : 2 	Loss: 0.010062
# Timeout : (1, 2) 	Local Epoch : 3 	Loss: 0.010004
# Timeout : (1, 2) 	Local Epoch : 4 	Loss: 0.009894
# Timeout : (5, 60) 	Local Epoch : 0 	Loss: 0.019242
# Timeout : (5, 60) 	Local Epoch : 1 	Loss: 0.016566
# Timeout : (5, 60) 	Local Epoch : 2 	Loss: 0.014840
# Timeout : (5, 60) 	Local Epoch : 3 	Loss: 0.013086
# Timeout : (5, 60) 	Local Epoch : 4 	Loss: 0.012648
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.010820
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.010520
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.010472
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.010434
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.010375
# Timeout : (2, 2) 	Local Epoch : 0 	Loss: 0.010440
# Timeout : (2, 2) 	Local Epoch : 1 	Loss: 0.010231
# Timeout : (2, 2) 	Local Epoch : 2 	Loss: 0.010123
# Timeout : (2, 2) 	Local Epoch : 3 	Loss: 0.010070
# Timeout : (2, 2) 	Local Epoch : 4 	Loss: 0.010017
# Timeout : (5, 30) 	Local Epoch : 0 	Loss: 0.019275
# Timeout : (5, 30) 	Local Epoch : 1 	Loss: 0.016457
# Timeout : (5, 30) 	Local Epoch : 2 	Loss: 0.014543
# Timeout : (5, 30) 	Local Epoch : 3 	Loss: 0.013187
# Timeout : (5, 30) 	Local Epoch : 4 	Loss: 0.011669
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.011356
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.010797
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.010456
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.010384
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.010593
# Timeout : (0.5, 3) 	Local Epoch : 0 	Loss: 0.010573
# Timeout : (0.5, 3) 	Local Epoch : 1 	Loss: 0.009966
# Timeout : (0.5, 3) 	Local Epoch : 2 	Loss: 0.009852
# Timeout : (0.5, 3) 	Local Epoch : 3 	Loss: 0.009719
# Timeout : (0.5, 3) 	Local Epoch : 4 	Loss: 0.009683
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.011059
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.010670
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.010571
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.010383
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.010366
# Timeout : (1, 60) 	Local Epoch : 0 	Loss: 0.010835
# Timeout : (1, 60) 	Local Epoch : 1 	Loss: 0.010394
# Timeout : (1, 60) 	Local Epoch : 2 	Loss: 0.010288
# Timeout : (1, 60) 	Local Epoch : 3 	Loss: 0.010159
# Timeout : (1, 60) 	Local Epoch : 4 	Loss: 0.010125
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.010545
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.010015
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.009916
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.009874
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.009733
# Timeout : (2, 4) 	Local Epoch : 0 	Loss: 0.010555
# Timeout : (2, 4) 	Local Epoch : 1 	Loss: 0.010434
# Timeout : (2, 4) 	Local Epoch : 2 	Loss: 0.010362
# Timeout : (2, 4) 	Local Epoch : 3 	Loss: 0.010359
# Timeout : (2, 4) 	Local Epoch : 4 	Loss: 0.010285
# Timeout : (4, 60) 	Local Epoch : 0 	Loss: 0.017868
# Timeout : (4, 60) 	Local Epoch : 1 	Loss: 0.016586
# Timeout : (4, 60) 	Local Epoch : 2 	Loss: 0.014572
# Timeout : (4, 60) 	Local Epoch : 3 	Loss: 0.012548
# Timeout : (4, 60) 	Local Epoch : 4 	Loss: 0.012023
# Timeout : (3, 30) 	Local Epoch : 0 	Loss: 0.011199
# Timeout : (3, 30) 	Local Epoch : 1 	Loss: 0.010667
# Timeout : (3, 30) 	Local Epoch : 2 	Loss: 0.010392
# Timeout : (3, 30) 	Local Epoch : 3 	Loss: 0.010439
# Timeout : (3, 30) 	Local Epoch : 4 	Loss: 0.010382
# Round   4, Average MLP loss 0.011
# Timeout : (4, 4) 	Local Epoch : 0 	Loss: 0.011655
# Timeout : (4, 4) 	Local Epoch : 1 	Loss: 0.011479
# Timeout : (4, 4) 	Local Epoch : 2 	Loss: 0.011469
# Timeout : (4, 4) 	Local Epoch : 3 	Loss: 0.011081
# Timeout : (4, 4) 	Local Epoch : 4 	Loss: 0.011021
# Timeout : (3, 3) 	Local Epoch : 0 	Loss: 0.010558
# Timeout : (3, 3) 	Local Epoch : 1 	Loss: 0.010311
# Timeout : (3, 3) 	Local Epoch : 2 	Loss: 0.010307
# Timeout : (3, 3) 	Local Epoch : 3 	Loss: 0.010193
# Timeout : (3, 3) 	Local Epoch : 4 	Loss: 0.010244
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.010715
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.010580
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.010314
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.010505
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.010375
# Timeout : (4, 30) 	Local Epoch : 0 	Loss: 0.017776
# Timeout : (4, 30) 	Local Epoch : 1 	Loss: 0.015457
# Timeout : (4, 30) 	Local Epoch : 2 	Loss: 0.013569
# Timeout : (4, 30) 	Local Epoch : 3 	Loss: 0.012438
# Timeout : (4, 30) 	Local Epoch : 4 	Loss: 0.011872
# Timeout : (4, 60) 	Local Epoch : 0 	Loss: 0.017422
# Timeout : (4, 60) 	Local Epoch : 1 	Loss: 0.015767
# Timeout : (4, 60) 	Local Epoch : 2 	Loss: 0.013472
# Timeout : (4, 60) 	Local Epoch : 3 	Loss: 0.012405
# Timeout : (4, 60) 	Local Epoch : 4 	Loss: 0.011361
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.011270
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.010688
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.010391
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.010592
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.010488
# Timeout : (2, 4) 	Local Epoch : 0 	Loss: 0.010467
# Timeout : (2, 4) 	Local Epoch : 1 	Loss: 0.010375
# Timeout : (2, 4) 	Local Epoch : 2 	Loss: 0.010325
# Timeout : (2, 4) 	Local Epoch : 3 	Loss: 0.010297
# Timeout : (2, 4) 	Local Epoch : 4 	Loss: 0.010266
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.010596
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.010447
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.010400
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.010399
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.010407
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.010644
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.010270
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.010164
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.010131
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.010061
# Timeout : (5, 5) 	Local Epoch : 0 	Loss: 0.012140
# Timeout : (5, 5) 	Local Epoch : 1 	Loss: 0.011644
# Timeout : (5, 5) 	Local Epoch : 2 	Loss: 0.011487
# Timeout : (5, 5) 	Local Epoch : 3 	Loss: 0.011247
# Timeout : (5, 5) 	Local Epoch : 4 	Loss: 0.011373
# Timeout : (5, 30) 	Local Epoch : 0 	Loss: 0.018022
# Timeout : (5, 30) 	Local Epoch : 1 	Loss: 0.015700
# Timeout : (5, 30) 	Local Epoch : 2 	Loss: 0.014287
# Timeout : (5, 30) 	Local Epoch : 3 	Loss: 0.013012
# Timeout : (5, 30) 	Local Epoch : 4 	Loss: 0.011404
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.010413
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.009861
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.009708
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.009633
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.009555
# Timeout : (0.5, 3) 	Local Epoch : 0 	Loss: 0.010370
# Timeout : (0.5, 3) 	Local Epoch : 1 	Loss: 0.009867
# Timeout : (0.5, 3) 	Local Epoch : 2 	Loss: 0.009676
# Timeout : (0.5, 3) 	Local Epoch : 3 	Loss: 0.009646
# Timeout : (0.5, 3) 	Local Epoch : 4 	Loss: 0.009523
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.010416
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.010248
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.010202
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.010110
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.010082
# Timeout : (5, 60) 	Local Epoch : 0 	Loss: 0.017434
# Timeout : (5, 60) 	Local Epoch : 1 	Loss: 0.015900
# Timeout : (5, 60) 	Local Epoch : 2 	Loss: 0.013530
# Timeout : (5, 60) 	Local Epoch : 3 	Loss: 0.012873
# Timeout : (5, 60) 	Local Epoch : 4 	Loss: 0.012399
# Timeout : (0.5, 5) 	Local Epoch : 0 	Loss: 0.010374
# Timeout : (0.5, 5) 	Local Epoch : 1 	Loss: 0.009889
# Timeout : (0.5, 5) 	Local Epoch : 2 	Loss: 0.009754
# Timeout : (0.5, 5) 	Local Epoch : 3 	Loss: 0.009647
# Timeout : (0.5, 5) 	Local Epoch : 4 	Loss: 0.009590
# Round   5, Average MLP loss 0.011
# Timeout : (10, 60) 	Local Epoch : 0 	Loss: 0.019212
# Timeout : (10, 60) 	Local Epoch : 1 	Loss: 0.016528
# Timeout : (10, 60) 	Local Epoch : 2 	Loss: 0.014944
# Timeout : (10, 60) 	Local Epoch : 3 	Loss: 0.013845
# Timeout : (10, 60) 	Local Epoch : 4 	Loss: 0.012583
# Timeout : (0.5, 60) 	Local Epoch : 0 	Loss: 0.010332
# Timeout : (0.5, 60) 	Local Epoch : 1 	Loss: 0.009767
# Timeout : (0.5, 60) 	Local Epoch : 2 	Loss: 0.009657
# Timeout : (0.5, 60) 	Local Epoch : 3 	Loss: 0.009596
# Timeout : (0.5, 60) 	Local Epoch : 4 	Loss: 0.009495
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.010214
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.009745
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.009655
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.009598
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.009535
# Timeout : (1, 30) 	Local Epoch : 0 	Loss: 0.010734
# Timeout : (1, 30) 	Local Epoch : 1 	Loss: 0.010268
# Timeout : (1, 30) 	Local Epoch : 2 	Loss: 0.010114
# Timeout : (1, 30) 	Local Epoch : 3 	Loss: 0.010130
# Timeout : (1, 30) 	Local Epoch : 4 	Loss: 0.010059
# Timeout : (1, 2) 	Local Epoch : 0 	Loss: 0.010366
# Timeout : (1, 2) 	Local Epoch : 1 	Loss: 0.009956
# Timeout : (1, 2) 	Local Epoch : 2 	Loss: 0.009955
# Timeout : (1, 2) 	Local Epoch : 3 	Loss: 0.009888
# Timeout : (1, 2) 	Local Epoch : 4 	Loss: 0.009776
# Timeout : (10, 30) 	Local Epoch : 0 	Loss: 0.019530
# Timeout : (10, 30) 	Local Epoch : 1 	Loss: 0.016794
# Timeout : (10, 30) 	Local Epoch : 2 	Loss: 0.015558
# Timeout : (10, 30) 	Local Epoch : 3 	Loss: 0.013276
# Timeout : (10, 30) 	Local Epoch : 4 	Loss: 0.012561
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.010341
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.010168
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.010103
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.010067
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.010079
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.010599
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.010420
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.010317
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.010365
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.010251
# Timeout : (3, 30) 	Local Epoch : 0 	Loss: 0.011006
# Timeout : (3, 30) 	Local Epoch : 1 	Loss: 0.010403
# Timeout : (3, 30) 	Local Epoch : 2 	Loss: 0.010344
# Timeout : (3, 30) 	Local Epoch : 3 	Loss: 0.010297
# Timeout : (3, 30) 	Local Epoch : 4 	Loss: 0.010300
# Timeout : (4, 30) 	Local Epoch : 0 	Loss: 0.017564
# Timeout : (4, 30) 	Local Epoch : 1 	Loss: 0.015342
# Timeout : (4, 30) 	Local Epoch : 2 	Loss: 0.013166
# Timeout : (4, 30) 	Local Epoch : 3 	Loss: 0.012236
# Timeout : (4, 30) 	Local Epoch : 4 	Loss: 0.012284
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.010557
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.010225
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.010153
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.010050
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.010024
# Timeout : (5, 60) 	Local Epoch : 0 	Loss: 0.017370
# Timeout : (5, 60) 	Local Epoch : 1 	Loss: 0.015147
# Timeout : (5, 60) 	Local Epoch : 2 	Loss: 0.014051
# Timeout : (5, 60) 	Local Epoch : 3 	Loss: 0.012416
# Timeout : (5, 60) 	Local Epoch : 4 	Loss: 0.011227
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.011184
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.010783
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.010517
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.010334
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.010542
# Timeout : (0.5, 2) 	Local Epoch : 0 	Loss: 0.010316
# Timeout : (0.5, 2) 	Local Epoch : 1 	Loss: 0.009781
# Timeout : (0.5, 2) 	Local Epoch : 2 	Loss: 0.009621
# Timeout : (0.5, 2) 	Local Epoch : 3 	Loss: 0.009524
# Timeout : (0.5, 2) 	Local Epoch : 4 	Loss: 0.009470
# Timeout : (4, 5) 	Local Epoch : 0 	Loss: 0.011781
# Timeout : (4, 5) 	Local Epoch : 1 	Loss: 0.011453
# Timeout : (4, 5) 	Local Epoch : 2 	Loss: 0.011321
# Timeout : (4, 5) 	Local Epoch : 3 	Loss: 0.010991
# Timeout : (4, 5) 	Local Epoch : 4 	Loss: 0.010948
# Timeout : (1, 3) 	Local Epoch : 0 	Loss: 0.010399
# Timeout : (1, 3) 	Local Epoch : 1 	Loss: 0.010098
# Timeout : (1, 3) 	Local Epoch : 2 	Loss: 0.009980
# Timeout : (1, 3) 	Local Epoch : 3 	Loss: 0.009891
# Timeout : (1, 3) 	Local Epoch : 4 	Loss: 0.009850
# Round   6, Average MLP loss 0.011
# Timeout : (10, 30) 	Local Epoch : 0 	Loss: 0.018598
# Timeout : (10, 30) 	Local Epoch : 1 	Loss: 0.016196
# Timeout : (10, 30) 	Local Epoch : 2 	Loss: 0.015108
# Timeout : (10, 30) 	Local Epoch : 3 	Loss: 0.013049
# Timeout : (10, 30) 	Local Epoch : 4 	Loss: 0.012800
# Timeout : (0.5, 5) 	Local Epoch : 0 	Loss: 0.010073
# Timeout : (0.5, 5) 	Local Epoch : 1 	Loss: 0.009642
# Timeout : (0.5, 5) 	Local Epoch : 2 	Loss: 0.009576
# Timeout : (0.5, 5) 	Local Epoch : 3 	Loss: 0.009476
# Timeout : (0.5, 5) 	Local Epoch : 4 	Loss: 0.009439
# Timeout : (1, 3) 	Local Epoch : 0 	Loss: 0.010189
# Timeout : (1, 3) 	Local Epoch : 1 	Loss: 0.009950
# Timeout : (1, 3) 	Local Epoch : 2 	Loss: 0.009927
# Timeout : (1, 3) 	Local Epoch : 3 	Loss: 0.009803
# Timeout : (1, 3) 	Local Epoch : 4 	Loss: 0.009821
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.010355
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.010091
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.010045
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.010046
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.010009
# Timeout : (1, 2) 	Local Epoch : 0 	Loss: 0.010172
# Timeout : (1, 2) 	Local Epoch : 1 	Loss: 0.009880
# Timeout : (1, 2) 	Local Epoch : 2 	Loss: 0.009761
# Timeout : (1, 2) 	Local Epoch : 3 	Loss: 0.009770
# Timeout : (1, 2) 	Local Epoch : 4 	Loss: 0.009720
# Timeout : (3, 5) 	Local Epoch : 0 	Loss: 0.010669
# Timeout : (3, 5) 	Local Epoch : 1 	Loss: 0.010512
# Timeout : (3, 5) 	Local Epoch : 2 	Loss: 0.010468
# Timeout : (3, 5) 	Local Epoch : 3 	Loss: 0.010402
# Timeout : (3, 5) 	Local Epoch : 4 	Loss: 0.010377
# Timeout : (0.5, 3) 	Local Epoch : 0 	Loss: 0.010076
# Timeout : (0.5, 3) 	Local Epoch : 1 	Loss: 0.009664
# Timeout : (0.5, 3) 	Local Epoch : 2 	Loss: 0.009558
# Timeout : (0.5, 3) 	Local Epoch : 3 	Loss: 0.009508
# Timeout : (0.5, 3) 	Local Epoch : 4 	Loss: 0.009377
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.010536
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.010380
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.010383
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.010353
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.010380
# Timeout : (4, 30) 	Local Epoch : 0 	Loss: 0.015896
# Timeout : (4, 30) 	Local Epoch : 1 	Loss: 0.014669
# Timeout : (4, 30) 	Local Epoch : 2 	Loss: 0.013125
# Timeout : (4, 30) 	Local Epoch : 3 	Loss: 0.011937
# Timeout : (4, 30) 	Local Epoch : 4 	Loss: 0.011121
# Timeout : (4, 60) 	Local Epoch : 0 	Loss: 0.017862
# Timeout : (4, 60) 	Local Epoch : 1 	Loss: 0.015168
# Timeout : (4, 60) 	Local Epoch : 2 	Loss: 0.013947
# Timeout : (4, 60) 	Local Epoch : 3 	Loss: 0.012333
# Timeout : (4, 60) 	Local Epoch : 4 	Loss: 0.011537
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.010361
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.010154
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.009970
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.009899
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.009924
# Timeout : (1, 60) 	Local Epoch : 0 	Loss: 0.010425
# Timeout : (1, 60) 	Local Epoch : 1 	Loss: 0.010118
# Timeout : (1, 60) 	Local Epoch : 2 	Loss: 0.010079
# Timeout : (1, 60) 	Local Epoch : 3 	Loss: 0.009947
# Timeout : (1, 60) 	Local Epoch : 4 	Loss: 0.009925
# Timeout : (0.5, 60) 	Local Epoch : 0 	Loss: 0.010097
# Timeout : (0.5, 60) 	Local Epoch : 1 	Loss: 0.009648
# Timeout : (0.5, 60) 	Local Epoch : 2 	Loss: 0.009545
# Timeout : (0.5, 60) 	Local Epoch : 3 	Loss: 0.009554
# Timeout : (0.5, 60) 	Local Epoch : 4 	Loss: 0.009495
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.010403
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.010062
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.010086
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.009959
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.009911
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.010067
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.009654
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.009612
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.009525
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.009483
# Timeout : (3, 4) 	Local Epoch : 0 	Loss: 0.010520
# Timeout : (3, 4) 	Local Epoch : 1 	Loss: 0.010381
# Timeout : (3, 4) 	Local Epoch : 2 	Loss: 0.010402
# Timeout : (3, 4) 	Local Epoch : 3 	Loss: 0.010373
# Timeout : (3, 4) 	Local Epoch : 4 	Loss: 0.010392
# Round   7, Average MLP loss 0.011
# Timeout : (4, 30) 	Local Epoch : 0 	Loss: 0.016826
# Timeout : (4, 30) 	Local Epoch : 1 	Loss: 0.014723
# Timeout : (4, 30) 	Local Epoch : 2 	Loss: 0.013445
# Timeout : (4, 30) 	Local Epoch : 3 	Loss: 0.012648
# Timeout : (4, 30) 	Local Epoch : 4 	Loss: 0.011387
# Timeout : (1, 2) 	Local Epoch : 0 	Loss: 0.009977
# Timeout : (1, 2) 	Local Epoch : 1 	Loss: 0.009774
# Timeout : (1, 2) 	Local Epoch : 2 	Loss: 0.009765
# Timeout : (1, 2) 	Local Epoch : 3 	Loss: 0.009669
# Timeout : (1, 2) 	Local Epoch : 4 	Loss: 0.009710
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.010161
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.009993
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.009950
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.009930
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.009886
# Timeout : (5, 60) 	Local Epoch : 0 	Loss: 0.018425
# Timeout : (5, 60) 	Local Epoch : 1 	Loss: 0.015968
# Timeout : (5, 60) 	Local Epoch : 2 	Loss: 0.014089
# Timeout : (5, 60) 	Local Epoch : 3 	Loss: 0.012415
# Timeout : (5, 60) 	Local Epoch : 4 	Loss: 0.012178
# Timeout : (0.5, 3) 	Local Epoch : 0 	Loss: 0.009739
# Timeout : (0.5, 3) 	Local Epoch : 1 	Loss: 0.009606
# Timeout : (0.5, 3) 	Local Epoch : 2 	Loss: 0.009491
# Timeout : (0.5, 3) 	Local Epoch : 3 	Loss: 0.009376
# Timeout : (0.5, 3) 	Local Epoch : 4 	Loss: 0.009359
# Timeout : (4, 60) 	Local Epoch : 0 	Loss: 0.017870
# Timeout : (4, 60) 	Local Epoch : 1 	Loss: 0.015462
# Timeout : (4, 60) 	Local Epoch : 2 	Loss: 0.014156
# Timeout : (4, 60) 	Local Epoch : 3 	Loss: 0.012301
# Timeout : (4, 60) 	Local Epoch : 4 	Loss: 0.012012
# Timeout : (4, 5) 	Local Epoch : 0 	Loss: 0.011658
# Timeout : (4, 5) 	Local Epoch : 1 	Loss: 0.011481
# Timeout : (4, 5) 	Local Epoch : 2 	Loss: 0.011208
# Timeout : (4, 5) 	Local Epoch : 3 	Loss: 0.011076
# Timeout : (4, 5) 	Local Epoch : 4 	Loss: 0.010947
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.009769
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.009529
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.009417
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.009392
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.009379
# Timeout : (2, 2) 	Local Epoch : 0 	Loss: 0.010122
# Timeout : (2, 2) 	Local Epoch : 1 	Loss: 0.010044
# Timeout : (2, 2) 	Local Epoch : 2 	Loss: 0.009901
# Timeout : (2, 2) 	Local Epoch : 3 	Loss: 0.009887
# Timeout : (2, 2) 	Local Epoch : 4 	Loss: 0.009911
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.010238
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.010054
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.010106
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.010092
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.009996
# Timeout : (5, 5) 	Local Epoch : 0 	Loss: 0.011776
# Timeout : (5, 5) 	Local Epoch : 1 	Loss: 0.011493
# Timeout : (5, 5) 	Local Epoch : 2 	Loss: 0.011332
# Timeout : (5, 5) 	Local Epoch : 3 	Loss: 0.011074
# Timeout : (5, 5) 	Local Epoch : 4 	Loss: 0.010935
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.011403
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.010603
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.010601
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.010329
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.010308
# Timeout : (5, 30) 	Local Epoch : 0 	Loss: 0.018032
# Timeout : (5, 30) 	Local Epoch : 1 	Loss: 0.015512
# Timeout : (5, 30) 	Local Epoch : 2 	Loss: 0.013778
# Timeout : (5, 30) 	Local Epoch : 3 	Loss: 0.012583
# Timeout : (5, 30) 	Local Epoch : 4 	Loss: 0.012441
# Timeout : (3, 3) 	Local Epoch : 0 	Loss: 0.010360
# Timeout : (3, 3) 	Local Epoch : 1 	Loss: 0.010202
# Timeout : (3, 3) 	Local Epoch : 2 	Loss: 0.010220
# Timeout : (3, 3) 	Local Epoch : 3 	Loss: 0.010140
# Timeout : (3, 3) 	Local Epoch : 4 	Loss: 0.010085
# Timeout : (4, 4) 	Local Epoch : 0 	Loss: 0.011616
# Timeout : (4, 4) 	Local Epoch : 1 	Loss: 0.011333
# Timeout : (4, 4) 	Local Epoch : 2 	Loss: 0.011029
# Timeout : (4, 4) 	Local Epoch : 3 	Loss: 0.011116
# Timeout : (4, 4) 	Local Epoch : 4 	Loss: 0.010844
# Timeout : (2, 4) 	Local Epoch : 0 	Loss: 0.010415
# Timeout : (2, 4) 	Local Epoch : 1 	Loss: 0.010197
# Timeout : (2, 4) 	Local Epoch : 2 	Loss: 0.010270
# Timeout : (2, 4) 	Local Epoch : 3 	Loss: 0.010257
# Timeout : (2, 4) 	Local Epoch : 4 	Loss: 0.010131
# Round   8, Average MLP loss 0.011
# Timeout : (3, 30) 	Local Epoch : 0 	Loss: 0.011342
# Timeout : (3, 30) 	Local Epoch : 1 	Loss: 0.010483
# Timeout : (3, 30) 	Local Epoch : 2 	Loss: 0.010239
# Timeout : (3, 30) 	Local Epoch : 3 	Loss: 0.010433
# Timeout : (3, 30) 	Local Epoch : 4 	Loss: 0.010187
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.011056
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.010657
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.010799
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.010327
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.010387
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.010167
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.010065
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.010190
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.009978
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.009971
# Timeout : (2, 4) 	Local Epoch : 0 	Loss: 0.010272
# Timeout : (2, 4) 	Local Epoch : 1 	Loss: 0.010209
# Timeout : (2, 4) 	Local Epoch : 2 	Loss: 0.010188
# Timeout : (2, 4) 	Local Epoch : 3 	Loss: 0.010184
# Timeout : (2, 4) 	Local Epoch : 4 	Loss: 0.010158
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.010254
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.009989
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.009929
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.009865
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.009836
# Timeout : (5, 5) 	Local Epoch : 0 	Loss: 0.011452
# Timeout : (5, 5) 	Local Epoch : 1 	Loss: 0.011342
# Timeout : (5, 5) 	Local Epoch : 2 	Loss: 0.011178
# Timeout : (5, 5) 	Local Epoch : 3 	Loss: 0.011017
# Timeout : (5, 5) 	Local Epoch : 4 	Loss: 0.010849
# Timeout : (0.5, 60) 	Local Epoch : 0 	Loss: 0.009969
# Timeout : (0.5, 60) 	Local Epoch : 1 	Loss: 0.009601
# Timeout : (0.5, 60) 	Local Epoch : 2 	Loss: 0.009516
# Timeout : (0.5, 60) 	Local Epoch : 3 	Loss: 0.009425
# Timeout : (0.5, 60) 	Local Epoch : 4 	Loss: 0.009405
# Timeout : (5, 30) 	Local Epoch : 0 	Loss: 0.017114
# Timeout : (5, 30) 	Local Epoch : 1 	Loss: 0.014743
# Timeout : (5, 30) 	Local Epoch : 2 	Loss: 0.013651
# Timeout : (5, 30) 	Local Epoch : 3 	Loss: 0.012798
# Timeout : (5, 30) 	Local Epoch : 4 	Loss: 0.010995
# Timeout : (0.5, 5) 	Local Epoch : 0 	Loss: 0.010075
# Timeout : (0.5, 5) 	Local Epoch : 1 	Loss: 0.009631
# Timeout : (0.5, 5) 	Local Epoch : 2 	Loss: 0.009463
# Timeout : (0.5, 5) 	Local Epoch : 3 	Loss: 0.009463
# Timeout : (0.5, 5) 	Local Epoch : 4 	Loss: 0.009412
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.010059
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.009565
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.009470
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.009473
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.009417
# Timeout : (4, 30) 	Local Epoch : 0 	Loss: 0.016751
# Timeout : (4, 30) 	Local Epoch : 1 	Loss: 0.014147
# Timeout : (4, 30) 	Local Epoch : 2 	Loss: 0.012878
# Timeout : (4, 30) 	Local Epoch : 3 	Loss: 0.011553
# Timeout : (4, 30) 	Local Epoch : 4 	Loss: 0.011095
# Timeout : (1, 3) 	Local Epoch : 0 	Loss: 0.010148
# Timeout : (1, 3) 	Local Epoch : 1 	Loss: 0.009889
# Timeout : (1, 3) 	Local Epoch : 2 	Loss: 0.009783
# Timeout : (1, 3) 	Local Epoch : 3 	Loss: 0.009850
# Timeout : (1, 3) 	Local Epoch : 4 	Loss: 0.009724
# Timeout : (1, 60) 	Local Epoch : 0 	Loss: 0.010348
# Timeout : (1, 60) 	Local Epoch : 1 	Loss: 0.010037
# Timeout : (1, 60) 	Local Epoch : 2 	Loss: 0.009954
# Timeout : (1, 60) 	Local Epoch : 3 	Loss: 0.009999
# Timeout : (1, 60) 	Local Epoch : 4 	Loss: 0.009881
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.010282
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.010023
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.009926
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.009886
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.009823
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.011165
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.010469
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.010408
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.010442
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.010352
# Timeout : (2, 60) 	Local Epoch : 0 	Loss: 0.011138
# Timeout : (2, 60) 	Local Epoch : 1 	Loss: 0.010515
# Timeout : (2, 60) 	Local Epoch : 2 	Loss: 0.010894
# Timeout : (2, 60) 	Local Epoch : 3 	Loss: 0.010285
# Timeout : (2, 60) 	Local Epoch : 4 	Loss: 0.010231
# Round   9, Average MLP loss 0.011

# %% [markdown]
# # Testing the global model on the combined test set of all clients

# %%
X_test, y_test = None, None
all_accuracy, all_f1Score, all_recall, all_precision = {}, {}, {}, {}

for i, timeout in enumerate(timeouts):
    if i == 0:
        X_test = np.load(os.path.join('../../data/CIC-IDS2017/baselineFeatures/X_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
        y_test = np.load(os.path.join('../../data/CIC-IDS2017/baselineFeatures/y_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
    else:
        X = np.load(os.path.join('../../data/CIC-IDS2017/baselineFeatures/X_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
        y = np.load(os.path.join('../../data/CIC-IDS2017/baselineFeatures/y_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
        X_test = np.concatenate((X_test, X), axis=0)
        y_test = np.concatenate((y_test, y), axis=0)

# %%
X_test.shape, y_test.shape
# Out:
# ((41511608, 57), (41511608,))

# %%
#from models.evaluate import get_thr #,evaluate_ae
import numpy as np
from sklearn.metrics import classification_report
import torch.nn as nn
import torch
from torch.utils.data import DataLoader, TensorDataset
import tqdm

# ------------------ Start Testing ----------------------#
print("Testing ... ")
test_dataset = torch.utils.data.TensorDataset(torch.Tensor(X_test), torch.Tensor(y_test))
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True, drop_last=True)


def test(config, model, test_loader):


    model.eval()

    history = {
        'test': {
            'total': 0,
            'loss': 0.0,
            'accuracy': 0.0,
            'output_pred': [],
            'output_true': [],
            'output_pred_prob': []
        }
    }

    test_loss = 0.0
    test_steps = 0
    test_total = 0
    test_correct = 0

    test_output_pred = []
    test_output_true = []
    test_output_pred_prob = []
    
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            inputs, labels = inputs.to(config.device), labels.type(torch.LongTensor).to(config.device)
            #labels = labels.squeeze(1)

            outputs = model(inputs)
            
            loss = criterion(outputs, labels)
            test_loss += loss.cpu().item()
            test_steps += 1

            _, predicted = torch.max(outputs.data, 1)
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

            test_output_pred += outputs.argmax(1).cpu().tolist()
            test_output_true += labels.tolist()
            test_output_pred_prob += nn.functional.softmax(outputs, dim=0).cpu().tolist()

    history['test']['total'] = test_total
    history['test']['loss'] = test_loss/test_steps
    history['test']['accuracy'] = test_correct/test_total
    history['test']['output_pred'] = test_output_pred
    history['test']['output_true'] = test_output_true
    history['test']['output_pred_prob'] = test_output_pred_prob

    return history

history=test(config, net_glob, test_loader)
# Out:
# Testing ...

# %%
test_output_true = history['test']['output_true']
test_output_pred = history['test']['output_pred']
test_output_pred_prob = history['test']['output_pred_prob']


print("Testing Set -- Classification Report", end="\n\n")
print(classification_report(test_output_true, test_output_pred, target_names=classes))
# Out:
# Testing Set -- Classification Report
#
#                             precision    recall  f1-score   support
#
#                     Benign       0.99      1.00      0.99  33084646
#                     Botnet       0.92      0.90      0.91     15698
#                       DDoS       1.00      1.00      1.00   1549945
#              DoS GoldenEye       0.90      1.00      0.94    163111
#                   DoS Hulk       1.00      0.89      0.94   1730882
#           DoS Slowhttptest       0.99      0.67      0.80     41603
#              DoS Slowloris       0.91      0.87      0.89     87324
#                FTP-Patator       1.00      1.00      1.00     84736
#               Infiltration       1.00      0.07      0.12       412
#    Infiltration - Portscan       0.91      0.99      0.95   1289808
#                   Portscan       1.00      1.00      1.00   3398037
#                SSH-Patator       0.99      0.99      0.99     63168
#   Web Attack - Brute Force       0.97      0.93      0.95      1549
# Web Attack - SQL Injection       0.00      0.00      0.00       281
#           Web Attack - XSS       1.00      0.48      0.65       384
#
#                   accuracy                           0.99  41511584
#                  macro avg       0.91      0.79      0.81  41511584
#               weighted avg       0.99      0.99      0.99  41511584

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, auc, roc_curve


acc = accuracy_score(test_output_true, test_output_pred)
precision = precision_score(test_output_true, test_output_pred, average='macro')
recall = recall_score(test_output_true, test_output_pred, average='macro')
f1Score = f1_score(test_output_true, test_output_pred, average='macro')

print('\nAccuracy: {:.4f}\n'.format(acc))

print('Macro Precision: {:.4f}'.format(precision))
print('Macro Recall: {:.4f}'.format(recall))
print('Macro F1-score: {:.4f}\n'.format(f1Score))

all_accuracy["all_test_sets"] = acc
all_precision["all_test_sets"] = precision
all_recall["all_test_sets"] = recall
all_f1Score["all_test_sets"] = f1Score
# Out:
# Accuracy: 0.9909
#
# Macro Precision: 0.9052
# Macro Recall: 0.7856
# Macro F1-score: 0.8094

# %% [markdown]
# # Testing the global model on the each client seperatly

# %%
X_test, y_test = None, None
for i, timeout in enumerate(timeouts):
    X_test = np.load(os.path.join('../../data/CIC-IDS2017/baselineFeatures/X_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
    y_test = np.load(os.path.join('../../data/CIC-IDS2017/baselineFeatures/y_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
    test_dataset = torch.utils.data.TensorDataset(torch.Tensor(X_test), torch.Tensor(y_test))
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True, drop_last=True)
    
    history=test(config, net_glob, test_loader)

    test_output_true = history['test']['output_true']
    test_output_pred = history['test']['output_pred']
    test_output_pred_prob = history['test']['output_pred_prob']

    all_accuracy[str(timeout)] = accuracy_score(test_output_true, test_output_pred)
    all_f1Score[str(timeout)] = f1_score(test_output_true, test_output_pred, average='macro')  
    all_precision[str(timeout)] = precision_score(test_output_true, test_output_pred, average='macro')
    all_recall[str(timeout)] = recall_score(test_output_true, test_output_pred, average='macro')
    
    print("Timenout : {} \tAccuracy={:.4f} \tF1_score={:.4f}".format(timeout, all_accuracy[str(timeout)], all_f1Score[str(timeout)]))
# Out:
# Timenout : (0.5, 2) 	Accuracy=0.9845 	F1_score=0.7129
# Timenout : (1, 2) 	Accuracy=0.9841 	F1_score=0.7250
# Timenout : (2, 2) 	Accuracy=0.9947 	F1_score=0.7726
# Timenout : (0.5, 3) 	Accuracy=0.9848 	F1_score=0.7787
# Timenout : (1, 3) 	Accuracy=0.9852 	F1_score=0.8347
# Timenout : (2, 3) 	Accuracy=0.9946 	F1_score=0.8498
# Timenout : (3, 3) 	Accuracy=0.9949 	F1_score=0.8416
# Timenout : (0.5, 4) 	Accuracy=0.9849 	F1_score=0.7521
# Timenout : (1, 4) 	Accuracy=0.9848 	F1_score=0.8178
# Timenout : (2, 4) 	Accuracy=0.9951 	F1_score=0.8391
# Timenout : (3, 4) 	Accuracy=0.9953 	F1_score=0.8330
# Timenout : (4, 4) 	Accuracy=0.9954 	F1_score=0.8346
# Timenout : (0.5, 5) 	Accuracy=0.9849 	F1_score=0.7853
# Timenout : (1, 5) 	Accuracy=0.9856 	F1_score=0.8181
# Timenout : (2, 5) 	Accuracy=0.9958 	F1_score=0.8460
# Timenout : (3, 5) 	Accuracy=0.9960 	F1_score=0.8492
# Timenout : (4, 5) 	Accuracy=0.9956 	F1_score=0.8367
# Timenout : (5, 5) 	Accuracy=0.9953 	F1_score=0.8308
# Timenout : (0.5, 30) 	Accuracy=0.9850 	F1_score=0.7592
# Timenout : (1, 30) 	Accuracy=0.9856 	F1_score=0.7646
# Timenout : (2, 30) 	Accuracy=0.9958 	F1_score=0.8500
# Timenout : (3, 30) 	Accuracy=0.9958 	F1_score=0.7949
# Timenout : (4, 30) 	Accuracy=0.9957 	F1_score=0.7836
# Timenout : (5, 30) 	Accuracy=0.9956 	F1_score=0.8478
# Timenout : (10, 30) 	Accuracy=0.9917 	F1_score=0.7071
# Timenout : (0.5, 60) 	Accuracy=0.9850 	F1_score=0.7597
# Timenout : (1, 60) 	Accuracy=0.9856 	F1_score=0.7646
# Timenout : (2, 60) 	Accuracy=0.9958 	F1_score=0.8500
# Timenout : (3, 60) 	Accuracy=0.9958 	F1_score=0.7949
# Timenout : (4, 60) 	Accuracy=0.9957 	F1_score=0.7836
# Timenout : (5, 60) 	Accuracy=0.9955 	F1_score=0.7832
# Timenout : (10, 60) 	Accuracy=0.9912 	F1_score=0.7095

# %%
results = {"accuracy": all_accuracy, "f1Score":all_f1Score, "precision": all_precision, "recall":all_recall}

import json
with open('../../save/results/CIC-IDS2017/{}_{}_E[{}]_R[{}].json'.format(config.dataset, config.model, config.local_ep,config.epochs), 'w') as f:
    json.dump(results, f)

# %%
import matplotlib.pyplot as plt
import json
plt.figure(figsize=(14, 10))


load_json=True
if load_json:
    f = open('../../save/results/CIC-IDS2017/addFeatures/cic17_MLP_E[5]_R[10].json')
    results = json.load(f)
    f.close()
    

time = timeouts = ["All", "(0.5,2)", "(1, 2)", "(2,2)","(0.5,3)", "(1,3)", "(2, 3)", "(3,3)", "(0.5,4)", "(1, 4)", "(2,4)", "(3,4)", "(4,4)", "(0.5,5)", "(1,5)", "(2,5)", "(3,5)",
                   "(4,5)", "(5,5)", "(0.5, 30)", "(1, 30)", "(2,30)", "(3,30)", "(4,30)", "(5,30)", "(10, 30)", "(0.5, 60)", "(1, 60)", "(2,60)", "(3,60)", "(4,60)", "(5,60)", "(10, 60)"]

acc= list(results["accuracy"].values())
print(time)

bars = plt.barh(time, acc, height = 0.8, color='steelblue')
plt.tick_params(axis='y', labelsize=12)
plt.tick_params(axis='x', labelsize=12)
bars[0].set_color('chocolate')
plt.ylabel('Timeouts', fontsize=18)
#plt.xlabel('Accuracy')
#plt.title('F1-score for each timeout')
#plt.grid(which="major", axis="both", linestyle='-', linewidth=0.5)
plt.savefig("../../save/plts/CIC-IDS2017/FL_cic17_acc.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# ['All', '(0.5,2)', '(1, 2)', '(2,2)', '(0.5,3)', '(1,3)', '(2, 3)', '(3,3)', '(0.5,4)', '(1, 4)', '(2,4)', '(3,4)', '(4,4)', '(0.5,5)', '(1,5)', '(2,5)', '(3,5)', '(4,5)', '(5,5)', '(0.5, 30)', '(1, 30)', '(2,30)', '(3,30)', '(4,30)', '(5,30)', '(10, 30)', '(0.5, 60)', '(1, 60)', '(2,60)', '(3,60)', '(4,60)', '(5,60)', '(10, 60)']

# %%
plt.figure(figsize=(14, 10))

f1_score= list(results["f1Score"].values())

bars = plt.barh(time, f1_score, height = 0.8, color='steelblue')
plt.tick_params(axis='y', labelsize=12)
plt.tick_params(axis='x', labelsize=12)
bars[0].set_color('chocolate')
plt.ylabel('Timeouts', fontsize=18)
#plt.xlabel('F1-score')
#plt.title('F1-score for each timeout')
#plt.grid(which="major", axis="both", linestyle='-', linewidth=0.5)
plt.savefig("../../save/plts/CIC-IDS2017/FL_cic17_f1.pdf", format="pdf", bbox_inches="tight")
plt.show()
