# %%
import sys
sys.path.append("../..")

# %%
from models.Fed import FedAvg
from models.Nets import MLP

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, f1_score
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor  
import warnings
import pickle
import os
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %%
cols = [ 'expiration_id', 'protocol', 'src_port', 'dst_port',
       'ip_version',   'bidirectional_duration_ms', 'bidirectional_packets',
       'bidirectional_bytes', 'src2dst_duration_ms', 'src2dst_packets',
       'src2dst_bytes', 'dst2src_duration_ms', 'dst2src_packets', 'dst2src_bytes',
       'bidirectional_min_ps', 'bidirectional_mean_ps',
       'bidirectional_stddev_ps', 'bidirectional_max_ps',
       'src2dst_min_ps', 'src2dst_mean_ps', 'src2dst_stddev_ps',
       'src2dst_max_ps', 'dst2src_min_ps', 'dst2src_mean_ps',
       'dst2src_stddev_ps', 'dst2src_max_ps', 'bidirectional_min_piat_ms',
       'bidirectional_mean_piat_ms', 'bidirectional_stddev_piat_ms',
       'bidirectional_max_piat_ms', 'src2dst_min_piat_ms',
       'src2dst_mean_piat_ms', 'src2dst_stddev_piat_ms',
       'src2dst_max_piat_ms', 'dst2src_min_piat_ms',
       'dst2src_mean_piat_ms', 'dst2src_stddev_piat_ms',
       'dst2src_max_piat_ms', 'bidirectional_syn_packets', 'bidirectional_ack_packets',
       'bidirectional_psh_packets', 'bidirectional_rst_packets',
       'bidirectional_fin_packets', 'src2dst_syn_packets', 'src2dst_ack_packets',
       'src2dst_psh_packets', 'src2dst_rst_packets',
       'src2dst_fin_packets', 'dst2src_syn_packets', 'dst2src_ack_packets',
       'dst2src_psh_packets', 'dst2src_rst_packets',
       'dst2src_fin_packets','application_name',
       'application_category_name', 'application_is_guessed',
       'application_confidence', 'content_type', 'udps.num_pkts_up_to_128_bytes',
       'udps.num_pkts_128_to_256_bytes', 'udps.num_pkts_256_to_512_bytes',
       'udps.num_pkts_512_to_1024_bytes',
       'udps.num_pkts_1024_to_1514_bytes', 'udps.min_ttl', 'udps.max_ttl',
       'udps.min_ip_pkt_len', 'udps.max_ip_pkt_len', 'udps.src2dst_flags',
       'udps.dst2src_flags', 'udps.tcp_flags', 'udps.tcp_win_max_in',
       'udps.tcp_win_max_out', 'udps.icmp_type', 'udps.icmp_v4_type',
       'udps.dns_query_id', 'udps.dns_query_type', 'udps.dns_ttl_answer',
       'udps.ftp_command_ret_code', 'udps.retransmitted_in_packets',
       'udps.retransmitted_out_packets', 'udps.retransmitted_in_bytes',
       'udps.retransmitted_out_bytes', 'udps.src_to_dst_second_bytes',
       'udps.dst_to_src_second_bytes', 'udps.src_to_dst_avg_throughput',
       'udps.dst_to_src_avg_throughput', 'udps.src_to_dst_second_bytes2',
       'udps.dst_to_src_second_bytes2', 'udps.src_to_dst_avg_throughput2',
       'udps.dst_to_src_avg_throughput2', 'udps.tcp_init_ms',
       'udps.tcp_synack_ack_ms', 'udps.tcp_half_closed_time_ms',
       'udps.num_pkts_after_termination',
       'udps.src2dst_first_packet_payload_len',
       'udps.dst2src_first_packet_payload_len',
       'udps.bidirectional_transport_bytes',
       'udps.bidirectional_payload_bytes', 'udps.src2dst_transport_bytes',
       'udps.src2dst_payload_bytes', 'udps.dst2src_transport_bytes',
       'udps.dst2src_payload_bytes',
       'udps.src2dst_most_freq_payload_ratio',
       'udps.src2dst_most_freq_payload_len',
       'udps.dst2src_most_freq_payload_ratio',
       'udps.dst2src_most_freq_payload_len',
       'udps.bidirectional_mean_packet_relative_times',
       'udps.bidirectional_stddev_packet_relative_times',
       'udps.bidirectional_variance_packet_relative_times',
       'udps.bidirectional_coeff_of_var_packet_relative_times',
       'udps.bidirectional_skew_from_median_packet_relative_times',
       'udps.src2dst_mean_packet_relative_times',
       'udps.src2dst_stddev_packet_relative_times',
       'udps.src2dst_variance_packet_relative_times',
       'udps.src2dst_coeff_of_var_packet_relative_times',
       'udps.src2dst_skew_from_median_packet_relative_times',
       'udps.dst2src_mean_packet_relative_times',
       'udps.dst2src_stddev_packet_relative_times',
       'udps.dst2src_variance_packet_relative_times',
       'udps.dst2src_coeff_of_var_packet_relative_times',
       'udps.dst2src_skew_from_median_packet_relative_times',
       'udps.min_req_res_time_diff', 'udps.max_req_res_time_diff',
       'udps.mean_req_res_time_diff', 'udps.stddev_req_res_time_diff',
       'udps.variance_req_res_time_diff',
       'udps.coeff_of_var_req_res_time_diff',
       'udps.skew_from_median_req_res_time_diff',
       'udps.src2dst_small_packet_payload_packets',
       'udps.src2dst_small_packet_payload_ratio',
       'udps.dst2src_small_packet_payload_packets',
       'udps.dst2src_small_packet_payload_ratio',
       'udps.sent_recv_packet_ratio',
       'udps.bidirectional_ps_first_quartile',
       'udps.bidirectional_ps_second_quartile',
       'udps.bidirectional_ps_third_quartile',
       'udps.bidirectional_ps_median_absoulte_deviation',
       'udps.bidirectional_ps_skewness', 'udps.bidirectional_ps_kurtosis',
       'udps.bidirectional_piat_first_quartile',
       'udps.bidirectional_piat_second_quartile',
       'udps.bidirectional_piat_third_quartile',
       'udps.bidirectional_piat_median_absoulte_deviation',
       'udps.bidirectional_piat_skewness',
       'udps.bidirectional_piat_kurtosis',
       'udps.median_req_res_time_diff', 'Attack']

# %%
def port_feature(port):
    if port < 1024:
        return 1
    elif port < 49152 and port >= 1024:
        return 2
    else:
        return 3

# %%
def encode(df, cols):
    """
    @param df pandas DataFrame
    @param cols a list of columns to encode 
    @return a DataFrame with one-hot encoding
    """
    les = {}
    for each in cols:
        le_col = LabelEncoder()
        df[each] = le_col.fit_transform(df[each])
        les[each] = le_col
       
    return df, les

# %%
def normalize_content_type(x):
    if str(x).isspace():
        return "unkown/unkown"
    elif "/" not in str(x):
        return str(x)+"/unkown"
    else:
        return x

# %%
def save_predictions(predictions, targets, timeout, save_path= "results/ET"):
    name_file_pred = 'predictions_idle_' + str(timeout[0]) + "_active_" + str(timeout[1]) + ".p"
    name_file_y = 'targets_idle_' + str(timeout[0]) + "_active_" + str(timeout[1]) + ".p"

    pickle.dump(predictions, open(os.path.join(save_path, name_file_pred), 'wb') )
    pickle.dump(targets, open(os.path.join(save_path, name_file_y), 'wb') )
    
def load_predictions(timeout, save_path= "results/ET"):
    name_file_pred = 'predictions_idle_' + str(timeout[0]) + "_active_" + str(timeout[1]) + ".p"
    name_file_y = 'targets_idle_' + str(timeout[0]) + "_active_" + str(timeout[1]) + ".p"
    
    predictions =  pickle.load(open(os.path.join(save_path, name_file_pred), 'rb') )
    targets =  pickle.load(open(os.path.join(save_path, name_file_y), 'rb') )
    return predictions, targets

# %%
timeouts = [(0.5,2), (1, 2), (2,2), (0.5,3), (1,3), (2, 3), (3,3), (0.5,4), (1, 4), (2,4), (3,4), (4,4), (0.5,5), (1,5), (2,5), (3,5), (4,5), (5,5), (0.5, 30), (1, 30), (2,30), (3,30), (4,30), (5,30), (10, 30), (0.5, 60), (1, 60), (2,60), (3,60), (4,60), (5,60), (10, 60)]

# %%
def split_data(data):
    train_idx, test_idx = next(StratifiedKFold(n_splits=3).split(data, data['Attack']))
    train, test = data.iloc[train_idx].reset_index(drop=True), data.iloc[test_idx].reset_index(drop=True)
    return train, test

# %%
from configs.net_config import MLPConfig
import torch

config = MLPConfig()

# %%
gpu = 0
config.device = torch.device('cuda:{}'.format(gpu) if torch.cuda.is_available() and gpu != -1 else 'cpu')
seed=config.seed
iid=config.iid
config.dataset= "cupid"
all_clients = config.all_clients
config.epochs=10
config.local_ep=5
print("Dataset: {}, Model: {}, IID: {}, Data Type : {}, Device : {} ".format(config.dataset, config.model, iid, config.data_type, config.device))
# Out:
# Dataset: cupid, Model: MLP, IID: True, Data Type : tabular, Device : cuda:0

# %%
# build model
classes =  ['Benign', 'Bonesi', 'DVWA Pentesting', 'Dnsmap', 'Manual DVWA', 'Nmap']
if config.model == 'MLP' and config.dataset == 'cupid' and config.data_type == "tabular":
    net_glob = MLP(num_features=57, hidden1_size=32, hidden2_size=16, num_classes=len(classes)).to(config.device) 
else:
    exit('Error: unrecognized model')
print(net_glob)
# Out:
# MLP(
#   (fc1): Linear(in_features=57, out_features=32, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=32, out_features=16, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=16, out_features=6, bias=True)
# )

# %%
from models.Update import LocalUpdate
import copy

preprocessing=False
if preprocessing:
    for timeout in timeouts:
        print("Processing timeout : ", timeout)
        idle, active = timeout
        out_dir = f'/home/meryem.janati/lustre/nlp_team-um6p-st-sccs-id7fz1zvotk/IDS/janati/IDS/project2/extractions/extractions/new_idle_{idle}min_active_{active}min/CUPID'
        df = pd.read_csv(out_dir+"/CUPID.csv")
        df = df[~df.Attack.isin(['Nslookup', 'Dnstracer', 'Dig'])]

        df = df.sort_values(by=['bidirectional_last_seen_ms']).reset_index(drop=True)
        df_new = df[cols]
        df_new['application_name'] = df_new['application_name'].apply(lambda x: x.split(".")[0])
        df_new['content_type'] = df_new['content_type'].fillna("unkown/unkown")
        df_new['content_type'] = df_new['content_type'].apply(lambda x: normalize_content_type(x))
        df_new['content_sub_type'] = df_new['content_type'].apply(lambda x: x.split("/")[1])
        df_new['content_type'] = df_new['content_type'].apply(lambda x: x.split("/")[0])
        #df_new['src_port'] = df_new['src_port'].apply(lambda x: port_feature(x))
        #df_new['dst_port'] = df_new['dst_port'].apply(lambda x: port_feature(x))
        df_new = df_new.fillna(0)
        categ_cols = ["application_name", "application_category_name", "content_sub_type", "content_type" ]
        df_new, lbl_encoders = encode(df_new,categ_cols)    
        train, test = split_data(df_new)
        y_train = train['Attack']
        X_train = train.drop('Attack', axis=1)
        y_test = test['Attack']
        X_test = test.drop('Attack', axis=1)
        le = LabelEncoder()
        y_train = le.fit_transform(y_train)
        y_test = le.transform(y_test)
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        print("Saving data for timeout: ", timeout)
        np.save(os.path.join('../../data/CUPID/baselineFeatures/X_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), X_train)
        np.save(os.path.join('../../data/CUPID/baselineFeatures/y_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), y_train)
        np.save(os.path.join('../../data/CUPID/baselineFeatures/X_test_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), X_test)
        np.save(os.path.join('../../data/CUPID/baselineFeatures/y_test_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), y_test)

# %%
from models.Update import LocalUpdate
import copy

def FL_training():
    #net_glob = MLP(dim_in=46, dim_hidden=32, dim_out=le.classes_).to(config.device) 
    net_glob.train()
    # copy weights
    w_glob = net_glob.state_dict()
    print("Training ... ")
    net_loss_train = []


    if config.all_clients: 
        print("Aggregation over all clients")
        w_net_locals = [w_glob for i in range(config.num_users)]

    for iter in range(config.epochs):
        net_loss_locals = []
        X_train, y_train = None, None
        if not config.all_clients:
            w_net_locals = []
        m = max(int(config.frac * config.num_users), 1)
        idxs_timeouts = np.random.choice(range(config.num_users), m, replace=False)
        for idx in idxs_timeouts:
            timeout = timeouts[idx]
            X_train = np.load(os.path.join('../../data/CUPID/baselineFeatures/X_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
            y_train = np.load(os.path.join('../../data/CUPID/baselineFeatures/y_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
            
            local = LocalUpdate(config=config, x_train=X_train, y_train=y_train)
            w_net, net_loss = local.train_net(net=copy.deepcopy(net_glob).to(config.device), timeout=timeout)

            w_net = w_net.state_dict()
            if config.all_clients:
                w_net_locals[idx] = copy.deepcopy(w_net)
            else:
                w_net_locals.append(copy.deepcopy(w_net))

            net_loss_locals.append(copy.deepcopy(net_loss))
        # update global weights
        w_glob = FedAvg(w_net_locals)

        # copy weight to net_glob
        net_glob.load_state_dict(w_glob)

        # print loss
        net_loss_avg = sum(net_loss_locals) / len(net_loss_locals)
        print('Round {:3d}, Average MLP loss {:.3f}'.format(iter, net_loss_avg))
        net_loss_train.append(net_loss_avg)

    #save_model(config.local_ep, net_glob, filepath) 
FL_training()
# Out:
# Training ...
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.033943
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.015268
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.014501
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.014003
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.013732
# Timeout : (0.5, 30) 	Local Epoch : 0 	Loss: 0.029140
# Timeout : (0.5, 30) 	Local Epoch : 1 	Loss: 0.013277
# Timeout : (0.5, 30) 	Local Epoch : 2 	Loss: 0.012802
# Timeout : (0.5, 30) 	Local Epoch : 3 	Loss: 0.012560
# Timeout : (0.5, 30) 	Local Epoch : 4 	Loss: 0.012290
# Timeout : (3, 3) 	Local Epoch : 0 	Loss: 0.033197
# Timeout : (3, 3) 	Local Epoch : 1 	Loss: 0.015065
# Timeout : (3, 3) 	Local Epoch : 2 	Loss: 0.014350
# Timeout : (3, 3) 	Local Epoch : 3 	Loss: 0.013880
# Timeout : (3, 3) 	Local Epoch : 4 	Loss: 0.013544
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.035720
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.015721
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.014943
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.014401
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.013957
# Timeout : (2, 2) 	Local Epoch : 0 	Loss: 0.031595
# Timeout : (2, 2) 	Local Epoch : 1 	Loss: 0.013864
# Timeout : (2, 2) 	Local Epoch : 2 	Loss: 0.013200
# Timeout : (2, 2) 	Local Epoch : 3 	Loss: 0.012905
# Timeout : (2, 2) 	Local Epoch : 4 	Loss: 0.012626
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.028928
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.013176
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.012698
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.012414
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.012175
# Timeout : (5, 30) 	Local Epoch : 0 	Loss: 0.038702
# Timeout : (5, 30) 	Local Epoch : 1 	Loss: 0.016130
# Timeout : (5, 30) 	Local Epoch : 2 	Loss: 0.015384
# Timeout : (5, 30) 	Local Epoch : 3 	Loss: 0.014778
# Timeout : (5, 30) 	Local Epoch : 4 	Loss: 0.014430
# Timeout : (1, 60) 	Local Epoch : 0 	Loss: 0.033854
# Timeout : (1, 60) 	Local Epoch : 1 	Loss: 0.015399
# Timeout : (1, 60) 	Local Epoch : 2 	Loss: 0.014510
# Timeout : (1, 60) 	Local Epoch : 3 	Loss: 0.014106
# Timeout : (1, 60) 	Local Epoch : 4 	Loss: 0.013904
# Timeout : (3, 30) 	Local Epoch : 0 	Loss: 0.037631
# Timeout : (3, 30) 	Local Epoch : 1 	Loss: 0.016006
# Timeout : (3, 30) 	Local Epoch : 2 	Loss: 0.015499
# Timeout : (3, 30) 	Local Epoch : 3 	Loss: 0.014669
# Timeout : (3, 30) 	Local Epoch : 4 	Loss: 0.014345
# Timeout : (0.5, 5) 	Local Epoch : 0 	Loss: 0.028828
# Timeout : (0.5, 5) 	Local Epoch : 1 	Loss: 0.013313
# Timeout : (0.5, 5) 	Local Epoch : 2 	Loss: 0.012736
# Timeout : (0.5, 5) 	Local Epoch : 3 	Loss: 0.012465
# Timeout : (0.5, 5) 	Local Epoch : 4 	Loss: 0.012358
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.032571
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.014811
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.014082
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.013842
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.013556
# Timeout : (1, 2) 	Local Epoch : 0 	Loss: 0.030522
# Timeout : (1, 2) 	Local Epoch : 1 	Loss: 0.013597
# Timeout : (1, 2) 	Local Epoch : 2 	Loss: 0.013068
# Timeout : (1, 2) 	Local Epoch : 3 	Loss: 0.012831
# Timeout : (1, 2) 	Local Epoch : 4 	Loss: 0.012703
# Timeout : (0.5, 3) 	Local Epoch : 0 	Loss: 0.028627
# Timeout : (0.5, 3) 	Local Epoch : 1 	Loss: 0.013296
# Timeout : (0.5, 3) 	Local Epoch : 2 	Loss: 0.012730
# Timeout : (0.5, 3) 	Local Epoch : 3 	Loss: 0.012413
# Timeout : (0.5, 3) 	Local Epoch : 4 	Loss: 0.012263
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.032177
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.014872
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.014044
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.013798
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.013567
# Timeout : (4, 5) 	Local Epoch : 0 	Loss: 0.034528
# Timeout : (4, 5) 	Local Epoch : 1 	Loss: 0.015412
# Timeout : (4, 5) 	Local Epoch : 2 	Loss: 0.014735
# Timeout : (4, 5) 	Local Epoch : 3 	Loss: 0.014180
# Timeout : (4, 5) 	Local Epoch : 4 	Loss: 0.013980
# Timeout : (3, 4) 	Local Epoch : 0 	Loss: 0.033809
# Timeout : (3, 4) 	Local Epoch : 1 	Loss: 0.015171
# Timeout : (3, 4) 	Local Epoch : 2 	Loss: 0.014546
# Timeout : (3, 4) 	Local Epoch : 3 	Loss: 0.014007
# Timeout : (3, 4) 	Local Epoch : 4 	Loss: 0.013759
# Round   0, Average MLP loss 0.018
# Timeout : (0.5, 2) 	Local Epoch : 0 	Loss: 0.013149
# Timeout : (0.5, 2) 	Local Epoch : 1 	Loss: 0.011698
# Timeout : (0.5, 2) 	Local Epoch : 2 	Loss: 0.011449
# Timeout : (0.5, 2) 	Local Epoch : 3 	Loss: 0.011236
# Timeout : (0.5, 2) 	Local Epoch : 4 	Loss: 0.011036
# Timeout : (1, 60) 	Local Epoch : 0 	Loss: 0.014293
# Timeout : (1, 60) 	Local Epoch : 1 	Loss: 0.013899
# Timeout : (1, 60) 	Local Epoch : 2 	Loss: 0.013616
# Timeout : (1, 60) 	Local Epoch : 3 	Loss: 0.013385
# Timeout : (1, 60) 	Local Epoch : 4 	Loss: 0.013160
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.013917
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.013541
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.013277
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.013093
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.012902
# Timeout : (4, 60) 	Local Epoch : 0 	Loss: 0.014948
# Timeout : (4, 60) 	Local Epoch : 1 	Loss: 0.014261
# Timeout : (4, 60) 	Local Epoch : 2 	Loss: 0.013992
# Timeout : (4, 60) 	Local Epoch : 3 	Loss: 0.013814
# Timeout : (4, 60) 	Local Epoch : 4 	Loss: 0.013552
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.014912
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.014228
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.014006
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.013633
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.013459
# Timeout : (0.5, 3) 	Local Epoch : 0 	Loss: 0.012628
# Timeout : (0.5, 3) 	Local Epoch : 1 	Loss: 0.012256
# Timeout : (0.5, 3) 	Local Epoch : 2 	Loss: 0.012009
# Timeout : (0.5, 3) 	Local Epoch : 3 	Loss: 0.011801
# Timeout : (0.5, 3) 	Local Epoch : 4 	Loss: 0.011630
# Timeout : (2, 2) 	Local Epoch : 0 	Loss: 0.013604
# Timeout : (2, 2) 	Local Epoch : 1 	Loss: 0.012640
# Timeout : (2, 2) 	Local Epoch : 2 	Loss: 0.012384
# Timeout : (2, 2) 	Local Epoch : 3 	Loss: 0.012133
# Timeout : (2, 2) 	Local Epoch : 4 	Loss: 0.012039
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.014499
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.014034
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.013639
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.013535
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.013312
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.012680
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.012287
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.011981
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.011806
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.011676
# Timeout : (0.5, 60) 	Local Epoch : 0 	Loss: 0.012851
# Timeout : (0.5, 60) 	Local Epoch : 1 	Loss: 0.012413
# Timeout : (0.5, 60) 	Local Epoch : 2 	Loss: 0.012119
# Timeout : (0.5, 60) 	Local Epoch : 3 	Loss: 0.011778
# Timeout : (0.5, 60) 	Local Epoch : 4 	Loss: 0.011560
# Timeout : (5, 60) 	Local Epoch : 0 	Loss: 0.015439
# Timeout : (5, 60) 	Local Epoch : 1 	Loss: 0.014508
# Timeout : (5, 60) 	Local Epoch : 2 	Loss: 0.014091
# Timeout : (5, 60) 	Local Epoch : 3 	Loss: 0.013903
# Timeout : (5, 60) 	Local Epoch : 4 	Loss: 0.013717
# Timeout : (3, 30) 	Local Epoch : 0 	Loss: 0.014788
# Timeout : (3, 30) 	Local Epoch : 1 	Loss: 0.014144
# Timeout : (3, 30) 	Local Epoch : 2 	Loss: 0.013953
# Timeout : (3, 30) 	Local Epoch : 3 	Loss: 0.013689
# Timeout : (3, 30) 	Local Epoch : 4 	Loss: 0.013655
# Timeout : (3, 4) 	Local Epoch : 0 	Loss: 0.014099
# Timeout : (3, 4) 	Local Epoch : 1 	Loss: 0.013635
# Timeout : (3, 4) 	Local Epoch : 2 	Loss: 0.013427
# Timeout : (3, 4) 	Local Epoch : 3 	Loss: 0.013212
# Timeout : (3, 4) 	Local Epoch : 4 	Loss: 0.013072
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.014001
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.013612
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.013396
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.013153
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.012969
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.014200
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.013780
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.013464
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.013243
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.013032
# Timeout : (2, 60) 	Local Epoch : 0 	Loss: 0.014581
# Timeout : (2, 60) 	Local Epoch : 1 	Loss: 0.014084
# Timeout : (2, 60) 	Local Epoch : 2 	Loss: 0.013640
# Timeout : (2, 60) 	Local Epoch : 3 	Loss: 0.013461
# Timeout : (2, 60) 	Local Epoch : 4 	Loss: 0.013261
# Round   1, Average MLP loss 0.013
# Timeout : (4, 60) 	Local Epoch : 0 	Loss: 0.013775
# Timeout : (4, 60) 	Local Epoch : 1 	Loss: 0.013370
# Timeout : (4, 60) 	Local Epoch : 2 	Loss: 0.013174
# Timeout : (4, 60) 	Local Epoch : 3 	Loss: 0.013017
# Timeout : (4, 60) 	Local Epoch : 4 	Loss: 0.012888
# Timeout : (1, 2) 	Local Epoch : 0 	Loss: 0.012461
# Timeout : (1, 2) 	Local Epoch : 1 	Loss: 0.011750
# Timeout : (1, 2) 	Local Epoch : 2 	Loss: 0.011593
# Timeout : (1, 2) 	Local Epoch : 3 	Loss: 0.011381
# Timeout : (1, 2) 	Local Epoch : 4 	Loss: 0.011269
# Timeout : (0.5, 60) 	Local Epoch : 0 	Loss: 0.011782
# Timeout : (0.5, 60) 	Local Epoch : 1 	Loss: 0.011490
# Timeout : (0.5, 60) 	Local Epoch : 2 	Loss: 0.011322
# Timeout : (0.5, 60) 	Local Epoch : 3 	Loss: 0.011167
# Timeout : (0.5, 60) 	Local Epoch : 4 	Loss: 0.011088
# Timeout : (2, 60) 	Local Epoch : 0 	Loss: 0.013356
# Timeout : (2, 60) 	Local Epoch : 1 	Loss: 0.013081
# Timeout : (2, 60) 	Local Epoch : 2 	Loss: 0.012833
# Timeout : (2, 60) 	Local Epoch : 3 	Loss: 0.012744
# Timeout : (2, 60) 	Local Epoch : 4 	Loss: 0.012553
# Timeout : (3, 5) 	Local Epoch : 0 	Loss: 0.013219
# Timeout : (3, 5) 	Local Epoch : 1 	Loss: 0.013034
# Timeout : (3, 5) 	Local Epoch : 2 	Loss: 0.012741
# Timeout : (3, 5) 	Local Epoch : 3 	Loss: 0.012629
# Timeout : (3, 5) 	Local Epoch : 4 	Loss: 0.012498
# Timeout : (4, 30) 	Local Epoch : 0 	Loss: 0.013707
# Timeout : (4, 30) 	Local Epoch : 1 	Loss: 0.013388
# Timeout : (4, 30) 	Local Epoch : 2 	Loss: 0.013179
# Timeout : (4, 30) 	Local Epoch : 3 	Loss: 0.012940
# Timeout : (4, 30) 	Local Epoch : 4 	Loss: 0.012878
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.011755
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.011455
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.011317
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.011121
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.011078
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.012937
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.012673
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.012463
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.012343
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.012211
# Timeout : (3, 4) 	Local Epoch : 0 	Loss: 0.013091
# Timeout : (3, 4) 	Local Epoch : 1 	Loss: 0.012874
# Timeout : (3, 4) 	Local Epoch : 2 	Loss: 0.012771
# Timeout : (3, 4) 	Local Epoch : 3 	Loss: 0.012537
# Timeout : (3, 4) 	Local Epoch : 4 	Loss: 0.012484
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.012942
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.012603
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.012433
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.012231
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.012121
# Timeout : (2, 2) 	Local Epoch : 0 	Loss: 0.012378
# Timeout : (2, 2) 	Local Epoch : 1 	Loss: 0.011872
# Timeout : (2, 2) 	Local Epoch : 2 	Loss: 0.011602
# Timeout : (2, 2) 	Local Epoch : 3 	Loss: 0.011485
# Timeout : (2, 2) 	Local Epoch : 4 	Loss: 0.011349
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.013386
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.012966
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.012723
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.012607
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.012501
# Timeout : (0.5, 2) 	Local Epoch : 0 	Loss: 0.011954
# Timeout : (0.5, 2) 	Local Epoch : 1 	Loss: 0.011008
# Timeout : (0.5, 2) 	Local Epoch : 2 	Loss: 0.010826
# Timeout : (0.5, 2) 	Local Epoch : 3 	Loss: 0.010700
# Timeout : (0.5, 2) 	Local Epoch : 4 	Loss: 0.010566
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.013257
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.012836
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.012579
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.012451
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.012286
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.013039
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.012815
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.012619
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.012484
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.012324
# Timeout : (4, 5) 	Local Epoch : 0 	Loss: 0.013318
# Timeout : (4, 5) 	Local Epoch : 1 	Loss: 0.012972
# Timeout : (4, 5) 	Local Epoch : 2 	Loss: 0.012803
# Timeout : (4, 5) 	Local Epoch : 3 	Loss: 0.012596
# Timeout : (4, 5) 	Local Epoch : 4 	Loss: 0.012466
# Round   2, Average MLP loss 0.012
# Timeout : (5, 60) 	Local Epoch : 0 	Loss: 0.013673
# Timeout : (5, 60) 	Local Epoch : 1 	Loss: 0.012843
# Timeout : (5, 60) 	Local Epoch : 2 	Loss: 0.012679
# Timeout : (5, 60) 	Local Epoch : 3 	Loss: 0.012648
# Timeout : (5, 60) 	Local Epoch : 4 	Loss: 0.012465
# Timeout : (4, 30) 	Local Epoch : 0 	Loss: 0.013148
# Timeout : (4, 30) 	Local Epoch : 1 	Loss: 0.012727
# Timeout : (4, 30) 	Local Epoch : 2 	Loss: 0.012539
# Timeout : (4, 30) 	Local Epoch : 3 	Loss: 0.012504
# Timeout : (4, 30) 	Local Epoch : 4 	Loss: 0.012326
# Timeout : (4, 5) 	Local Epoch : 0 	Loss: 0.012575
# Timeout : (4, 5) 	Local Epoch : 1 	Loss: 0.012360
# Timeout : (4, 5) 	Local Epoch : 2 	Loss: 0.012131
# Timeout : (4, 5) 	Local Epoch : 3 	Loss: 0.012104
# Timeout : (4, 5) 	Local Epoch : 4 	Loss: 0.011914
# Timeout : (1, 2) 	Local Epoch : 0 	Loss: 0.011593
# Timeout : (1, 2) 	Local Epoch : 1 	Loss: 0.011186
# Timeout : (1, 2) 	Local Epoch : 2 	Loss: 0.011112
# Timeout : (1, 2) 	Local Epoch : 3 	Loss: 0.011045
# Timeout : (1, 2) 	Local Epoch : 4 	Loss: 0.011014
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.012238
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.012046
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.011856
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.011781
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.011733
# Timeout : (1, 3) 	Local Epoch : 0 	Loss: 0.012194
# Timeout : (1, 3) 	Local Epoch : 1 	Loss: 0.011988
# Timeout : (1, 3) 	Local Epoch : 2 	Loss: 0.011859
# Timeout : (1, 3) 	Local Epoch : 3 	Loss: 0.011781
# Timeout : (1, 3) 	Local Epoch : 4 	Loss: 0.011733
# Timeout : (0.5, 60) 	Local Epoch : 0 	Loss: 0.011227
# Timeout : (0.5, 60) 	Local Epoch : 1 	Loss: 0.011017
# Timeout : (0.5, 60) 	Local Epoch : 2 	Loss: 0.010975
# Timeout : (0.5, 60) 	Local Epoch : 3 	Loss: 0.010840
# Timeout : (0.5, 60) 	Local Epoch : 4 	Loss: 0.010785
# Timeout : (3, 4) 	Local Epoch : 0 	Loss: 0.012509
# Timeout : (3, 4) 	Local Epoch : 1 	Loss: 0.012287
# Timeout : (3, 4) 	Local Epoch : 2 	Loss: 0.012170
# Timeout : (3, 4) 	Local Epoch : 3 	Loss: 0.011981
# Timeout : (3, 4) 	Local Epoch : 4 	Loss: 0.011970
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.012271
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.012186
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.012019
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.011916
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.011904
# Timeout : (2, 4) 	Local Epoch : 0 	Loss: 0.012373
# Timeout : (2, 4) 	Local Epoch : 1 	Loss: 0.012153
# Timeout : (2, 4) 	Local Epoch : 2 	Loss: 0.012013
# Timeout : (2, 4) 	Local Epoch : 3 	Loss: 0.011981
# Timeout : (2, 4) 	Local Epoch : 4 	Loss: 0.011869
# Timeout : (5, 5) 	Local Epoch : 0 	Loss: 0.012922
# Timeout : (5, 5) 	Local Epoch : 1 	Loss: 0.012421
# Timeout : (5, 5) 	Local Epoch : 2 	Loss: 0.012217
# Timeout : (5, 5) 	Local Epoch : 3 	Loss: 0.012170
# Timeout : (5, 5) 	Local Epoch : 4 	Loss: 0.012000
# Timeout : (0.5, 30) 	Local Epoch : 0 	Loss: 0.011225
# Timeout : (0.5, 30) 	Local Epoch : 1 	Loss: 0.010966
# Timeout : (0.5, 30) 	Local Epoch : 2 	Loss: 0.010971
# Timeout : (0.5, 30) 	Local Epoch : 3 	Loss: 0.010826
# Timeout : (0.5, 30) 	Local Epoch : 4 	Loss: 0.010802
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.012623
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.012348
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.012224
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.012159
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.012047
# Timeout : (3, 5) 	Local Epoch : 0 	Loss: 0.012499
# Timeout : (3, 5) 	Local Epoch : 1 	Loss: 0.012301
# Timeout : (3, 5) 	Local Epoch : 2 	Loss: 0.012171
# Timeout : (3, 5) 	Local Epoch : 3 	Loss: 0.012066
# Timeout : (3, 5) 	Local Epoch : 4 	Loss: 0.011936
# Timeout : (3, 3) 	Local Epoch : 0 	Loss: 0.012247
# Timeout : (3, 3) 	Local Epoch : 1 	Loss: 0.012128
# Timeout : (3, 3) 	Local Epoch : 2 	Loss: 0.011978
# Timeout : (3, 3) 	Local Epoch : 3 	Loss: 0.011819
# Timeout : (3, 3) 	Local Epoch : 4 	Loss: 0.011716
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.012925
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.012667
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.012567
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.012412
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.012317
# Round   3, Average MLP loss 0.012
# Timeout : (1, 2) 	Local Epoch : 0 	Loss: 0.011373
# Timeout : (1, 2) 	Local Epoch : 1 	Loss: 0.010934
# Timeout : (1, 2) 	Local Epoch : 2 	Loss: 0.010843
# Timeout : (1, 2) 	Local Epoch : 3 	Loss: 0.010826
# Timeout : (1, 2) 	Local Epoch : 4 	Loss: 0.010721
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.012243
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.012134
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.011948
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.011836
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.011811
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.011994
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.011843
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.011711
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.011659
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.011669
# Timeout : (2, 60) 	Local Epoch : 0 	Loss: 0.012390
# Timeout : (2, 60) 	Local Epoch : 1 	Loss: 0.012068
# Timeout : (2, 60) 	Local Epoch : 2 	Loss: 0.011970
# Timeout : (2, 60) 	Local Epoch : 3 	Loss: 0.011867
# Timeout : (2, 60) 	Local Epoch : 4 	Loss: 0.011844
# Timeout : (1, 60) 	Local Epoch : 0 	Loss: 0.012159
# Timeout : (1, 60) 	Local Epoch : 1 	Loss: 0.011925
# Timeout : (1, 60) 	Local Epoch : 2 	Loss: 0.011916
# Timeout : (1, 60) 	Local Epoch : 3 	Loss: 0.011887
# Timeout : (1, 60) 	Local Epoch : 4 	Loss: 0.011774
# Timeout : (10, 30) 	Local Epoch : 0 	Loss: 0.015052
# Timeout : (10, 30) 	Local Epoch : 1 	Loss: 0.012866
# Timeout : (10, 30) 	Local Epoch : 2 	Loss: 0.012727
# Timeout : (10, 30) 	Local Epoch : 3 	Loss: 0.012706
# Timeout : (10, 30) 	Local Epoch : 4 	Loss: 0.012510
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.012552
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.012271
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.012108
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.012036
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.011908
# Timeout : (3, 30) 	Local Epoch : 0 	Loss: 0.012448
# Timeout : (3, 30) 	Local Epoch : 1 	Loss: 0.012178
# Timeout : (3, 30) 	Local Epoch : 2 	Loss: 0.012258
# Timeout : (3, 30) 	Local Epoch : 3 	Loss: 0.011955
# Timeout : (3, 30) 	Local Epoch : 4 	Loss: 0.011921
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.011857
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.011688
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.011538
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.011495
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.011511
# Timeout : (1, 3) 	Local Epoch : 0 	Loss: 0.011931
# Timeout : (1, 3) 	Local Epoch : 1 	Loss: 0.011657
# Timeout : (1, 3) 	Local Epoch : 2 	Loss: 0.011593
# Timeout : (1, 3) 	Local Epoch : 3 	Loss: 0.011541
# Timeout : (1, 3) 	Local Epoch : 4 	Loss: 0.011483
# Timeout : (0.5, 60) 	Local Epoch : 0 	Loss: 0.010983
# Timeout : (0.5, 60) 	Local Epoch : 1 	Loss: 0.010772
# Timeout : (0.5, 60) 	Local Epoch : 2 	Loss: 0.010685
# Timeout : (0.5, 60) 	Local Epoch : 3 	Loss: 0.010636
# Timeout : (0.5, 60) 	Local Epoch : 4 	Loss: 0.010636
# Timeout : (4, 4) 	Local Epoch : 0 	Loss: 0.012034
# Timeout : (4, 4) 	Local Epoch : 1 	Loss: 0.011844
# Timeout : (4, 4) 	Local Epoch : 2 	Loss: 0.011787
# Timeout : (4, 4) 	Local Epoch : 3 	Loss: 0.011702
# Timeout : (4, 4) 	Local Epoch : 4 	Loss: 0.011681
# Timeout : (5, 5) 	Local Epoch : 0 	Loss: 0.012484
# Timeout : (5, 5) 	Local Epoch : 1 	Loss: 0.011960
# Timeout : (5, 5) 	Local Epoch : 2 	Loss: 0.011799
# Timeout : (5, 5) 	Local Epoch : 3 	Loss: 0.011741
# Timeout : (5, 5) 	Local Epoch : 4 	Loss: 0.011695
# Timeout : (2, 4) 	Local Epoch : 0 	Loss: 0.011945
# Timeout : (2, 4) 	Local Epoch : 1 	Loss: 0.011755
# Timeout : (2, 4) 	Local Epoch : 2 	Loss: 0.011673
# Timeout : (2, 4) 	Local Epoch : 3 	Loss: 0.011610
# Timeout : (2, 4) 	Local Epoch : 4 	Loss: 0.011547
# Timeout : (4, 5) 	Local Epoch : 0 	Loss: 0.012148
# Timeout : (4, 5) 	Local Epoch : 1 	Loss: 0.011994
# Timeout : (4, 5) 	Local Epoch : 2 	Loss: 0.011820
# Timeout : (4, 5) 	Local Epoch : 3 	Loss: 0.011761
# Timeout : (4, 5) 	Local Epoch : 4 	Loss: 0.011744
# Timeout : (3, 3) 	Local Epoch : 0 	Loss: 0.011893
# Timeout : (3, 3) 	Local Epoch : 1 	Loss: 0.011686
# Timeout : (3, 3) 	Local Epoch : 2 	Loss: 0.011617
# Timeout : (3, 3) 	Local Epoch : 3 	Loss: 0.011548
# Timeout : (3, 3) 	Local Epoch : 4 	Loss: 0.011485
# Round   4, Average MLP loss 0.012
# Timeout : (1, 30) 	Local Epoch : 0 	Loss: 0.011922
# Timeout : (1, 30) 	Local Epoch : 1 	Loss: 0.011640
# Timeout : (1, 30) 	Local Epoch : 2 	Loss: 0.011653
# Timeout : (1, 30) 	Local Epoch : 3 	Loss: 0.011600
# Timeout : (1, 30) 	Local Epoch : 4 	Loss: 0.011595
# Timeout : (10, 60) 	Local Epoch : 0 	Loss: 0.014675
# Timeout : (10, 60) 	Local Epoch : 1 	Loss: 0.012753
# Timeout : (10, 60) 	Local Epoch : 2 	Loss: 0.012656
# Timeout : (10, 60) 	Local Epoch : 3 	Loss: 0.012473
# Timeout : (10, 60) 	Local Epoch : 4 	Loss: 0.012545
# Timeout : (4, 60) 	Local Epoch : 0 	Loss: 0.012229
# Timeout : (4, 60) 	Local Epoch : 1 	Loss: 0.012075
# Timeout : (4, 60) 	Local Epoch : 2 	Loss: 0.012026
# Timeout : (4, 60) 	Local Epoch : 3 	Loss: 0.011931
# Timeout : (4, 60) 	Local Epoch : 4 	Loss: 0.011997
# Timeout : (5, 60) 	Local Epoch : 0 	Loss: 0.012826
# Timeout : (5, 60) 	Local Epoch : 1 	Loss: 0.012075
# Timeout : (5, 60) 	Local Epoch : 2 	Loss: 0.012030
# Timeout : (5, 60) 	Local Epoch : 3 	Loss: 0.012102
# Timeout : (5, 60) 	Local Epoch : 4 	Loss: 0.011999
# Timeout : (10, 30) 	Local Epoch : 0 	Loss: 0.014030
# Timeout : (10, 30) 	Local Epoch : 1 	Loss: 0.012552
# Timeout : (10, 30) 	Local Epoch : 2 	Loss: 0.012452
# Timeout : (10, 30) 	Local Epoch : 3 	Loss: 0.012534
# Timeout : (10, 30) 	Local Epoch : 4 	Loss: 0.012279
# Timeout : (5, 5) 	Local Epoch : 0 	Loss: 0.012081
# Timeout : (5, 5) 	Local Epoch : 1 	Loss: 0.011713
# Timeout : (5, 5) 	Local Epoch : 2 	Loss: 0.011654
# Timeout : (5, 5) 	Local Epoch : 3 	Loss: 0.011596
# Timeout : (5, 5) 	Local Epoch : 4 	Loss: 0.011550
# Timeout : (0.5, 2) 	Local Epoch : 0 	Loss: 0.010525
# Timeout : (0.5, 2) 	Local Epoch : 1 	Loss: 0.010002
# Timeout : (0.5, 2) 	Local Epoch : 2 	Loss: 0.009966
# Timeout : (0.5, 2) 	Local Epoch : 3 	Loss: 0.009914
# Timeout : (0.5, 2) 	Local Epoch : 4 	Loss: 0.009896
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.010694
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.010538
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.010461
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.010355
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.010351
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.011710
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.011579
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.011572
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.011600
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.011499
# Timeout : (3, 4) 	Local Epoch : 0 	Loss: 0.011649
# Timeout : (3, 4) 	Local Epoch : 1 	Loss: 0.011534
# Timeout : (3, 4) 	Local Epoch : 2 	Loss: 0.011544
# Timeout : (3, 4) 	Local Epoch : 3 	Loss: 0.011469
# Timeout : (3, 4) 	Local Epoch : 4 	Loss: 0.011428
# Timeout : (3, 30) 	Local Epoch : 0 	Loss: 0.012092
# Timeout : (3, 30) 	Local Epoch : 1 	Loss: 0.011954
# Timeout : (3, 30) 	Local Epoch : 2 	Loss: 0.011859
# Timeout : (3, 30) 	Local Epoch : 3 	Loss: 0.011836
# Timeout : (3, 30) 	Local Epoch : 4 	Loss: 0.011788
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.011881
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.011781
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.011639
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.011644
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.011604
# Timeout : (1, 2) 	Local Epoch : 0 	Loss: 0.011096
# Timeout : (1, 2) 	Local Epoch : 1 	Loss: 0.010729
# Timeout : (1, 2) 	Local Epoch : 2 	Loss: 0.010707
# Timeout : (1, 2) 	Local Epoch : 3 	Loss: 0.010641
# Timeout : (1, 2) 	Local Epoch : 4 	Loss: 0.010535
# Timeout : (3, 5) 	Local Epoch : 0 	Loss: 0.011772
# Timeout : (3, 5) 	Local Epoch : 1 	Loss: 0.011598
# Timeout : (3, 5) 	Local Epoch : 2 	Loss: 0.011609
# Timeout : (3, 5) 	Local Epoch : 3 	Loss: 0.011504
# Timeout : (3, 5) 	Local Epoch : 4 	Loss: 0.011479
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.011769
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.011629
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.011582
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.011512
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.011477
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.012169
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.011985
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.011896
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.011876
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.011794
# Round   5, Average MLP loss 0.012
# Timeout : (3, 5) 	Local Epoch : 0 	Loss: 0.011641
# Timeout : (3, 5) 	Local Epoch : 1 	Loss: 0.011514
# Timeout : (3, 5) 	Local Epoch : 2 	Loss: 0.011466
# Timeout : (3, 5) 	Local Epoch : 3 	Loss: 0.011436
# Timeout : (3, 5) 	Local Epoch : 4 	Loss: 0.011327
# Timeout : (2, 2) 	Local Epoch : 0 	Loss: 0.010866
# Timeout : (2, 2) 	Local Epoch : 1 	Loss: 0.010589
# Timeout : (2, 2) 	Local Epoch : 2 	Loss: 0.010592
# Timeout : (2, 2) 	Local Epoch : 3 	Loss: 0.010496
# Timeout : (2, 2) 	Local Epoch : 4 	Loss: 0.010535
# Timeout : (0.5, 30) 	Local Epoch : 0 	Loss: 0.010613
# Timeout : (0.5, 30) 	Local Epoch : 1 	Loss: 0.010392
# Timeout : (0.5, 30) 	Local Epoch : 2 	Loss: 0.010363
# Timeout : (0.5, 30) 	Local Epoch : 3 	Loss: 0.010315
# Timeout : (0.5, 30) 	Local Epoch : 4 	Loss: 0.010324
# Timeout : (1, 3) 	Local Epoch : 0 	Loss: 0.011421
# Timeout : (1, 3) 	Local Epoch : 1 	Loss: 0.011371
# Timeout : (1, 3) 	Local Epoch : 2 	Loss: 0.011266
# Timeout : (1, 3) 	Local Epoch : 3 	Loss: 0.011238
# Timeout : (1, 3) 	Local Epoch : 4 	Loss: 0.011144
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.011493
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.011410
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.011341
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.011378
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.011250
# Timeout : (5, 60) 	Local Epoch : 0 	Loss: 0.012401
# Timeout : (5, 60) 	Local Epoch : 1 	Loss: 0.012010
# Timeout : (5, 60) 	Local Epoch : 2 	Loss: 0.011954
# Timeout : (5, 60) 	Local Epoch : 3 	Loss: 0.012042
# Timeout : (5, 60) 	Local Epoch : 4 	Loss: 0.011838
# Timeout : (0.5, 5) 	Local Epoch : 0 	Loss: 0.010533
# Timeout : (0.5, 5) 	Local Epoch : 1 	Loss: 0.010388
# Timeout : (0.5, 5) 	Local Epoch : 2 	Loss: 0.010310
# Timeout : (0.5, 5) 	Local Epoch : 3 	Loss: 0.010287
# Timeout : (0.5, 5) 	Local Epoch : 4 	Loss: 0.010235
# Timeout : (1, 30) 	Local Epoch : 0 	Loss: 0.011745
# Timeout : (1, 30) 	Local Epoch : 1 	Loss: 0.011524
# Timeout : (1, 30) 	Local Epoch : 2 	Loss: 0.011525
# Timeout : (1, 30) 	Local Epoch : 3 	Loss: 0.011537
# Timeout : (1, 30) 	Local Epoch : 4 	Loss: 0.011449
# Timeout : (1, 60) 	Local Epoch : 0 	Loss: 0.011678
# Timeout : (1, 60) 	Local Epoch : 1 	Loss: 0.011557
# Timeout : (1, 60) 	Local Epoch : 2 	Loss: 0.011507
# Timeout : (1, 60) 	Local Epoch : 3 	Loss: 0.011491
# Timeout : (1, 60) 	Local Epoch : 4 	Loss: 0.011485
# Timeout : (0.5, 2) 	Local Epoch : 0 	Loss: 0.010340
# Timeout : (0.5, 2) 	Local Epoch : 1 	Loss: 0.009843
# Timeout : (0.5, 2) 	Local Epoch : 2 	Loss: 0.009805
# Timeout : (0.5, 2) 	Local Epoch : 3 	Loss: 0.009761
# Timeout : (0.5, 2) 	Local Epoch : 4 	Loss: 0.009754
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.010583
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.010393
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.010336
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.010334
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.010213
# Timeout : (4, 60) 	Local Epoch : 0 	Loss: 0.012117
# Timeout : (4, 60) 	Local Epoch : 1 	Loss: 0.011869
# Timeout : (4, 60) 	Local Epoch : 2 	Loss: 0.011850
# Timeout : (4, 60) 	Local Epoch : 3 	Loss: 0.011829
# Timeout : (4, 60) 	Local Epoch : 4 	Loss: 0.011736
# Timeout : (0.5, 60) 	Local Epoch : 0 	Loss: 0.010571
# Timeout : (0.5, 60) 	Local Epoch : 1 	Loss: 0.010408
# Timeout : (0.5, 60) 	Local Epoch : 2 	Loss: 0.010386
# Timeout : (0.5, 60) 	Local Epoch : 3 	Loss: 0.010332
# Timeout : (0.5, 60) 	Local Epoch : 4 	Loss: 0.010269
# Timeout : (10, 30) 	Local Epoch : 0 	Loss: 0.013770
# Timeout : (10, 30) 	Local Epoch : 1 	Loss: 0.012428
# Timeout : (10, 30) 	Local Epoch : 2 	Loss: 0.012295
# Timeout : (10, 30) 	Local Epoch : 3 	Loss: 0.012279
# Timeout : (10, 30) 	Local Epoch : 4 	Loss: 0.012244
# Timeout : (10, 60) 	Local Epoch : 0 	Loss: 0.014109
# Timeout : (10, 60) 	Local Epoch : 1 	Loss: 0.012523
# Timeout : (10, 60) 	Local Epoch : 2 	Loss: 0.012401
# Timeout : (10, 60) 	Local Epoch : 3 	Loss: 0.012365
# Timeout : (10, 60) 	Local Epoch : 4 	Loss: 0.012326
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.011571
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.011487
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.011383
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.011390
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.011322
# Round   6, Average MLP loss 0.011
# Timeout : (0.5, 60) 	Local Epoch : 0 	Loss: 0.010386
# Timeout : (0.5, 60) 	Local Epoch : 1 	Loss: 0.010291
# Timeout : (0.5, 60) 	Local Epoch : 2 	Loss: 0.010240
# Timeout : (0.5, 60) 	Local Epoch : 3 	Loss: 0.010155
# Timeout : (0.5, 60) 	Local Epoch : 4 	Loss: 0.010156
# Timeout : (4, 5) 	Local Epoch : 0 	Loss: 0.011619
# Timeout : (4, 5) 	Local Epoch : 1 	Loss: 0.011477
# Timeout : (4, 5) 	Local Epoch : 2 	Loss: 0.011378
# Timeout : (4, 5) 	Local Epoch : 3 	Loss: 0.011304
# Timeout : (4, 5) 	Local Epoch : 4 	Loss: 0.011348
# Timeout : (5, 5) 	Local Epoch : 0 	Loss: 0.011959
# Timeout : (5, 5) 	Local Epoch : 1 	Loss: 0.011545
# Timeout : (5, 5) 	Local Epoch : 2 	Loss: 0.011372
# Timeout : (5, 5) 	Local Epoch : 3 	Loss: 0.011400
# Timeout : (5, 5) 	Local Epoch : 4 	Loss: 0.011330
# Timeout : (3, 30) 	Local Epoch : 0 	Loss: 0.011902
# Timeout : (3, 30) 	Local Epoch : 1 	Loss: 0.011794
# Timeout : (3, 30) 	Local Epoch : 2 	Loss: 0.011708
# Timeout : (3, 30) 	Local Epoch : 3 	Loss: 0.011670
# Timeout : (3, 30) 	Local Epoch : 4 	Loss: 0.011553
# Timeout : (1, 3) 	Local Epoch : 0 	Loss: 0.011215
# Timeout : (1, 3) 	Local Epoch : 1 	Loss: 0.011141
# Timeout : (1, 3) 	Local Epoch : 2 	Loss: 0.011189
# Timeout : (1, 3) 	Local Epoch : 3 	Loss: 0.011079
# Timeout : (1, 3) 	Local Epoch : 4 	Loss: 0.011075
# Timeout : (4, 60) 	Local Epoch : 0 	Loss: 0.012100
# Timeout : (4, 60) 	Local Epoch : 1 	Loss: 0.011824
# Timeout : (4, 60) 	Local Epoch : 2 	Loss: 0.011752
# Timeout : (4, 60) 	Local Epoch : 3 	Loss: 0.011679
# Timeout : (4, 60) 	Local Epoch : 4 	Loss: 0.011750
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.011367
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.011226
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.011176
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.011133
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.011118
# Timeout : (10, 30) 	Local Epoch : 0 	Loss: 0.013882
# Timeout : (10, 30) 	Local Epoch : 1 	Loss: 0.012373
# Timeout : (10, 30) 	Local Epoch : 2 	Loss: 0.012470
# Timeout : (10, 30) 	Local Epoch : 3 	Loss: 0.012188
# Timeout : (10, 30) 	Local Epoch : 4 	Loss: 0.012110
# Timeout : (0.5, 3) 	Local Epoch : 0 	Loss: 0.010340
# Timeout : (0.5, 3) 	Local Epoch : 1 	Loss: 0.010276
# Timeout : (0.5, 3) 	Local Epoch : 2 	Loss: 0.010189
# Timeout : (0.5, 3) 	Local Epoch : 3 	Loss: 0.010159
# Timeout : (0.5, 3) 	Local Epoch : 4 	Loss: 0.010078
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.011538
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.011354
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.011323
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.011283
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.011265
# Timeout : (0.5, 2) 	Local Epoch : 0 	Loss: 0.010030
# Timeout : (0.5, 2) 	Local Epoch : 1 	Loss: 0.009787
# Timeout : (0.5, 2) 	Local Epoch : 2 	Loss: 0.009764
# Timeout : (0.5, 2) 	Local Epoch : 3 	Loss: 0.009711
# Timeout : (0.5, 2) 	Local Epoch : 4 	Loss: 0.009685
# Timeout : (10, 60) 	Local Epoch : 0 	Loss: 0.014363
# Timeout : (10, 60) 	Local Epoch : 1 	Loss: 0.012584
# Timeout : (10, 60) 	Local Epoch : 2 	Loss: 0.012341
# Timeout : (10, 60) 	Local Epoch : 3 	Loss: 0.012244
# Timeout : (10, 60) 	Local Epoch : 4 	Loss: 0.012235
# Timeout : (2, 4) 	Local Epoch : 0 	Loss: 0.011438
# Timeout : (2, 4) 	Local Epoch : 1 	Loss: 0.011299
# Timeout : (2, 4) 	Local Epoch : 2 	Loss: 0.011231
# Timeout : (2, 4) 	Local Epoch : 3 	Loss: 0.011207
# Timeout : (2, 4) 	Local Epoch : 4 	Loss: 0.011126
# Timeout : (2, 30) 	Local Epoch : 0 	Loss: 0.011685
# Timeout : (2, 30) 	Local Epoch : 1 	Loss: 0.011465
# Timeout : (2, 30) 	Local Epoch : 2 	Loss: 0.011448
# Timeout : (2, 30) 	Local Epoch : 3 	Loss: 0.011850
# Timeout : (2, 30) 	Local Epoch : 4 	Loss: 0.011451
# Timeout : (1, 30) 	Local Epoch : 0 	Loss: 0.011504
# Timeout : (1, 30) 	Local Epoch : 1 	Loss: 0.011425
# Timeout : (1, 30) 	Local Epoch : 2 	Loss: 0.011381
# Timeout : (1, 30) 	Local Epoch : 3 	Loss: 0.011318
# Timeout : (1, 30) 	Local Epoch : 4 	Loss: 0.011299
# Timeout : (4, 4) 	Local Epoch : 0 	Loss: 0.011608
# Timeout : (4, 4) 	Local Epoch : 1 	Loss: 0.011408
# Timeout : (4, 4) 	Local Epoch : 2 	Loss: 0.011279
# Timeout : (4, 4) 	Local Epoch : 3 	Loss: 0.011245
# Timeout : (4, 4) 	Local Epoch : 4 	Loss: 0.011235
# Round   7, Average MLP loss 0.011
# Timeout : (3, 60) 	Local Epoch : 0 	Loss: 0.011761
# Timeout : (3, 60) 	Local Epoch : 1 	Loss: 0.011681
# Timeout : (3, 60) 	Local Epoch : 2 	Loss: 0.011560
# Timeout : (3, 60) 	Local Epoch : 3 	Loss: 0.011577
# Timeout : (3, 60) 	Local Epoch : 4 	Loss: 0.011462
# Timeout : (2, 4) 	Local Epoch : 0 	Loss: 0.011246
# Timeout : (2, 4) 	Local Epoch : 1 	Loss: 0.011124
# Timeout : (2, 4) 	Local Epoch : 2 	Loss: 0.011211
# Timeout : (2, 4) 	Local Epoch : 3 	Loss: 0.011087
# Timeout : (2, 4) 	Local Epoch : 4 	Loss: 0.011089
# Timeout : (5, 60) 	Local Epoch : 0 	Loss: 0.012167
# Timeout : (5, 60) 	Local Epoch : 1 	Loss: 0.011765
# Timeout : (5, 60) 	Local Epoch : 2 	Loss: 0.011707
# Timeout : (5, 60) 	Local Epoch : 3 	Loss: 0.011689
# Timeout : (5, 60) 	Local Epoch : 4 	Loss: 0.011627
# Timeout : (5, 30) 	Local Epoch : 0 	Loss: 0.012080
# Timeout : (5, 30) 	Local Epoch : 1 	Loss: 0.011740
# Timeout : (5, 30) 	Local Epoch : 2 	Loss: 0.011736
# Timeout : (5, 30) 	Local Epoch : 3 	Loss: 0.011642
# Timeout : (5, 30) 	Local Epoch : 4 	Loss: 0.011648
# Timeout : (2, 60) 	Local Epoch : 0 	Loss: 0.011575
# Timeout : (2, 60) 	Local Epoch : 1 	Loss: 0.011430
# Timeout : (2, 60) 	Local Epoch : 2 	Loss: 0.011286
# Timeout : (2, 60) 	Local Epoch : 3 	Loss: 0.011256
# Timeout : (2, 60) 	Local Epoch : 4 	Loss: 0.011290
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.011240
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.011165
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.011034
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.010998
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.010958
# Timeout : (2, 2) 	Local Epoch : 0 	Loss: 0.010859
# Timeout : (2, 2) 	Local Epoch : 1 	Loss: 0.010355
# Timeout : (2, 2) 	Local Epoch : 2 	Loss: 0.010375
# Timeout : (2, 2) 	Local Epoch : 3 	Loss: 0.010262
# Timeout : (2, 2) 	Local Epoch : 4 	Loss: 0.010200
# Timeout : (4, 30) 	Local Epoch : 0 	Loss: 0.011768
# Timeout : (4, 30) 	Local Epoch : 1 	Loss: 0.011633
# Timeout : (4, 30) 	Local Epoch : 2 	Loss: 0.011516
# Timeout : (4, 30) 	Local Epoch : 3 	Loss: 0.011538
# Timeout : (4, 30) 	Local Epoch : 4 	Loss: 0.011689
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.011272
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.011156
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.011111
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.011071
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.011013
# Timeout : (2, 5) 	Local Epoch : 0 	Loss: 0.011366
# Timeout : (2, 5) 	Local Epoch : 1 	Loss: 0.011283
# Timeout : (2, 5) 	Local Epoch : 2 	Loss: 0.011287
# Timeout : (2, 5) 	Local Epoch : 3 	Loss: 0.011149
# Timeout : (2, 5) 	Local Epoch : 4 	Loss: 0.011143
# Timeout : (4, 5) 	Local Epoch : 0 	Loss: 0.011370
# Timeout : (4, 5) 	Local Epoch : 1 	Loss: 0.011299
# Timeout : (4, 5) 	Local Epoch : 2 	Loss: 0.011248
# Timeout : (4, 5) 	Local Epoch : 3 	Loss: 0.011239
# Timeout : (4, 5) 	Local Epoch : 4 	Loss: 0.011200
# Timeout : (0.5, 30) 	Local Epoch : 0 	Loss: 0.010331
# Timeout : (0.5, 30) 	Local Epoch : 1 	Loss: 0.010158
# Timeout : (0.5, 30) 	Local Epoch : 2 	Loss: 0.010114
# Timeout : (0.5, 30) 	Local Epoch : 3 	Loss: 0.010059
# Timeout : (0.5, 30) 	Local Epoch : 4 	Loss: 0.010132
# Timeout : (3, 30) 	Local Epoch : 0 	Loss: 0.011752
# Timeout : (3, 30) 	Local Epoch : 1 	Loss: 0.011662
# Timeout : (3, 30) 	Local Epoch : 2 	Loss: 0.011527
# Timeout : (3, 30) 	Local Epoch : 3 	Loss: 0.011512
# Timeout : (3, 30) 	Local Epoch : 4 	Loss: 0.011453
# Timeout : (0.5, 5) 	Local Epoch : 0 	Loss: 0.010290
# Timeout : (0.5, 5) 	Local Epoch : 1 	Loss: 0.010141
# Timeout : (0.5, 5) 	Local Epoch : 2 	Loss: 0.010132
# Timeout : (0.5, 5) 	Local Epoch : 3 	Loss: 0.010087
# Timeout : (0.5, 5) 	Local Epoch : 4 	Loss: 0.010027
# Timeout : (3, 3) 	Local Epoch : 0 	Loss: 0.011237
# Timeout : (3, 3) 	Local Epoch : 1 	Loss: 0.011118
# Timeout : (3, 3) 	Local Epoch : 2 	Loss: 0.011062
# Timeout : (3, 3) 	Local Epoch : 3 	Loss: 0.010962
# Timeout : (3, 3) 	Local Epoch : 4 	Loss: 0.011017
# Timeout : (1, 30) 	Local Epoch : 0 	Loss: 0.011401
# Timeout : (1, 30) 	Local Epoch : 1 	Loss: 0.011279
# Timeout : (1, 30) 	Local Epoch : 2 	Loss: 0.011218
# Timeout : (1, 30) 	Local Epoch : 3 	Loss: 0.011267
# Timeout : (1, 30) 	Local Epoch : 4 	Loss: 0.011221
# Round   8, Average MLP loss 0.011
# Timeout : (3, 3) 	Local Epoch : 0 	Loss: 0.011070
# Timeout : (3, 3) 	Local Epoch : 1 	Loss: 0.011014
# Timeout : (3, 3) 	Local Epoch : 2 	Loss: 0.010955
# Timeout : (3, 3) 	Local Epoch : 3 	Loss: 0.010921
# Timeout : (3, 3) 	Local Epoch : 4 	Loss: 0.010905
# Timeout : (5, 30) 	Local Epoch : 0 	Loss: 0.011970
# Timeout : (5, 30) 	Local Epoch : 1 	Loss: 0.011670
# Timeout : (5, 30) 	Local Epoch : 2 	Loss: 0.011569
# Timeout : (5, 30) 	Local Epoch : 3 	Loss: 0.011532
# Timeout : (5, 30) 	Local Epoch : 4 	Loss: 0.011530
# Timeout : (1, 60) 	Local Epoch : 0 	Loss: 0.011294
# Timeout : (1, 60) 	Local Epoch : 1 	Loss: 0.011252
# Timeout : (1, 60) 	Local Epoch : 2 	Loss: 0.011244
# Timeout : (1, 60) 	Local Epoch : 3 	Loss: 0.011117
# Timeout : (1, 60) 	Local Epoch : 4 	Loss: 0.011082
# Timeout : (4, 4) 	Local Epoch : 0 	Loss: 0.011196
# Timeout : (4, 4) 	Local Epoch : 1 	Loss: 0.011092
# Timeout : (4, 4) 	Local Epoch : 2 	Loss: 0.011147
# Timeout : (4, 4) 	Local Epoch : 3 	Loss: 0.011079
# Timeout : (4, 4) 	Local Epoch : 4 	Loss: 0.011072
# Timeout : (3, 4) 	Local Epoch : 0 	Loss: 0.011176
# Timeout : (3, 4) 	Local Epoch : 1 	Loss: 0.011107
# Timeout : (3, 4) 	Local Epoch : 2 	Loss: 0.011045
# Timeout : (3, 4) 	Local Epoch : 3 	Loss: 0.010952
# Timeout : (3, 4) 	Local Epoch : 4 	Loss: 0.011038
# Timeout : (0.5, 2) 	Local Epoch : 0 	Loss: 0.010082
# Timeout : (0.5, 2) 	Local Epoch : 1 	Loss: 0.009581
# Timeout : (0.5, 2) 	Local Epoch : 2 	Loss: 0.009495
# Timeout : (0.5, 2) 	Local Epoch : 3 	Loss: 0.009571
# Timeout : (0.5, 2) 	Local Epoch : 4 	Loss: 0.009443
# Timeout : (1, 5) 	Local Epoch : 0 	Loss: 0.011142
# Timeout : (1, 5) 	Local Epoch : 1 	Loss: 0.011088
# Timeout : (1, 5) 	Local Epoch : 2 	Loss: 0.011055
# Timeout : (1, 5) 	Local Epoch : 3 	Loss: 0.011021
# Timeout : (1, 5) 	Local Epoch : 4 	Loss: 0.010973
# Timeout : (0.5, 4) 	Local Epoch : 0 	Loss: 0.010218
# Timeout : (0.5, 4) 	Local Epoch : 1 	Loss: 0.010037
# Timeout : (0.5, 4) 	Local Epoch : 2 	Loss: 0.009989
# Timeout : (0.5, 4) 	Local Epoch : 3 	Loss: 0.009963
# Timeout : (0.5, 4) 	Local Epoch : 4 	Loss: 0.009923
# Timeout : (1, 2) 	Local Epoch : 0 	Loss: 0.010752
# Timeout : (1, 2) 	Local Epoch : 1 	Loss: 0.010270
# Timeout : (1, 2) 	Local Epoch : 2 	Loss: 0.010236
# Timeout : (1, 2) 	Local Epoch : 3 	Loss: 0.010182
# Timeout : (1, 2) 	Local Epoch : 4 	Loss: 0.010182
# Timeout : (0.5, 30) 	Local Epoch : 0 	Loss: 0.010280
# Timeout : (0.5, 30) 	Local Epoch : 1 	Loss: 0.010099
# Timeout : (0.5, 30) 	Local Epoch : 2 	Loss: 0.010011
# Timeout : (0.5, 30) 	Local Epoch : 3 	Loss: 0.009947
# Timeout : (0.5, 30) 	Local Epoch : 4 	Loss: 0.009942
# Timeout : (2, 3) 	Local Epoch : 0 	Loss: 0.011063
# Timeout : (2, 3) 	Local Epoch : 1 	Loss: 0.010960
# Timeout : (2, 3) 	Local Epoch : 2 	Loss: 0.010930
# Timeout : (2, 3) 	Local Epoch : 3 	Loss: 0.010871
# Timeout : (2, 3) 	Local Epoch : 4 	Loss: 0.010868
# Timeout : (10, 30) 	Local Epoch : 0 	Loss: 0.013805
# Timeout : (10, 30) 	Local Epoch : 1 	Loss: 0.012209
# Timeout : (10, 30) 	Local Epoch : 2 	Loss: 0.012088
# Timeout : (10, 30) 	Local Epoch : 3 	Loss: 0.012032
# Timeout : (10, 30) 	Local Epoch : 4 	Loss: 0.011955
# Timeout : (2, 4) 	Local Epoch : 0 	Loss: 0.011149
# Timeout : (2, 4) 	Local Epoch : 1 	Loss: 0.011120
# Timeout : (2, 4) 	Local Epoch : 2 	Loss: 0.011143
# Timeout : (2, 4) 	Local Epoch : 3 	Loss: 0.011018
# Timeout : (2, 4) 	Local Epoch : 4 	Loss: 0.010953
# Timeout : (3, 5) 	Local Epoch : 0 	Loss: 0.011275
# Timeout : (3, 5) 	Local Epoch : 1 	Loss: 0.011122
# Timeout : (3, 5) 	Local Epoch : 2 	Loss: 0.011123
# Timeout : (3, 5) 	Local Epoch : 3 	Loss: 0.011111
# Timeout : (3, 5) 	Local Epoch : 4 	Loss: 0.011045
# Timeout : (1, 4) 	Local Epoch : 0 	Loss: 0.011119
# Timeout : (1, 4) 	Local Epoch : 1 	Loss: 0.011000
# Timeout : (1, 4) 	Local Epoch : 2 	Loss: 0.011006
# Timeout : (1, 4) 	Local Epoch : 3 	Loss: 0.010987
# Timeout : (1, 4) 	Local Epoch : 4 	Loss: 0.010966
# Timeout : (4, 5) 	Local Epoch : 0 	Loss: 0.011290
# Timeout : (4, 5) 	Local Epoch : 1 	Loss: 0.011182
# Timeout : (4, 5) 	Local Epoch : 2 	Loss: 0.011188
# Timeout : (4, 5) 	Local Epoch : 3 	Loss: 0.011208
# Timeout : (4, 5) 	Local Epoch : 4 	Loss: 0.011254
# Round   9, Average MLP loss 0.011

# %% [markdown]
# # Testing the global model on the combined test set of all clients

# %%
X_test, y_test = None, None
all_accuracy, all_f1Score, all_recall, all_precision = {}, {}, {}, {}

for i, timeout in enumerate(timeouts):
    if i == 0:
        X_test = np.load(os.path.join('../../data/CUPID/baselineFeatures/X_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
        y_test = np.load(os.path.join('../../data/CUPID/baselineFeatures/y_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
    else:
        X = np.load(os.path.join('../../data/CUPID/baselineFeatures/X_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
        y = np.load(os.path.join('../../data/CUPID/baselineFeatures/y_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
        X_test = np.concatenate((X_test, X), axis=0)
        y_test = np.concatenate((y_test, y), axis=0)

# %%
X_test.shape, y_test.shape
# Out:
# ((37460433, 57), (37460433,))

# %%
#from models.evaluate import get_thr #,evaluate_ae
import numpy as np
from sklearn.metrics import classification_report
import torch.nn as nn
import torch
from torch.utils.data import DataLoader, TensorDataset
import tqdm

# ------------------ Start Testing ----------------------#
print("Testing ... ")
test_dataset = torch.utils.data.TensorDataset(torch.Tensor(X_test), torch.Tensor(y_test))
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True, drop_last=True)


def test(config, model, test_loader):


    model.eval()

    history = {
        'test': {
            'total': 0,
            'loss': 0.0,
            'accuracy': 0.0,
            'output_pred': [],
            'output_true': [],
            'output_pred_prob': []
        }
    }

    test_loss = 0.0
    test_steps = 0
    test_total = 0
    test_correct = 0

    test_output_pred = []
    test_output_true = []
    test_output_pred_prob = []
    
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            inputs, labels = inputs.to(config.device), labels.type(torch.LongTensor).to(config.device)
            #labels = labels.squeeze(1)

            outputs = model(inputs)
            
            loss = criterion(outputs, labels)
            test_loss += loss.cpu().item()
            test_steps += 1

            _, predicted = torch.max(outputs.data, 1)
            test_total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

            test_output_pred += outputs.argmax(1).cpu().tolist()
            test_output_true += labels.tolist()
            test_output_pred_prob += nn.functional.softmax(outputs, dim=0).cpu().tolist()

    history['test']['total'] = test_total
    history['test']['loss'] = test_loss/test_steps
    history['test']['accuracy'] = test_correct/test_total
    history['test']['output_pred'] = test_output_pred
    history['test']['output_true'] = test_output_true
    history['test']['output_pred_prob'] = test_output_pred_prob

    return history

history=test(config, net_glob, test_loader)
# Out:
# Testing ...

# %%
test_output_true = history['test']['output_true']
test_output_pred = history['test']['output_pred']
test_output_pred_prob = history['test']['output_pred_prob']


print("Testing Set -- Classification Report", end="\n\n")
print(classification_report(test_output_true, test_output_pred, target_names=classes))
# Out:
# Testing Set -- Classification Report
#
#                  precision    recall  f1-score   support
#
#          Benign       0.99      0.99      0.99  30148353
#          Bonesi       1.00      0.87      0.93   2325025
# DVWA Pentesting       1.00      0.97      0.98   1221857
#          Dnsmap       0.83      0.67      0.74      3667
#     Manual DVWA       0.87      0.96      0.92   2301187
#            Nmap       1.00      1.00      1.00   1460327
#
#        accuracy                           0.98  37460416
#       macro avg       0.95      0.91      0.93  37460416
#    weighted avg       0.98      0.98      0.98  37460416

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, auc, roc_curve


acc = accuracy_score(test_output_true, test_output_pred)
precision = precision_score(test_output_true, test_output_pred, average='macro')
recall = recall_score(test_output_true, test_output_pred, average='macro')
f1Score = f1_score(test_output_true, test_output_pred, average='macro')

print('\nAccuracy: {:.4f}\n'.format(acc))

print('Macro Precision: {:.4f}'.format(precision))
print('Macro Recall: {:.4f}'.format(recall))
print('Macro F1-score: {:.4f}\n'.format(f1Score))

all_accuracy["all_test_sets"] = acc
all_precision["all_test_sets"] = precision
all_recall["all_test_sets"] = recall
all_f1Score["all_test_sets"] = f1Score
# Out:
# Accuracy: 0.9798
#
# Macro Precision: 0.9484
# Macro Recall: 0.9098
# Macro F1-score: 0.9265

# %% [markdown]
# # Testing the global model on the each client seperatly

# %%
X_test, y_test = None, None
for i, timeout in enumerate(timeouts):
    X_test = np.load(os.path.join('../../data/CUPID/baselineFeatures/X_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
    y_test = np.load(os.path.join('../../data/CUPID/baselineFeatures/y_train_'+ str(timeout[0])+ str('-') + str(timeout[1])+ '.npy'), mmap_mode='r')
    test_dataset = torch.utils.data.TensorDataset(torch.Tensor(X_test), torch.Tensor(y_test))
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True, drop_last=True)
    
    history=test(config, net_glob, test_loader)

    test_output_true = history['test']['output_true']
    test_output_pred = history['test']['output_pred']
    test_output_pred_prob = history['test']['output_pred_prob']

    all_accuracy[str(timeout)] = accuracy_score(test_output_true, test_output_pred)
    all_f1Score[str(timeout)] = f1_score(test_output_true, test_output_pred, average='macro')  
    all_precision[str(timeout)] = precision_score(test_output_true, test_output_pred, average='macro')
    all_recall[str(timeout)] = recall_score(test_output_true, test_output_pred, average='macro')
    
    print("Timenout : {} \tAccuracy={:.4f} \tF1_score={:.4f}".format(timeout, all_accuracy[str(timeout)], all_f1Score[str(timeout)]))
# Out:
# Timenout : (0.5, 2) 	Accuracy=0.9278 	F1_score=0.8260
# Timenout : (1, 2) 	Accuracy=0.9220 	F1_score=0.8513
# Timenout : (2, 2) 	Accuracy=0.9193 	F1_score=0.8437
# Timenout : (0.5, 3) 	Accuracy=0.9974 	F1_score=0.8635
# Timenout : (1, 3) 	Accuracy=0.9974 	F1_score=0.9607
# Timenout : (2, 3) 	Accuracy=0.9974 	F1_score=0.9509
# Timenout : (3, 3) 	Accuracy=0.9973 	F1_score=0.9576
# Timenout : (0.5, 4) 	Accuracy=0.9974 	F1_score=0.8635
# Timenout : (1, 4) 	Accuracy=0.9974 	F1_score=0.9607
# Timenout : (2, 4) 	Accuracy=0.9973 	F1_score=0.9551
# Timenout : (3, 4) 	Accuracy=0.9973 	F1_score=0.9641
# Timenout : (4, 4) 	Accuracy=0.9973 	F1_score=0.9638
# Timenout : (0.5, 5) 	Accuracy=0.9973 	F1_score=0.8635
# Timenout : (1, 5) 	Accuracy=0.9974 	F1_score=0.9607
# Timenout : (2, 5) 	Accuracy=0.9974 	F1_score=0.9551
# Timenout : (3, 5) 	Accuracy=0.9973 	F1_score=0.9661
# Timenout : (4, 5) 	Accuracy=0.9973 	F1_score=0.9660
# Timenout : (5, 5) 	Accuracy=0.9967 	F1_score=0.9685
# Timenout : (0.5, 30) 	Accuracy=0.9973 	F1_score=0.9330
# Timenout : (1, 30) 	Accuracy=0.9973 	F1_score=0.9590
# Timenout : (2, 30) 	Accuracy=0.9896 	F1_score=0.9451
# Timenout : (3, 30) 	Accuracy=0.9738 	F1_score=0.9367
# Timenout : (4, 30) 	Accuracy=0.9725 	F1_score=0.9494
# Timenout : (5, 30) 	Accuracy=0.9706 	F1_score=0.9487
# Timenout : (10, 30) 	Accuracy=0.9210 	F1_score=0.7611
# Timenout : (0.5, 60) 	Accuracy=0.9973 	F1_score=0.9329
# Timenout : (1, 60) 	Accuracy=0.9973 	F1_score=0.9590
# Timenout : (2, 60) 	Accuracy=0.9814 	F1_score=0.9357
# Timenout : (3, 60) 	Accuracy=0.9729 	F1_score=0.9362
# Timenout : (4, 60) 	Accuracy=0.9718 	F1_score=0.9389
# Timenout : (5, 60) 	Accuracy=0.9523 	F1_score=0.9311
# Timenout : (10, 60) 	Accuracy=0.9176 	F1_score=0.7582

# %%
results = {"accuracy": all_accuracy, "f1Score":all_f1Score, "precision": all_precision, "recall":all_recall}

import json
with open('../../save/results/CUPID/{}_{}_E[{}]_R[{}].json'.format(config.dataset, config.model, config.local_ep,config.epochs), 'w') as f:
    json.dump(results, f)

# %%
import matplotlib.pyplot as plt
import json
plt.figure(figsize=(14, 10))


load_json=True
if load_json:
    f = open('../../save/results/CUPID/addFeatures/cupid_MLP_E[5]_R[10].json')
    results = json.load(f)
    f.close()
    

time = timeouts = ["All", "(0.5,2)", "(1, 2)", "(2,2)","(0.5,3)", "(1,3)", "(2, 3)", "(3,3)", "(0.5,4)", "(1, 4)", "(2,4)", "(3,4)", "(4,4)", "(0.5,5)", "(1,5)", "(2,5)", "(3,5)",
                   "(4,5)", "(5,5)", "(0.5, 30)", "(1, 30)", "(2,30)", "(3,30)", "(4,30)", "(5,30)", "(10, 30)", "(0.5, 60)", "(1, 60)", "(2,60)", "(3,60)", "(4,60)", "(5,60)", "(10, 60)"]

acc= list(results["accuracy"].values())
print(time)

bars = plt.barh(time, acc, height = 0.8, color='steelblue')
plt.tick_params(axis='y', labelsize=12)
plt.tick_params(axis='x', labelsize=12)
bars[0].set_color('chocolate')
plt.ylabel('Timeouts', fontsize=18)
#plt.xlabel('Accuracy')
#plt.title('F1-score for each timeout')
#plt.grid(which="major", axis="both", linestyle='-', linewidth=0.5)
plt.savefig("../../save/plts/CUPID/FL_cupid_acc.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# ['All', '(0.5,2)', '(1, 2)', '(2,2)', '(0.5,3)', '(1,3)', '(2, 3)', '(3,3)', '(0.5,4)', '(1, 4)', '(2,4)', '(3,4)', '(4,4)', '(0.5,5)', '(1,5)', '(2,5)', '(3,5)', '(4,5)', '(5,5)', '(0.5, 30)', '(1, 30)', '(2,30)', '(3,30)', '(4,30)', '(5,30)', '(10, 30)', '(0.5, 60)', '(1, 60)', '(2,60)', '(3,60)', '(4,60)', '(5,60)', '(10, 60)']

# %%
plt.figure(figsize=(14, 10))

f1_score= list(results["f1Score"].values())

bars = plt.barh(time, f1_score, height = 0.8, color='steelblue')
plt.tick_params(axis='y', labelsize=12)
plt.tick_params(axis='x', labelsize=12)
bars[0].set_color('chocolate')
plt.ylabel('Timeouts', fontsize=18)
#plt.xlabel('F1-score')
#plt.title('F1-score for each timeout')
#plt.grid(which="major", axis="both", linestyle='-', linewidth=0.5)
plt.savefig("../../save/plts/CUPID/FL_cupid_f1.pdf", format="pdf", bbox_inches="tight")
plt.show()
