# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, f1_score, accuracy_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, auc, roc_curve
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.outliers_influence import variance_inflation_factor  
import warnings
import pickle
import os
import json

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %%
out_dir = f'/home/meryem.janati/lustre/nlp_team-um6p-st-sccs-id7fz1zvotk/IDS/janati/IDS/Datasets/cupid/Argus/timeout60'
df = pd.read_csv(out_dir+"/CUPID_argus_60.csv")
df.head()
# Out:
#      SrcId  Rank        StartTime         LastTime  Trans        Flgs  Seq  \
# 0  0.0.0.0   NaN  20:47:06.050091  20:47:06.049301    NaN                0
# 1  0.0.0.0   1.0  04:26:15.987722  04:26:15.988693    1.0   * r          1
# 2  0.0.0.0   2.0  04:26:16.642721  04:26:20.375668    1.0   * *          2
# 3  0.0.0.0   3.0  04:26:16.698657  04:26:16.701755    1.0   * * t        3
# 4  0.0.0.0   4.0  04:26:16.712642  04:26:16.714416    1.0   * * t        4
#
#         Dur   RunTime      IdleTime      Mean  StdDev       Sum       Min  \
# 0  0.000790       NaN           NaN       NaN     NaN       NaN       NaN
# 1  0.000971  0.000971  1.725911e+09  0.000971     0.0  0.000971  0.000971
# 2  3.732947  3.732947  1.725911e+09  3.732947     0.0  3.732947  3.732947
# 3  0.003098  0.003098  1.725911e+09  0.003098     0.0  0.003098  0.003098
# 4  0.001774  0.001774  1.725911e+09  0.001774     0.0  0.001774  0.001774
#
#         Max  SrcMac  DstMac  SrcOui  DstOui      SrcAddr      DstAddr Proto  \
# 0       NaN     NaN     NaN     NaN     NaN            0            0   man
# 1  0.000971     NaN     NaN     NaN     NaN  192.168.1.9  192.168.1.7   tcp
# 2  3.732947     NaN     NaN     NaN     NaN  192.168.1.9  192.168.1.7   tcp
# 3  0.003098     NaN     NaN     NaN     NaN  192.168.1.9  192.168.1.7   tcp
# 4  0.001774     NaN     NaN     NaN     NaN  192.168.1.9  192.168.1.7   tcp
#
#    Sport     Dport  sTos  dTos sDSb dDSb  sCo  dCo   sTtl   dTtl  sHops  \
# 0      0         0   NaN   NaN  NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 1   7749      ldap   0.0   2.0  cs0  cs0  NaN  NaN  128.0  128.0    0.0
# 2  11106      ldap   0.0   2.0  cs0  cs0  NaN  NaN  128.0  128.0    0.0
# 3  12667  kerberos   0.0   0.0  cs0  cs0  NaN  NaN  128.0  128.0    0.0
# 4  12669  kerberos   0.0   0.0  cs0  cs0  NaN  NaN  128.0  128.0    0.0
#
#    dHops   sIpId   dIpId  sMpls  dMpls  AutoId  sAS  dAS  iAS  Cause  NStrok  \
# 0    NaN     NaN     NaN    NaN    NaN       0  NaN  NaN  NaN  Start     NaN
# 1    0.0  0x7e0a  0xc931    NaN    NaN       0  NaN  NaN  NaN  Start     NaN
# 2    0.0  0x0b0c  0xb533    NaN    NaN       0  NaN  NaN  NaN  Start     NaN
# 3    0.0  0x870a  0xd431    NaN    NaN       0  NaN  NaN  NaN  Start     NaN
# 4    0.0  0x8c0a  0xd931    NaN    NaN       0  NaN  NaN  NaN  Start     NaN
#
#    sNStrok  dNStrok  TotPkts  SrcPkts  DstPkts  TotBytes  SrcBytes  DstBytes  \
# 0      NaN      NaN        0        0        0         0         0         0
# 1      NaN      NaN        7        3        4      9881      1269      8612
# 2      NaN      NaN       57       28       29     58176     17978     40198
# 3      NaN      NaN       16        8        8      1944      1026       918
# 4      NaN      NaN       20       10       10      5290      1308      3982
#
#    TotAppByte  SAppBytes  DAppBytes  PCRatio          Load       SrcLoad  \
# 0           0          0          0      NaN  0.000000e+00  0.000000e+00
# 1           0          0          0     -0.0  6.018538e+07  6.970134e+06
# 2           0          0          0     -0.0  1.203296e+05  3.715241e+04
# 3           0          0          0     -0.0  4.395094e+06  2.318915e+06
# 4           0          0          0     -0.0  2.147463e+07  5.312288e+06
#
#         DstLoad  Loss  SrcLoss  DstLoss      pLoss  Retrans  SrcRetra  \
# 0  0.000000e+00     0        0        0   0.000000        0         0
# 1  5.321524e+07     0        0        0   0.000000        0         0
# 2  8.317718e+04    18        6       12  24.000000        0         0
# 3  2.076178e+06     3        1        2  15.789474        0         0
# 4  1.616234e+07     4        1        3  16.666667        0         0
#
#    DstRetra  pRetran  SrcGap  DstGap          Rate      SrcRate      DstRate  \
# 0         0      0.0     NaN     NaN      0.000000     0.000000     0.000000
# 1         0      0.0     0.0     0.0   6179.196777  2059.732178  3089.598389
# 2         0      0.0     0.0     0.0     15.001552     7.232891     7.500776
# 3         0      0.0     0.0     0.0   4841.833496  2259.522217  2259.522217
# 4         0      0.0     0.0     0.0  10710.258789  5073.280762  5073.280762
#
#      Dir  SIntPkt  SIntDist  SIntPktAct  SIntActDist  SIntPktIdl  SIntIdlDist  \
# 0    NaN      NaN       NaN         NaN          NaN         NaN          NaN
# 1    <?>      NaN       NaN         NaN          NaN         NaN          NaN
# 2    <?>      NaN       NaN         NaN          NaN         NaN          NaN
# 3     ->      NaN       NaN         NaN          NaN         NaN          NaN
# 4     ->      NaN       NaN         NaN          NaN         NaN          NaN
#
#    DIntPkt  DIntDist  DIntPktAct  DIntActDist  DIntPktIdl  DIntIdlDist  \
# 0      NaN       NaN         NaN          NaN         NaN          NaN
# 1      NaN       NaN         NaN          NaN         NaN          NaN
# 2      NaN       NaN         NaN          NaN         NaN          NaN
# 3      NaN       NaN         NaN          NaN         NaN          NaN
# 4      NaN       NaN         NaN          NaN         NaN          NaN
#
#    SrcJitter  SrcJitAct  DstJitter  DstJitAct State  Label  srcUdata  \
# 0        NaN        NaN        NaN        NaN   STA    NaN       NaN
# 1        NaN        NaN        NaN        NaN   CON    NaN       NaN
# 2        NaN        NaN        NaN        NaN   CON    NaN       NaN
# 3        NaN        NaN        NaN        NaN   RST    NaN       NaN
# 4        NaN        NaN        NaN        NaN   RST    NaN       NaN
#
#    dstUdata    SrcWin    DstWin   sVlan   dVlan  sVid  dVid  sVpri  dVpri  \
# 0       NaN       NaN       NaN     NaN     NaN   NaN   NaN    NaN    NaN
# 1       NaN    2053.0    2048.0  0x0001  0x0001   1.0   1.0    NaN    NaN
# 2       NaN    2053.0    2053.0  0x0001  0x0001   1.0   1.0    NaN    NaN
# 3       NaN  525568.0  525568.0  0x0001  0x0001   1.0   1.0    NaN    NaN
# 4       NaN   65536.0  525568.0  0x0001  0x0001   1.0   1.0    NaN    NaN
#
#    SRange  ERange    SrcTCPBase    DstTCPBase  TcpRtt  SynAck  AckDat  \
# 0     NaN     NaN           NaN           NaN     0.0     0.0     0.0
# 1     NaN     NaN  4.820130e+06  3.766890e+08     0.0     0.0     0.0
# 2     NaN     NaN  2.260341e+09  1.899517e+09     0.0     0.0     0.0
# 3     NaN     NaN  3.546554e+09  3.372354e+09     0.0     0.0     0.0
# 4     NaN     NaN  2.363787e+09  9.066079e+08     0.0     0.0     0.0
#
#         TcpOpt  Attack  Dport_number  Sport_number  id
# 0          NaN  Benign           NaN           NaN NaN
# 1          NaN  Benign           NaN           NaN NaN
# 2          NaN  Benign           NaN           NaN NaN
# 3  Mws       S  Benign           NaN           NaN NaN
# 4  Mws       S  Benign           NaN           NaN NaN

# %%
def save_scores(timeout, meanScores, stdScore):
    results = {
        'Timeout': timeout,
        'Mean of all scores': meanScores,
        'Std of all Scores': stdScores

    }

    with open(f'../Checkpoints/RF/RF_cupid_argus_{timeout}.json', 'w') as f:
        json.dump(results, f, indent=4)

# %%
# Features used in paper 2 modified names
cols = ["Dur", "RunTime", "IdleTime", "Mean", "StdDev", "Sum", "Min", "Max", "Proto", "Cause", "TotPkts", "SrcPkts", "DstPkts", "TotBytes", "SrcBytes",
         "DstBytes", "Load", "SrcLoad", "DstLoad", "Rate", "SrcRate", "DstRate", "Attack",
        "SAppBytes", "DAppBytes", "SynAck", "AckDat", "TcpRtt"
        ]

len(cols)
# Out:
# 28

# %%
timeouts = ['default', 0.5, 1, 2, 3, 4, 5, 6, 10, 30, 60]

# %% [markdown]
# ### Training

# %%
best_f1 = 0
worst_f1 = 1


best_mean, worst_mean, best_std, worst_std = None, None, None, None
save=True

for timeout in timeouts:
    print("Processing timeout : ", timeout)
    
    if timeout =='default':
        out_dir = f'/home/meryem.janati/lustre/nlp_team-um6p-st-sccs-id7fz1zvotk/IDS/janati/IDS/Datasets/cupid/Argus/{timeout}/CUPID_argus_{timeout}.csv'
    else:
        out_dir = f'/home/meryem.janati/lustre/nlp_team-um6p-st-sccs-id7fz1zvotk/IDS/janati/IDS/Datasets/cupid/Argus/timeout{timeout}/CUPID_argus_{timeout}.csv'
    
    df = pd.read_csv(out_dir)
    df = df[cols]
    
    #df = df.drop(columns=['SrcId', 'SrcAddr', 'DstAddr', 'Sport', 'Dport', 'StartTime', 'LastTime', 'Dir', 'State', 'sIpId', 'sDSb', 'AutoId'])
    df = df.dropna() 
    # Convert categorical variables to numerical using Label Encoding
    label_encoders = {}
    for column in ['Proto', 'Cause', 'Flgs' ]:
        if column in df.columns:
            le = LabelEncoder()
            df[column] = le.fit_transform(df[column])
            label_encoders[column] = le

    # Split df into features and labels
    X = df.drop(columns=['Attack'])  # Assuming 'label' is the target variable
    y = df['Attack']
    
    
    accuracy, f1, precision, recall =[], [], [], []
    skf= StratifiedKFold(n_splits=5,random_state=None)
    skf.get_n_splits(X,y)
    
    for (train_index, test_index), i in zip(skf.split(X, y), range(5)):
        X_train,X_test=X.iloc[train_index],X.iloc[test_index]
        y_train,y_test=y.iloc[train_index],y.iloc[test_index]


        le = LabelEncoder()
        y_train = le.fit_transform(y_train)
        
        
        # Map unseen values to '<unknown>'
        y_test = y_test.map(lambda s: '<unknown>' if s not in le.classes_ else s)

        # Add '<unknown>' to classes and transform
        le.classes_ = np.append(le.classes_, '<unknown>')
        y_test = le.transform(y_test)
        
        
        
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        # Initialize and train Extra Trees Classifier
        clf = RandomForestClassifier(random_state=42)
        clf.fit(X_train, y_train)
        pred = clf.predict(X_test)
        
        f1Score = f1_score(y_true=y_test, y_pred=pred, average='macro')
        accScore=accuracy_score(y_test, pred)
        precScore = precision_score(y_test, pred, average='macro')
        recScrore = recall_score(y_test, pred, average='macro')
                             
        f1.append(f1Score)
        accuracy.append(accScore)
        precision.append(precScore)
        recall.append(recScrore)
        print('Fold: ', i, 'done!')

        
    meanScores, stdScores = {}, {}
    
    meanScores['f1Mean'] = np.array(f1).mean()
    meanScores['accMean'] = np.array(accuracy).mean()
    meanScores['recMean'] = np.array(recall).mean()
    meanScores['precMean'] = np.array(precision).mean()
    
    stdScores['f1Std'] = np.array(f1).std()
    stdScores['accStd'] = np.array(accuracy).std()
    stdScores['recStd'] = np.array(recall).std()
    stdScores['precStd'] = np.array(precision).std()
    
    print("Mean of all scores: ", meanScores)
    print("Std of all scores: ", stdScores)


    if save:
        save_scores(timeout, meanScores, stdScores)

    if meanScores['f1Mean'] > best_f1: 
        best_timeout = timeout
        best_mean = meanScores
        best_std = stdScores
        best_f1 = meanScores['f1Mean']
    
    if meanScores['f1Mean'] <= worst_f1: 
        
        worst_timeout = timeout
        worst_mean = meanScores
        worst_std = stdScores
        worst_f1 = meanScores['f1Mean']
               
    print('_______________________________________________')
# Out:
# Processing timeout :  default
# Fold:  0 done!
# Fold:  1 done!
# Fold:  2 done!
# Fold:  3 done!
# Fold:  4 done!
# Mean of all scores:  {'f1Mean': 0.6644151423845852, 'accMean': 0.9501149978326129, 'recMean': 0.7224726395814363, 'precMean': 0.6751630908937832}
# Std of all scores:  {'f1Std': 0.12337155555382359, 'accStd': 0.05111668692392077, 'recStd': 0.051471043945408544, 'precStd': 0.14703870470985256}
# _______________________________________________
# Processing timeout :  0.5
# Fold:  0 done!
# Fold:  1 done!
# Fold:  2 done!
# Fold:  3 done!
# Fold:  4 done!
# Mean of all scores:  {'f1Mean': 0.6539875905307123, 'accMean': 0.8929228099415607, 'recMean': 0.7107207377697218, 'precMean': 0.6692001197035828}
# Std of all scores:  {'f1Std': 0.15524034083504823, 'accStd': 0.15754754378500943, 'recStd': 0.045458046864152564, 'precStd': 0.16341065077867223}
# _______________________________________________
# Processing timeout :  1
# Fold:  0 done!
# Fold:  1 done!
# Fold:  2 done!
# Fold:  3 done!
# Fold:  4 done!
# Mean of all scores:  {'f1Mean': 0.6606732518417079, 'accMean': 0.9528797146309295, 'recMean': 0.7057941751579998, 'precMean': 0.6788816590042359}
# Std of all scores:  {'f1Std': 0.11696989977171562, 'accStd': 0.047680309571098915, 'recStd': 0.05299274157007281, 'precStd': 0.1404822516609213}
# _______________________________________________
# Processing timeout :  2
# Fold:  0 done!
# Fold:  1 done!
# Fold:  2 done!
# Fold:  3 done!
# Fold:  4 done!
# Mean of all scores:  {'f1Mean': 0.6540072967619269, 'accMean': 0.95442996483554, 'recMean': 0.6934264287266904, 'precMean': 0.6718983083693442}
# Std of all scores:  {'f1Std': 0.12792571988044737, 'accStd': 0.04584331718358552, 'recStd': 0.05208213738849545, 'precStd': 0.15030556384389773}
# _______________________________________________
# Processing timeout :  3
# Fold:  0 done!
# Fold:  1 done!
# Fold:  2 done!
# Fold:  3 done!
# Fold:  4 done!
# Mean of all scores:  {'f1Mean': 0.6577824469023402, 'accMean': 0.9521789331181649, 'recMean': 0.7118397256041678, 'precMean': 0.6781479091170235}
# Std of all scores:  {'f1Std': 0.11795759606052578, 'accStd': 0.04964197336452029, 'recStd': 0.05826925463415749, 'precStd': 0.1416831743980536}
# _______________________________________________
# Processing timeout :  4
# Fold:  0 done!
# Fold:  1 done!
# Fold:  2 done!
# Fold:  3 done!
# Fold:  4 done!
# Mean of all scores:  {'f1Mean': 0.6606408347777979, 'accMean': 0.9517870214969302, 'recMean': 0.7049486174093134, 'precMean': 0.6813826981970883}
# Std of all scores:  {'f1Std': 0.11651998426976863, 'accStd': 0.05033941872515668, 'recStd': 0.05339548987701022, 'precStd': 0.13958688846562892}
# _______________________________________________
# Processing timeout :  5
# Fold:  0 done!
# Fold:  1 done!
# Fold:  2 done!
# Fold:  3 done!
# Fold:  4 done!
# Mean of all scores:  {'f1Mean': 0.6960705747813611, 'accMean': 0.9694493059342969, 'recMean': 0.6899831515676954, 'precMean': 0.7282300154404844}
# Std of all scores:  {'f1Std': 0.05382840849179157, 'accStd': 0.03769747429076733, 'recStd': 0.05452271118716465, 'precStd': 0.051404657052299435}
# _______________________________________________
# Processing timeout :  6
# Fold:  0 done!
# Fold:  1 done!
# Fold:  2 done!
# Fold:  3 done!
# Fold:  4 done!
# Mean of all scores:  {'f1Mean': 0.6456849196493665, 'accMean': 0.9535394641163041, 'recMean': 0.7069335412592685, 'precMean': 0.6628440459450312}
# Std of all scores:  {'f1Std': 0.14638191661134606, 'accStd': 0.047761372838743536, 'recStd': 0.05151850241268427, 'precStd': 0.17088629890649887}
# _______________________________________________
# Processing timeout :  10
# Fold:  0 done!
# Fold:  1 done!
# Fold:  2 done!
# Fold:  3 done!
# Fold:  4 done!
# Mean of all scores:  {'f1Mean': 0.6890520785267132, 'accMean': 0.9686057440372592, 'recMean': 0.6969571119180856, 'precMean': 0.7083554063955615}
# Std of all scores:  {'f1Std': 0.06623852364774632, 'accStd': 0.03763573149540279, 'recStd': 0.05320449840230878, 'precStd': 0.08131723841525808}
# _______________________________________________
# Processing timeout :  30
# Fold:  0 done!
# Fold:  1 done!
# Fold:  2 done!
# Fold:  3 done!
# Fold:  4 done!
# Mean of all scores:  {'f1Mean': 0.6370182584844076, 'accMean': 0.9217286465178309, 'recMean': 0.6972776805355565, 'precMean': 0.6578628256143078}
# Std of all scores:  {'f1Std': 0.1562548293544175, 'accStd': 0.09859705975191302, 'recStd': 0.053452645662119755, 'precStd': 0.1764691716081214}
# _______________________________________________
# Processing timeout :  60
# Fold:  0 done!
# Fold:  1 done!
# Fold:  2 done!
# Fold:  3 done!
# Fold:  4 done!
# Mean of all scores:  {'f1Mean': 0.655674016346668, 'accMean': 0.922667722947234, 'recMean': 0.7135371069057931, 'precMean': 0.666927966571539}
# Std of all scores:  {'f1Std': 0.14710038134331557, 'accStd': 0.10030593133719538, 'recStd': 0.04309766320918355, 'precStd': 0.16384093204911088}
# _______________________________________________

# %%
print("Best Timeout Combination: ", best_timeout)
print("Mean Scores (Best): ", best_mean)
print('Std Scores (Best):', best_std)
# Out:
# Best Timeout Combination:  5
# Mean Scores (Best):  {'f1Mean': 0.6960705747813611, 'accMean': 0.9694493059342969, 'recMean': 0.6899831515676954, 'precMean': 0.7282300154404844}
# Std Scores (Best): {'f1Std': 0.05382840849179157, 'accStd': 0.03769747429076733, 'recStd': 0.05452271118716465, 'precStd': 0.051404657052299435}

# %%
print("worst Timeout Combination: ", worst_timeout)
print("Mean Scores (Worst): ", worst_mean)
print('Std Scores (Worst):', worst_std)
# Out:
# worst Timeout Combination:  30
# Mean Scores (Worst):  {'f1Mean': 0.6370182584844076, 'accMean': 0.9217286465178309, 'recMean': 0.6972776805355565, 'precMean': 0.6578628256143078}
# Std Scores (Worst): {'f1Std': 0.1562548293544175, 'accStd': 0.09859705975191302, 'recStd': 0.053452645662119755, 'precStd': 0.1764691716081214}

# %%
results = {
    'Best score': {
        'Best Timeout': best_timeout,
        'Mean Scores (Best)': best_mean,
        'Std Scores (Best)': best_std,
    },
    
    'Worst score': {
        'Worst Timeout': worst_timeout,
        'Mean Scores (Worst)': worst_mean,
        'Std Scores (Worst)': worst_std,
    },
    
    'Difference': {
        'Accuracy': (best_mean['accMean'] - worst_mean['accMean'])*100,
        'F1 Score': (best_mean['f1Mean'] - worst_mean['f1Mean'])*100,
        'Precision': (best_mean['precMean'] - worst_mean['precMean'])*100,
        'Recall': (best_mean['recMean'] - worst_mean['recMean'])*100
    }
}



with open('../results/RF_cupid_argus.json', 'w') as f:
    json.dump(results, f, indent=4)
