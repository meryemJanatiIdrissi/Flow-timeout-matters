# %%
import json
def load_score(path):
    with open(path, 'r') as f:
        loaded_results = json.load(f)
    return loaded_results

# %%
results_ET = load_score('../results/ET_ustc_zeek.json')

# %%
results_RF = load_score('../results/RF_ustc_zeek.json')

# %%
results_MLP = load_score('../results/MLP_ustc_zeek.json')

# %%
print("ET classifier: \n" , results_ET)
print("\nRF classifier :\n" , results_RF)
print("\nMLP classifier : \n" , results_MLP)
# Out:
# ET classifier:
#  {'Best score': {'Best Timeout': 'default', 'Mean Scores (Best)': {'f1Mean': 0.8869640911843966, 'accMean': 0.9604993028700708, 'recMean': 0.8993197609689465, 'precMean': 0.894273200586267}, 'Std Scores (Best)': {'f1Std': 0.05684731569281597, 'accStd': 0.02049124870399308, 'recStd': 0.044028399995619756, 'precStd': 0.061833180492736756}}, 'Worst score': {'Worst Timeout': 0.5, 'Mean Scores (Worst)': {'f1Mean': 0.8683073791237368, 'accMean': 0.9515333142604909, 'recMean': 0.8891246161037731, 'precMean': 0.8720649801454339}, 'Std Scores (Worst)': {'f1Std': 0.06355661142832485, 'accStd': 0.025311428632770968, 'recStd': 0.04221385315450868, 'precStd': 0.06780055153818457}}, 'Difference': {'Accuracy': 0.8965988609579867, 'F1 Score': 1.8656712060659775, 'Precision': 2.220822044083315, 'Recall': 1.0195144865173367}}
#
# RF classifier :
#  {'Best score': {'Best Timeout': 30, 'Mean Scores (Best)': {'f1Mean': 0.8702412024924845, 'accMean': 0.9544390848567128, 'recMean': 0.8892982042002503, 'precMean': 0.8906997276141666}, 'Std Scores (Best)': {'f1Std': 0.0343899690644257, 'accStd': 0.010243457356614144, 'recStd': 0.030876107152330932, 'precStd': 0.04886693630877315}}, 'Worst score': {'Worst Timeout': 0.5, 'Mean Scores (Worst)': {'f1Mean': 0.8459183649523123, 'accMean': 0.9344264305384229, 'recMean': 0.8742888197508385, 'precMean': 0.8600399674957835}, 'Std Scores (Worst)': {'f1Std': 0.06772354820400206, 'accStd': 0.0427722784774913, 'recStd': 0.04011938987459781, 'precStd': 0.07313439592380304}}, 'Difference': {'Accuracy': 2.0012654318289913, 'F1 Score': 2.432283754017217, 'Precision': 3.0659760118383117, 'Recall': 1.50093844494118}}
#
# MLP classifier :
#  {'Best score': {'Best Timeout': 'default', 'Mean Scores (Best)': {'f1Mean': 0.8028120279604372, 'accMean': 0.936926840817615, 'recMean': 0.8006076205444259, 'precMean': 0.8259149617757391}, 'Std Scores (Best)': {'f1Std': 0.04851860333817631, 'accStd': 0.019372544338109275, 'recStd': 0.04750320810726693, 'precStd': 0.03579410264072459}}, 'Worst score': {'Worst Timeout': 60, 'Mean Scores (Worst)': {'f1Mean': 0.7741585475353988, 'accMean': 0.9292758550699002, 'recMean': 0.7964777652169939, 'precMean': 0.7849664715900773}, 'Std Scores (Worst)': {'f1Std': 0.06315152698667863, 'accStd': 0.021340510160580257, 'recStd': 0.05212614888561606, 'precStd': 0.055254339162881465}}, 'Difference': {'Accuracy': 0.7650985747714834, 'F1 Score': 2.8653480425038347, 'Precision': 4.094849018566182, 'Recall': 0.41298553274320415}}

# %%
Macro F1-score     & 88.7 $\pm$ 0.06   & 87.02 $\pm$ 0.03  & 80.28 $\pm$ 0.05 & & 86.83 $\pm$ 0.06 & 84.59 $\pm$ 0.07 & 77.42 $\pm$ 0.06 & & 1.87 & 2.43 & 2.87 \
Macro Recall       & 89.93 $\pm$ 0.04  & 88.93 $\pm$ 0.03 & 80.06 $\pm$ 0.05 & & 88.91 $\pm$ 0.04 & 87.43 $\pm$ 0.04 & 79.65 $\pm$ 0.05 & & 1.02 & 1.5 & 0.41 \
Macro Precision    & 89.43 $\pm$ 0.06   & 89.07 $\pm$ 0.05 & 82.59 $\pm$ 0.04 & & 87.21 $\pm$ 0.07 & 86.0 $\pm$ 0.07 & 78.5 $\pm$ 0.06 & & 2.22 & 3.07 & 4.09 \
Accuracy           & 96.05 $\pm$ 0.02 & 95.44 $\pm$ 0.01 & 93.69 $\pm$ 0.02 & & 95.15 $\pm$ 0.03 & 93.44 $\pm$ 0.04 & 92.93 $\pm$ 0.02 & & 0.9 & 2.0 & 0.77 \

# %%
Macro F1-score     & 88.70 $\pm$ 0.06 & 87.02 $\pm$ 0.03 & 80.28 $\pm$ 0.05 & & 86.83 $\pm$ 0.06 & 84.59 $\pm$ 0.07 & 77.42 $\pm$ 0.06 & & 1.87 & 2.43 & \textbf{2.87} \\
& Macro Recall       & 89.93 $\pm$ 0.04 & 88.93 $\pm$ 0.03 & 80.06 $\pm$ 0.05 & & 88.91 $\pm$ 0.04 & 87.43 $\pm$ 0.04 & 79.65 $\pm$ 0.05 & & 1.02 & 1.50 & 0.41 \\
& Macro Precision    & 89.43 $\pm$ 0.06 & 89.07 $\pm$ 0.05 & 82.59 $\pm$ 0.04 & & 87.21 $\pm$ 0.07 & 86.00 $\pm$ 0.07 & 78.50 $\pm$ 0.06 & & 2.22 & 3.07 & 4.09 \\
& Accuracy     & 96.05 $\pm$ 0.02 & 95.44 $\pm$ 0.01 & 93.69 $\pm$ 0.02 & & 95.15 $\pm$ 0.03 & 93.44 $\pm$ 0.04 & 92.93 $\pm$ 0.02 & & 0.90 & 2.00 & 0.77 \\
        
\cmidrule(l{2.7em}r{0em}){1-13}
&         Timeouts         & Default & 30 & Default & & 0.5 & 0.5 & 60 & & - & - & - \\
\bottomrule[1.5pt]\\ [-2ex]

# %%
ET classifier: 
 {'Best score': {'Best Timeout': t1, 'Mean Scores (Best)': {'f1Mean': m1, 'accMean': m2, 'recMean': m3, 'precMean': m4}, 'Std Scores (Best)': {'f1Std': s1, 'accStd': s2, 'recStd': s3, 'precStd': s4}}, 'Worst score': {'Worst Timeout': t2,
 'Mean Scores (Worst)': {'f1Mean': mm1, 'accMean': mm2, 'recMean': mm3, 'precMean': mm4}, 'Std Scores (Worst)': {'f1Std': ss1, 'accStd': ss2, 'recStd': ss3, 'precStd': ss4}}, 'Difference': {'Accuracy': d1, 'F1 Score': d2, 'Precision': d3, 'Recall': d4}}
# Out:
# {'Best Timeout': 'default',
#  'Mean Scores (Best)': {'f1Mean': 0.8869640911843966,
#   'accMean': 0.9604993028700708,
#   'recMean': 0.8993197609689465,
#   'precMean': 0.894273200586267},
#  'Std Scores (Best)': {'f1Std': 0.05684731569281597,
#   'accStd': 0.02049124870399308,
#   'recStd': 0.044028399995619756,
#   'precStd': 0.061833180492736756}}

# %%
f1_ET_best = [m1 , s1]
acc_ET_best = [m2 , s2]
rec_et_best = [m3 , s3]
prec_et_best = [m4 , s4] 

f1_ET_worst = [mm1 , ss1]
acc_ET_worst = [mm2 , ss2]
rec_et_worst = [mm3 , ss3]
prec_et_worst = [mm4 , ss4] 

d_f1 = d2
d_acc = d1
d_rec = d4
d_prec = d3

# %%
Macro F1-score     & m1 $\pm$ s1 & & mm1 $\pm$ ss1  & & d1  \\
& Macro Recall       & m2 $\pm$ s2 & & mm2 $\pm$ ss2  & & d2 \\
& Macro Precision    & m3 $\pm$ s3  & & mm3 $\pm$ ss3  & & d3  \\
& Accuracy     & m4 $\pm$ s4  & & mm4 $\pm$ ss4  & & d4 \\
        
\cmidrule(l{2.7em}r{0em}){1-13}
&         Timeouts         & t1 & 30 & Default & & t2 & 0.5 & 60 & & - & - & - \\

# %%
et_classifier = results_ET

# Best score variables
f1_ET_best = [et_classifier["Best score"]["Mean Scores (Best)"]["f1Mean"], 
              et_classifier["Best score"]["Std Scores (Best)"]["f1Std"]]
acc_ET_best = [et_classifier["Best score"]["Mean Scores (Best)"]["accMean"], 
               et_classifier["Best score"]["Std Scores (Best)"]["accStd"]]
rec_ET_best = [et_classifier["Best score"]["Mean Scores (Best)"]["recMean"], 
               et_classifier["Best score"]["Std Scores (Best)"]["recStd"]]
prec_ET_best = [et_classifier["Best score"]["Mean Scores (Best)"]["precMean"], 
                et_classifier["Best score"]["Std Scores (Best)"]["precStd"]]

# Worst score variables
f1_ET_worst = [et_classifier["Worst score"]["Mean Scores (Worst)"]["f1Mean"], 
               et_classifier["Worst score"]["Std Scores (Worst)"]["f1Std"]]
acc_ET_worst = [et_classifier["Worst score"]["Mean Scores (Worst)"]["accMean"], 
                et_classifier["Worst score"]["Std Scores (Worst)"]["accStd"]]
rec_ET_worst = [et_classifier["Worst score"]["Mean Scores (Worst)"]["recMean"], 
                et_classifier["Worst score"]["Std Scores (Worst)"]["recStd"]]
prec_ET_worst = [et_classifier["Worst score"]["Mean Scores (Worst)"]["precMean"], 
                 et_classifier["Worst score"]["Std Scores (Worst)"]["precStd"]]

# Difference variables
d_ET_acc = et_classifier["Difference"]["Accuracy"]
d_ET_f1 = et_classifier["Difference"]["F1 Score"]
d_ET_rec = et_classifier["Difference"]["Recall"]
d_ET_prec = et_classifier["Difference"]["Precision"]

# Output the results
print("f1_ET_best =", f1_ET_best)
print("acc_ET_best =", acc_ET_best)
print("rec_ET_best =", rec_ET_best)
print("prec_ET_best =", prec_ET_best)

print("f1_ET_worst =", f1_ET_worst)
print("acc_ET_worst =", acc_ET_worst)
print("rec_ET_worst =", rec_ET_worst)
print("prec_ET_worst =", prec_ET_worst)

print("d_f1 =", d_ET_f1)
print("d_acc =", d_ET_acc)
print("d_rec =", d_ET_rec)
print("d_prec =", d_ET_prec)
# Out:
# f1_ET_best = [0.8869640911843966, 0.05684731569281597]
# acc_ET_best = [0.9604993028700708, 0.02049124870399308]
# rec_ET_best = [0.8993197609689465, 0.044028399995619756]
# prec_ET_best = [0.894273200586267, 0.061833180492736756]
# f1_ET_worst = [0.8683073791237368, 0.06355661142832485]
# acc_ET_worst = [0.9515333142604909, 0.025311428632770968]
# rec_ET_worst = [0.8891246161037731, 0.04221385315450868]
# prec_ET_worst = [0.8720649801454339, 0.06780055153818457]
# d_f1 = 1.8656712060659775
# d_acc = 0.8965988609579867
# d_rec = 1.0195144865173367
# d_prec = 2.220822044083315

# %%
RF_classifier = results_RF

# Best score variables
f1_RF_best = [RF_classifier["Best score"]["Mean Scores (Best)"]["f1Mean"], 
              RF_classifier["Best score"]["Std Scores (Best)"]["f1Std"]]
acc_RF_best = [RF_classifier["Best score"]["Mean Scores (Best)"]["accMean"], 
               RF_classifier["Best score"]["Std Scores (Best)"]["accStd"]]
rec_RF_best = [RF_classifier["Best score"]["Mean Scores (Best)"]["recMean"], 
               RF_classifier["Best score"]["Std Scores (Best)"]["recStd"]]
prec_RF_best = [RF_classifier["Best score"]["Mean Scores (Best)"]["precMean"], 
                RF_classifier["Best score"]["Std Scores (Best)"]["precStd"]]

# Worst score variables
f1_RF_worst = [RF_classifier["Worst score"]["Mean Scores (Worst)"]["f1Mean"], 
               RF_classifier["Worst score"]["Std Scores (Worst)"]["f1Std"]]
acc_RF_worst = [RF_classifier["Worst score"]["Mean Scores (Worst)"]["accMean"], 
                RF_classifier["Worst score"]["Std Scores (Worst)"]["accStd"]]
rec_RF_worst = [RF_classifier["Worst score"]["Mean Scores (Worst)"]["recMean"], 
                RF_classifier["Worst score"]["Std Scores (Worst)"]["recStd"]]
prec_RF_worst = [RF_classifier["Worst score"]["Mean Scores (Worst)"]["precMean"], 
                 RF_classifier["Worst score"]["Std Scores (Worst)"]["precStd"]]

# Difference variables
d_RF_acc = RF_classifier["Difference"]["Accuracy"]
d_RF_f1 = RF_classifier["Difference"]["F1 Score"]
d_RF_rec = RF_classifier["Difference"]["Recall"]
d_RF_prec = RF_classifier["Difference"]["Precision"]

# Output the results
print("f1_RF_best =", f1_RF_best)
print("acc_RF_best =", acc_RF_best)
print("rec_RF_best =", rec_RF_best)
print("prec_RF_best =", prec_RF_best)

print("f1_RF_worst =", f1_RF_worst)
print("acc_RF_worst =", acc_RF_worst)
print("rec_RF_worst =", rec_RF_worst)
print("prec_RF_worst =", prec_RF_worst)

print("d_f1 =", d_RF_f1)
print("d_acc =", d_RF_acc)
print("d_rec =", d_RF_rec)
print("d_prec =", d_RF_prec)
# Out:
# f1_RF_best = [0.8702412024924845, 0.0343899690644257]
# acc_RF_best = [0.9544390848567128, 0.010243457356614144]
# rec_RF_best = [0.8892982042002503, 0.030876107152330932]
# prec_RF_best = [0.8906997276141666, 0.04886693630877315]
# f1_RF_worst = [0.8459183649523123, 0.06772354820400206]
# acc_RF_worst = [0.9344264305384229, 0.0427722784774913]
# rec_RF_worst = [0.8742888197508385, 0.04011938987459781]
# prec_RF_worst = [0.8600399674957835, 0.07313439592380304]
# d_f1 = 2.432283754017217
# d_acc = 2.0012654318289913
# d_rec = 1.50093844494118
# d_prec = 3.0659760118383117

# %%
MLP_classifier = results_MLP

# Best score variables
f1_MLP_best = [MLP_classifier["Best score"]["Mean Scores (Best)"]["f1Mean"], 
              MLP_classifier["Best score"]["Std Scores (Best)"]["f1Std"]]
acc_MLP_best = [MLP_classifier["Best score"]["Mean Scores (Best)"]["accMean"], 
               MLP_classifier["Best score"]["Std Scores (Best)"]["accStd"]]
rec_MLP_best = [MLP_classifier["Best score"]["Mean Scores (Best)"]["recMean"], 
               MLP_classifier["Best score"]["Std Scores (Best)"]["recStd"]]
prec_MLP_best = [MLP_classifier["Best score"]["Mean Scores (Best)"]["precMean"], 
                MLP_classifier["Best score"]["Std Scores (Best)"]["precStd"]]

# Worst score variables
f1_MLP_worst = [MLP_classifier["Worst score"]["Mean Scores (Worst)"]["f1Mean"], 
               MLP_classifier["Worst score"]["Std Scores (Worst)"]["f1Std"]]
acc_MLP_worst = [MLP_classifier["Worst score"]["Mean Scores (Worst)"]["accMean"], 
                MLP_classifier["Worst score"]["Std Scores (Worst)"]["accStd"]]
rec_MLP_worst = [MLP_classifier["Worst score"]["Mean Scores (Worst)"]["recMean"], 
                MLP_classifier["Worst score"]["Std Scores (Worst)"]["recStd"]]
prec_MLP_worst = [MLP_classifier["Worst score"]["Mean Scores (Worst)"]["precMean"], 
                 MLP_classifier["Worst score"]["Std Scores (Worst)"]["precStd"]]

# Difference variables
d_MLP_acc = MLP_classifier["Difference"]["Accuracy"]
d_MLP_f1 = MLP_classifier["Difference"]["F1 Score"]
d_MLP_rec = MLP_classifier["Difference"]["Recall"]
d_MLP_prec = MLP_classifier["Difference"]["Precision"]

# Output the results
print("f1_MLP_best =", f1_MLP_best)
print("acc_MLP_best =", acc_MLP_best)
print("rec_MLP_best =", rec_MLP_best)
print("prec_MLP_best =", prec_MLP_best)

print("f1_MLP_worst =", f1_MLP_worst)
print("acc_MLP_worst =", acc_MLP_worst)
print("rec_MLP_worst =", rec_MLP_worst)
print("prec_MLP_worst =", prec_MLP_worst)

print("d_f1 =", d_MLP_f1)
print("d_acc =", d_MLP_acc)
print("d_rec =", d_MLP_rec)
print("d_prec =", d_MLP_prec)
# Out:
# f1_MLP_best = [0.8028120279604372, 0.04851860333817631]
# acc_MLP_best = [0.936926840817615, 0.019372544338109275]
# rec_MLP_best = [0.8006076205444259, 0.04750320810726693]
# prec_MLP_best = [0.8259149617757391, 0.03579410264072459]
# f1_MLP_worst = [0.7741585475353988, 0.06315152698667863]
# acc_MLP_worst = [0.9292758550699002, 0.021340510160580257]
# rec_MLP_worst = [0.7964777652169939, 0.05212614888561606]
# prec_MLP_worst = [0.7849664715900773, 0.055254339162881465]
# d_f1 = 2.8653480425038347
# d_acc = 0.7650985747714834
# d_rec = 0.41298553274320415
# d_prec = 4.094849018566182

# %%
# Fill in the LaTeX table
latex_table = f"""
Macro F1-score     & {round(f1_ET_best[0], 2)} $\pm$ {round(f1_ET_best[1], 2)}   & {round(f1_RF_best[0], 2)} $\pm$ {round(f1_RF_best[1], 2)}  & {round(f1_MLP_best[0], 2)} $\pm$ {round(f1_MLP_best[1], 2)} & & {round(f1_ET_worst[0], 2)} $\pm$ {round(f1_ET_worst[1], 2)} & {round(f1_RF_worst[0], 2)} $\pm$ {round(f1_RF_worst[1], 2)} & {round(f1_MLP_worst[0], 2)} $\pm$ {round(f1_MLP_worst[1], 2)} & & {round(d_ET_f1,2)} & {round(d_RF_f1, 2)} & {round(d_MLP_f1, 2)} \\
Macro Recall       & {round(rec_ET_best[0], 2)} $\pm$ {round(rec_ET_best[1], 2)}  & {round(rec_RF_best[0], 2)} $\pm$ {round(rec_RF_best[1], 2)} & {round(rec_MLP_best[0], 2)} $\pm$ {round(rec_MLP_best[1], 2)} & & {round(rec_ET_worst[0], 2)} $\pm$ {round(rec_ET_worst[1], 2)} & {round(rec_RF_worst[0], 2)} $\pm$ {round(rec_RF_worst[1], 2)} & {round(rec_MLP_worst[0], 2)} $\pm$ {round(rec_MLP_worst[1], 2)} & & {round(d_ET_rec, 2)} & {round(d_RF_rec, 2)} & {round(d_MLP_rec, 2)} \\
Macro Precision    & {round(prec_ET_best[0], 2)} $\pm$ {round(prec_ET_best[1], 2)}   & {round(prec_RF_best[0], 2)} $\pm$ {round(prec_RF_best[1], 2)} & {round(prec_MLP_best[0], 2)} $\pm$ {round(prec_MLP_best[1], 2)} & & {round(prec_ET_worst[0], 2)} $\pm$ {round(prec_ET_worst[1], 2)} & {round(prec_RF_worst[0], 2)} $\pm$ {round(prec_RF_worst[1], 2)} & {round(prec_MLP_worst[0], 2)} $\pm$ {round(prec_MLP_worst[1], 2)} & & {round(d_ET_prec, 2)} & {round(d_RF_prec, 2)} & {round(d_MLP_prec, 2)} \\
Accuracy           & {round(acc_ET_best[0], 2)} $\pm$ {round(acc_ET_best[1], 2)} & {round(acc_RF_best[0], 2)} $\pm$ {round(acc_RF_best[1], 2)} & {round(acc_MLP_best[0], 2)} $\pm$ {round(acc_MLP_best[1], 2)} & & {round(acc_ET_worst[0], 2)} $\pm$ {round(acc_ET_worst[1], 2)} & {round(acc_RF_worst[0], 2)} $\pm$ {round(acc_RF_worst[1], 2)} & {round(acc_MLP_worst[0], 2)} $\pm$ {round(acc_MLP_worst[1], 2)} & & {round(d_ET_acc, 2)} & {round(d_RF_acc, 2)} & {round(d_MLP_acc, 2)} \\
"""

# Output the LaTeX table
print(latex_table)
# Out:
# Macro F1-score     & 0.89 $\pm$ 0.06   & 0.87 $\pm$ 0.03  & 0.8 $\pm$ 0.05 & & 0.87 $\pm$ 0.06 & 0.85 $\pm$ 0.07 & 0.77 $\pm$ 0.06 & & 1.87 & 2.43 & 2.87 \
# Macro Recall       & 0.9 $\pm$ 0.04  & 0.89 $\pm$ 0.03 & 0.8 $\pm$ 0.05 & & 0.89 $\pm$ 0.04 & 0.87 $\pm$ 0.04 & 0.8 $\pm$ 0.05 & & 1.02 & 1.5 & 0.41 \
# Macro Precision    & 0.89 $\pm$ 0.06   & 0.89 $\pm$ 0.05 & 0.83 $\pm$ 0.04 & & 0.87 $\pm$ 0.07 & 0.86 $\pm$ 0.07 & 0.78 $\pm$ 0.06 & & 2.22 & 3.07 & 4.09 \
# Accuracy           & 0.96 $\pm$ 0.02 & 0.95 $\pm$ 0.01 & 0.94 $\pm$ 0.02 & & 0.95 $\pm$ 0.03 & 0.93 $\pm$ 0.04 & 0.93 $\pm$ 0.02 & & 0.9 & 2.0 & 0.77 \

# %%
latex_table = f"""
Macro F1-score     & {round(f1_ET_best[0]*100, 2)} $\pm$ {round(f1_ET_best[1], 2)}   & {round(f1_RF_best[0]*100, 2)} $\pm$ {round(f1_RF_best[1], 2)}  & {round(f1_MLP_best[0]*100, 2)} $\pm$ {round(f1_MLP_best[1], 2)} & & {round(f1_ET_worst[0]*100, 2)} $\pm$ {round(f1_ET_worst[1], 2)} & {round(f1_RF_worst[0]*100, 2)} $\pm$ {round(f1_RF_worst[1], 2)} & {round(f1_MLP_worst[0]*100, 2)} $\pm$ {round(f1_MLP_worst[1], 2)} & & {round(d_ET_f1, 2)} & {round(d_RF_f1, 2)} & {round(d_MLP_f1, 2)} \\
Macro Recall       & {round(rec_ET_best[0]*100, 2)} $\pm$ {round(rec_ET_best[1], 2)}  & {round(rec_RF_best[0]*100, 2)} $\pm$ {round(rec_RF_best[1], 2)} & {round(rec_MLP_best[0]*100, 2)} $\pm$ {round(rec_MLP_best[1], 2)} & & {round(rec_ET_worst[0]*100, 2)} $\pm$ {round(rec_ET_worst[1], 2)} & {round(rec_RF_worst[0]*100, 2)} $\pm$ {round(rec_RF_worst[1], 2)} & {round(rec_MLP_worst[0]*100, 2)} $\pm$ {round(rec_MLP_worst[1], 2)} & & {round(d_ET_rec, 2)} & {round(d_RF_rec, 2)} & {round(d_MLP_rec, 2)} \\
Macro Precision    & {round(prec_ET_best[0]*100, 2)} $\pm$ {round(prec_ET_best[1], 2)}   & {round(prec_RF_best[0]*100, 2)} $\pm$ {round(prec_RF_best[1], 2)} & {round(prec_MLP_best[0]*100, 2)} $\pm$ {round(prec_MLP_best[1], 2)} & & {round(prec_ET_worst[0]*100, 2)} $\pm$ {round(prec_ET_worst[1], 2)} & {round(prec_RF_worst[0]*100, 2)} $\pm$ {round(prec_RF_worst[1], 2)} & {round(prec_MLP_worst[0]*100, 2)} $\pm$ {round(prec_MLP_worst[1], 2)} & & {round(d_ET_prec, 2)} & {round(d_RF_prec, 2)} & {round(d_MLP_prec, 2)} \\
Accuracy           & {round(acc_ET_best[0]*100, 2)} $\pm$ {round(acc_ET_best[1], 2)} & {round(acc_RF_best[0]*100, 2)} $\pm$ {round(acc_RF_best[1], 2)} & {round(acc_MLP_best[0]*100, 2)} $\pm$ {round(acc_MLP_best[1], 2)} & & {round(acc_ET_worst[0]*100, 2)} $\pm$ {round(acc_ET_worst[1], 2)} & {round(acc_RF_worst[0]*100, 2)} $\pm$ {round(acc_RF_worst[1], 2)} & {round(acc_MLP_worst[0]*100, 2)} $\pm$ {round(acc_MLP_worst[1], 2)} & & {round(d_ET_acc, 2)} & {round(d_RF_acc, 2)} & {round(d_MLP_acc, 2)} \\
"""

# Output the LaTeX table
print(latex_table)
# Out:
# Macro F1-score     & 88.7 $\pm$ 0.06   & 87.02 $\pm$ 0.03  & 80.28 $\pm$ 0.05 & & 86.83 $\pm$ 0.06 & 84.59 $\pm$ 0.07 & 77.42 $\pm$ 0.06 & & 1.87 & 2.43 & 2.87 \
# Macro Recall       & 89.93 $\pm$ 0.04  & 88.93 $\pm$ 0.03 & 80.06 $\pm$ 0.05 & & 88.91 $\pm$ 0.04 & 87.43 $\pm$ 0.04 & 79.65 $\pm$ 0.05 & & 1.02 & 1.5 & 0.41 \
# Macro Precision    & 89.43 $\pm$ 0.06   & 89.07 $\pm$ 0.05 & 82.59 $\pm$ 0.04 & & 87.21 $\pm$ 0.07 & 86.0 $\pm$ 0.07 & 78.5 $\pm$ 0.06 & & 2.22 & 3.07 & 4.09 \
# Accuracy           & 96.05 $\pm$ 0.02 & 95.44 $\pm$ 0.01 & 93.69 $\pm$ 0.02 & & 95.15 $\pm$ 0.03 & 93.44 $\pm$ 0.04 & 92.93 $\pm$ 0.02 & & 0.9 & 2.0 & 0.77 \

# %%
#Fill in the LaTeX table
latex_table = f"""
Macro F1-score     & {round(f1_ET_best[0]*100, 2)} $\pm$ {round(f1_ET_best[1], 2)}   & {f1_RF_best[0]} $\pm$ {f1_RF_best[1]}  & {f1_MLP_best[0]} $\pm$ {f1_MLP_best[1]} & & {f1_ET_worst[0]} $\pm$ {f1_ET_worst[1]} & {f1_RF_worst[0]} $\pm$ {f1_RF_worst[1]} & {f1_MLP_worst[0]} $\pm$ {f1_MLP_worst[1]} & & {d_ET_f1} & {d_RF_f1} & {d_MLP_f1} \\
Macro Recall       & {rec_ET_best[0]} $\pm$ {rec_ET_best[1]}  & {rec_RF_best[0]} $\pm$ {rec_RF_best[1]} & {rec_MLP_best[0]} $\pm$ {rec_MLP_best[1]} & & {rec_ET_worst[0]} $\pm$ {rec_ET_worst[1]} & {rec_RF_worst[0]} $\pm$ {rec_RF_worst[1]} & {rec_MLP_worst[0]} $\pm$ {rec_MLP_worst[1]} & & {d_ET_rec} & {d_RF_rec} & {d_MLP_rec} \\
Macro Precision    & {prec_ET_best[0]} $\pm$ {prec_ET_best[1]}   & {prec_RF_best[0]} $\pm$ {prec_RF_best[1]} & {prec_MLP_best[0]} $\pm$ {prec_MLP_best[1]} & & {prec_ET_worst[0]} $\pm$ {prec_ET_worst[1]} & {prec_RF_worst[0]} $\pm$ {prec_RF_worst[1]} & {prec_MLP_worst[0]} $\pm$ {prec_MLP_worst[1]} & & {d_ET_prec} & {d_RF_prec} & {d_MLP_prec} \\
Accuracy           & {acc_ET_best[0]} $\pm$ {acc_ET_best[1]} & {acc_RF_best[0]} $\pm$ {acc_RF_best[1]} & {acc_MLP_best[0]} $\pm$ {acc_MLP_best[1]} & & {acc_ET_worst[0]} $\pm$ {acc_ET_worst[1]} & {acc_RF_worst[0]} $\pm$ {acc_RF_worst[1]} & {acc_MLP_worst[0]} $\pm$ {acc_MLP_worst[1]} & & {d_ET_acc} & {d_RF_acc} & {d_MLP_acc} \\
"""

# Output the LaTeX table
print(latex_table)
# Out:
# Macro F1-score     & 0.8869640911843966 $\pm$ 0.05684731569281597   & 0.8702412024924845 $\pm$ 0.0343899690644257  & 0.8028120279604372 $\pm$ 0.04851860333817631 & & 0.8683073791237368 $\pm$ 0.06355661142832485 & 0.8459183649523123 $\pm$ 0.06772354820400206 & 0.7741585475353988 $\pm$ 0.06315152698667863 & & 1.8656712060659775 & 2.432283754017217 & 2.8653480425038347 \
# Macro Recall       & 0.8993197609689465 $\pm$ 0.044028399995619756  & 0.8892982042002503 $\pm$ 0.030876107152330932 & 0.8006076205444259 $\pm$ 0.04750320810726693 & & 0.8891246161037731 $\pm$ 0.04221385315450868 & 0.8742888197508385 $\pm$ 0.04011938987459781 & 0.7964777652169939 $\pm$ 0.05212614888561606 & & 1.0195144865173367 & 1.50093844494118 & 0.41298553274320415 \
# Macro Precision    & 0.894273200586267 $\pm$ 0.061833180492736756   & 0.8906997276141666 $\pm$ 0.04886693630877315 & 0.8259149617757391 $\pm$ 0.03579410264072459 & & 0.8720649801454339 $\pm$ 0.06780055153818457 & 0.8600399674957835 $\pm$ 0.07313439592380304 & 0.7849664715900773 $\pm$ 0.055254339162881465 & & 2.220822044083315 & 3.0659760118383117 & 4.094849018566182 \
# Accuracy           & 0.9604993028700708 $\pm$ 0.02049124870399308 & 0.9544390848567128 $\pm$ 0.010243457356614144 & 0.936926840817615 $\pm$ 0.019372544338109275 & & 0.9515333142604909 $\pm$ 0.025311428632770968 & 0.9344264305384229 $\pm$ 0.0427722784774913 & 0.9292758550699002 $\pm$ 0.021340510160580257 & & 0.8965988609579867 & 2.0012654318289913 & 0.7650985747714834 \

# %%
round(0.8906997276141666*100, 2)
# Out:
# 89.07

# %%
 {f1_ET_best[0]} $\pm$ {f1_ET_best[1]}
# Out:
# 0.05

# %%
0.8869640911843966*100
# Out:
# 88.69640911843966

# %%
Macro F1-score     & f1_ET_best[0] $\pm$ f1_ET_best[1]   & f1_RF_best  & f1_MLP_best5      & & f1_ET_worst & f1_RF_worst & f1_MLP_worst     & &   d_ET_f1 & d_RF_f1 & d_MLP_f1 \\
& Macro Recall       & rec_ET_best[0] $\pm$ rec_ET_best[1]  & rec_RF_best  & rec_MLP_best5 & & rec_ET_worst & rec_RF_worst & rec_MLP_worst & & d_ET_rec & d_RF_rec & d_MLP_rec \\
& Macro Precision    & prec_ET_best[0] $\pm$ prec_ET_best[1]   & prec_RF_best  & prec_MLP_best & & prec_ET_worst & prec_RF_worst & prec_MLP_worst & & d_ET_prec & d_RF_prec & d_MLP_prec \\
& Accuracy     & acc_ET_best[0] $\pm$  acc_ET_best[1] &  acc_RF_best &  acc_MLP_best & & acc_ET_worst& acc_RF_worst& acc_MLP_worst & & d_ET_ac & d_RF_ac & d_MLP_ac \\

# %%
Macro F1-score     & f1_ET_best[0] $\pm$ f1_ET_best[1]   & f1_RF_best[0] $\pm$ f1_RF_best[1]  & f1_MLP_best[0] $\pm$ f1_MLP_best[1] & & f1_ET_worst[0] $\pm$ f1_ET_worst[1] & f1_RF_worst[0] $\pm$ f1_RF_worst[1] & f1_MLP_worst[0] $\pm$ f1_MLP_worst[1] & & d_f1_ET & d_f1_RF & d_f1_MLP \\
& Macro Recall       & rec_ET_best[0] $\pm$ rec_ET_best[1]  & rec_RF_best[0] $\pm$ rec_RF_best[1] & rec_MLP_best[0] $\pm$ rec_MLP_best[1] & & rec_ET_worst[0] $\pm$ rec_ET_worst[1] & rec_RF_worst[0] $\pm$ rec_RF_worst[1] & rec_MLP_worst[0] $\pm$ rec_MLP_worst[1] & & d_rec_ET & d_rec_RF & d_rec_MLP \\
& Macro Precision    & prec_ET_best[0] $\pm$ prec_ET_best[1]   & prec_RF_best[0] $\pm$ prec_RF_best[1] & prec_MLP_best[0] $\pm$ prec_MLP_best[1] & & prec_ET_worst[0] $\pm$ prec_ET_worst[1] & prec_RF_worst[0] $\pm$ prec_RF_worst[1] & prec_MLP_worst[0] $\pm$ prec_MLP_worst[1] & & d_prec_ET & d_prec_RF & d_prec_MLP \\
& Accuracy     & acc_ET_best[0] $\pm$  acc_ET_best[1] &  acc_RF_best[0] $\pm$ acc_RF_best[1] &  acc_MLP_best[0] $\pm$ acc_MLP_best[1] & & acc_ET_worst[0] $\pm$ acc_ET_worst[1] & acc_RF_worst[0] $\pm$ acc_RF_worst[1] & acc_MLP_worst[0] $\pm$ acc_MLP_worst[1] & & d_acc_ET & d_acc_RF & d_acc_MLP \\
